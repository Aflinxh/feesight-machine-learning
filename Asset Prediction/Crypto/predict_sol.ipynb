# %% [markdown]
# #Try Stock Prediction - NETFLIX

# %%
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import datetime as dt
import joblib
import yfinance as yf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 1. Read Data

# %%
# stock_data = pd.read_csv('/content/NFLX.csv', index_col='Date')
# stock_data

ticker = 'SOL-USD'
# start_date = '2020-05-20'
# end_date = pd.Timestamp.now().strftime('%Y-%m-%d')
start_date = '2020-05-21'
end_date = '2024-05-21'
stock_data = yf.download(ticker, start=start_date, end=end_date)
stock_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-05-21    0.579692    0.613789    0.543346    0.608915    0.608915
# 2020-05-22    0.605239    0.676432    0.582830    0.638875    0.638875
# 2020-05-23    0.637415    0.638849    0.588247    0.613031    0.613031
# 2020-05-24    0.613289    0.613289    0.548432    0.549053    0.549053
# 2020-05-25    0.548570    0.650138    0.538064    0.600857    0.600857
# ...                ...         ...         ...         ...         ...
# 2024-05-16  158.187759  164.319321  156.772629  159.116455  159.116455
# 2024-05-17  159.116455  171.606079  159.116455  169.530548  169.530548
# 2024-05-18  169.530548  175.779099  168.933060  172.539139  172.539139
# 2024-05-19  172.539200  175.189331  166.732620  170.091354  170.091354
# 2024-05-20  170.091354  187.447128  168.030441  186.520493  186.520493
#
#                 Volume
# Date
# 2020-05-21     2863017
# 2020-05-22     3411419
# 2020-05-23     2638524
# 2020-05-24     2786816
# 2020-05-25     4509580
# ...                ...
# 2024-05-16  3498272951
# 2024-05-17  3371355809
# 2024-05-18  2479657643
# 2024-05-19  2300080451
# 2024-05-20  4636864705
#
# [1461 rows x 6 columns]

# %% [markdown]
# ## 2. Plotting Data

# %% [markdown]
# ### 2.1 Plot High & Low

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
# x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]
x_dates = stock_data.index

plt.plot(x_dates, stock_data['High'], label='High')
plt.plot(x_dates, stock_data['Low'], label='Low')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ### 2.2 Plot Open & Close

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
# x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]
x_dates = stock_data.index

plt.plot(x_dates, stock_data['Open'], label='Open')
plt.plot(x_dates, stock_data['Close'], label='Close')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ## 3. Stock Prediction

# %% [markdown]
# ### 3.1 Normalize or Rescale

# %%
features = stock_data.iloc[:, 0:4]
sc = StandardScaler()
features_scaled = sc.fit_transform(features.values)
stock_data_ft = pd.DataFrame(columns=features.columns, data=features_scaled, index=features.index)

# Simpan objek StandardScaler
joblib.dump(sc, 'standard_scaler.pkl')
# Out:
# ['standard_scaler.pkl']

# %% [markdown]
# ### 3.2 Train & Test

# %% [markdown]
# #### 3.2.1 Splitting

# %%
def lstm_split(data, n_steps):
  X, y = [], []
  for i in range(len(data) - n_steps):
    X.append(data[i:i + n_steps, :-1])
    y.append(data[i + n_steps-1, -1])

  return np.array(X), np.array(y)

# %%
n_steps = 13
X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

train_split = 0.8
split_idx = int(np.ceil(len(X1)*train_split))
date_index = stock_data_ft.index

X_train, X_test = X1[:split_idx], X1[split_idx:]
y_train, y_test = y1[:split_idx], y1[split_idx:]
X_train_date, X_test_date = date_index[n_steps-1:split_idx + n_steps-1], date_index[split_idx + n_steps-1:len(X1) + n_steps-1]

print(X1.shape, X_train.shape, X_test.shape, y_test.shape)
# Out:
# (1448, 13, 3) (1159, 13, 3) (289, 13, 3) (289,)

# %% [markdown]
# #### 3.2.2 Training

# %%
lstm = Sequential()
lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
lstm.add(LSTM(50, activation="relu"))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error', optimizer='adam')
lstm.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 13, 50)            10800
#
#  lstm_11 (LSTM)              (None, 50)                20200
#
#  dense_5 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 31051 (121.29 KB)
# Trainable params: 31051 (121.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = lstm.fit(X_train, y_train, epochs=150, batch_size=4, verbose=2, shuffle=False)
# Out:
# Epoch 1/150
# 290/290 - 6s - loss: 0.1836 - 6s/epoch - 19ms/step
# Epoch 2/150
# 290/290 - 5s - loss: 0.0337 - 5s/epoch - 17ms/step
# Epoch 3/150
# 290/290 - 3s - loss: 0.0349 - 3s/epoch - 10ms/step
# Epoch 4/150
# 290/290 - 3s - loss: 0.0295 - 3s/epoch - 10ms/step
# Epoch 5/150
# 290/290 - 3s - loss: 0.0291 - 3s/epoch - 9ms/step
# Epoch 6/150
# 290/290 - 3s - loss: 0.0266 - 3s/epoch - 11ms/step
# Epoch 7/150
# 290/290 - 4s - loss: 0.0246 - 4s/epoch - 13ms/step
# Epoch 8/150
# 290/290 - 3s - loss: 0.0251 - 3s/epoch - 10ms/step
# Epoch 9/150
# 290/290 - 3s - loss: 0.0255 - 3s/epoch - 10ms/step
# Epoch 10/150
# 290/290 - 3s - loss: 0.0252 - 3s/epoch - 10ms/step
# Epoch 11/150
# 290/290 - 4s - loss: 0.0253 - 4s/epoch - 15ms/step
# Epoch 12/150
# 290/290 - 3s - loss: 0.0280 - 3s/epoch - 10ms/step
# Epoch 13/150
# 290/290 - 3s - loss: 0.0213 - 3s/epoch - 10ms/step
# Epoch 14/150
# 290/290 - 3s - loss: 0.0198 - 3s/epoch - 10ms/step
# Epoch 15/150
# 290/290 - 4s - loss: 0.0186 - 4s/epoch - 15ms/step
# Epoch 16/150
# 290/290 - 3s - loss: 0.0216 - 3s/epoch - 10ms/step
# Epoch 17/150
# 290/290 - 3s - loss: 0.0133 - 3s/epoch - 10ms/step
# Epoch 18/150
# 290/290 - 3s - loss: 0.0146 - 3s/epoch - 10ms/step
# Epoch 19/150
# 290/290 - 4s - loss: 0.0182 - 4s/epoch - 13ms/step
# Epoch 20/150
# 290/290 - 3s - loss: 0.0099 - 3s/epoch - 12ms/step
# Epoch 21/150
# 290/290 - 3s - loss: 0.0096 - 3s/epoch - 10ms/step
# Epoch 22/150
# 290/290 - 3s - loss: 0.0146 - 3s/epoch - 10ms/step
# Epoch 23/150
# 290/290 - 3s - loss: 0.0128 - 3s/epoch - 12ms/step
# Epoch 24/150
# 290/290 - 4s - loss: 0.0140 - 4s/epoch - 12ms/step
# Epoch 25/150
# 290/290 - 3s - loss: 0.0174 - 3s/epoch - 10ms/step
# Epoch 26/150
# 290/290 - 3s - loss: 0.0123 - 3s/epoch - 10ms/step
# Epoch 27/150
# 290/290 - 3s - loss: 0.0080 - 3s/epoch - 9ms/step
# Epoch 28/150
# 290/290 - 4s - loss: 0.0142 - 4s/epoch - 14ms/step
# Epoch 29/150
# 290/290 - 3s - loss: 0.0192 - 3s/epoch - 10ms/step
# Epoch 30/150
# 290/290 - 3s - loss: 0.0086 - 3s/epoch - 9ms/step
# Epoch 31/150
# 290/290 - 3s - loss: 0.0093 - 3s/epoch - 11ms/step
# Epoch 32/150
# 290/290 - 4s - loss: 0.0167 - 4s/epoch - 13ms/step
# Epoch 33/150
# 290/290 - 3s - loss: 0.0094 - 3s/epoch - 10ms/step
# Epoch 34/150
# 290/290 - 3s - loss: 0.0107 - 3s/epoch - 10ms/step
# Epoch 35/150
# 290/290 - 3s - loss: 0.0164 - 3s/epoch - 10ms/step
# Epoch 36/150
# 290/290 - 3s - loss: 0.0157 - 3s/epoch - 11ms/step
# Epoch 37/150
# 290/290 - 4s - loss: 0.0147 - 4s/epoch - 13ms/step
# Epoch 38/150
# 290/290 - 3s - loss: 0.0127 - 3s/epoch - 10ms/step
# Epoch 39/150
# 290/290 - 3s - loss: 0.0111 - 3s/epoch - 10ms/step
# Epoch 40/150
# 290/290 - 3s - loss: 0.0098 - 3s/epoch - 10ms/step
# Epoch 41/150
# 290/290 - 4s - loss: 0.0140 - 4s/epoch - 14ms/step
# Epoch 42/150
# 290/290 - 3s - loss: 0.0047 - 3s/epoch - 10ms/step
# Epoch 43/150
# 290/290 - 3s - loss: 0.0033 - 3s/epoch - 9ms/step
# Epoch 44/150
# 290/290 - 3s - loss: 0.0053 - 3s/epoch - 9ms/step
# Epoch 45/150
# 290/290 - 4s - loss: 0.0095 - 4s/epoch - 13ms/step
# Epoch 46/150
# 290/290 - 3s - loss: 0.0134 - 3s/epoch - 10ms/step
# Epoch 47/150
# 290/290 - 3s - loss: 0.0108 - 3s/epoch - 9ms/step
# Epoch 48/150
# 290/290 - 3s - loss: 0.0138 - 3s/epoch - 9ms/step
# Epoch 49/150
# 290/290 - 3s - loss: 0.0088 - 3s/epoch - 11ms/step
# Epoch 50/150
# 290/290 - 4s - loss: 0.0061 - 4s/epoch - 12ms/step
# Epoch 51/150
# 290/290 - 3s - loss: 0.0048 - 3s/epoch - 10ms/step
# Epoch 52/150
# 290/290 - 3s - loss: 0.0039 - 3s/epoch - 9ms/step
# Epoch 53/150
# 290/290 - 3s - loss: 0.0037 - 3s/epoch - 10ms/step
# Epoch 54/150
# 290/290 - 4s - loss: 0.0037 - 4s/epoch - 14ms/step
# Epoch 55/150
# 290/290 - 3s - loss: 0.0042 - 3s/epoch - 10ms/step
# Epoch 56/150
# 290/290 - 3s - loss: 0.0038 - 3s/epoch - 9ms/step
# Epoch 57/150
# 290/290 - 3s - loss: 0.0049 - 3s/epoch - 10ms/step
# Epoch 58/150
# 290/290 - 4s - loss: 0.0060 - 4s/epoch - 13ms/step
# Epoch 59/150
# 290/290 - 3s - loss: 0.0071 - 3s/epoch - 11ms/step
# Epoch 60/150
# 290/290 - 3s - loss: 0.0077 - 3s/epoch - 9ms/step
# Epoch 61/150
# 290/290 - 3s - loss: 0.0082 - 3s/epoch - 9ms/step
# Epoch 62/150
# 290/290 - 3s - loss: 0.0079 - 3s/epoch - 10ms/step
# Epoch 63/150
# 290/290 - 4s - loss: 0.0069 - 4s/epoch - 13ms/step
# Epoch 64/150
# 290/290 - 3s - loss: 0.0065 - 3s/epoch - 9ms/step
# Epoch 65/150
# 290/290 - 3s - loss: 0.0067 - 3s/epoch - 10ms/step
# Epoch 66/150
# 290/290 - 3s - loss: 0.0066 - 3s/epoch - 10ms/step
# Epoch 67/150
# 290/290 - 4s - loss: 0.0060 - 4s/epoch - 14ms/step
# Epoch 68/150
# 290/290 - 3s - loss: 0.0057 - 3s/epoch - 9ms/step
# Epoch 69/150
# 290/290 - 3s - loss: 0.0053 - 3s/epoch - 9ms/step
# Epoch 70/150
# 290/290 - 3s - loss: 0.0050 - 3s/epoch - 9ms/step
# Epoch 71/150
# 290/290 - 3s - loss: 0.0046 - 3s/epoch - 11ms/step
# Epoch 72/150
# 290/290 - 3s - loss: 0.0044 - 3s/epoch - 12ms/step
# Epoch 73/150
# 290/290 - 3s - loss: 0.0045 - 3s/epoch - 9ms/step
# Epoch 74/150
# 290/290 - 3s - loss: 0.0048 - 3s/epoch - 9ms/step
# Epoch 75/150
# 290/290 - 3s - loss: 0.0052 - 3s/epoch - 9ms/step
# Epoch 76/150
# 290/290 - 4s - loss: 0.0055 - 4s/epoch - 14ms/step
# Epoch 77/150
# 290/290 - 3s - loss: 0.0052 - 3s/epoch - 9ms/step
# Epoch 78/150
# 290/290 - 3s - loss: 0.0044 - 3s/epoch - 9ms/step
# Epoch 79/150
# 290/290 - 3s - loss: 0.0040 - 3s/epoch - 9ms/step
# Epoch 80/150
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 11ms/step
# Epoch 81/150
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 12ms/step
# Epoch 82/150
# 290/290 - 3s - loss: 0.0035 - 3s/epoch - 9ms/step
# Epoch 83/150
# 290/290 - 3s - loss: 0.0041 - 3s/epoch - 9ms/step
# Epoch 84/150
# 290/290 - 3s - loss: 0.0060 - 3s/epoch - 9ms/step
# Epoch 85/150
# 290/290 - 4s - loss: 0.0048 - 4s/epoch - 14ms/step
# Epoch 86/150
# 290/290 - 3s - loss: 0.0051 - 3s/epoch - 9ms/step
# Epoch 87/150
# 290/290 - 3s - loss: 0.0044 - 3s/epoch - 9ms/step
# Epoch 88/150
# 290/290 - 3s - loss: 0.0039 - 3s/epoch - 9ms/step
# Epoch 89/150
# 290/290 - 3s - loss: 0.0032 - 3s/epoch - 11ms/step
# Epoch 90/150
# 290/290 - 3s - loss: 0.0032 - 3s/epoch - 12ms/step
# Epoch 91/150
# 290/290 - 3s - loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 92/150
# 290/290 - 3s - loss: 0.0021 - 3s/epoch - 9ms/step
# Epoch 93/150
# 290/290 - 3s - loss: 0.0020 - 3s/epoch - 9ms/step
# Epoch 94/150
# 290/290 - 4s - loss: 0.0022 - 4s/epoch - 14ms/step
# Epoch 95/150
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 9ms/step
# Epoch 96/150
# 290/290 - 3s - loss: 0.0065 - 3s/epoch - 9ms/step
# Epoch 97/150
# 290/290 - 3s - loss: 0.0041 - 3s/epoch - 9ms/step
# Epoch 98/150
# 290/290 - 4s - loss: 0.0061 - 4s/epoch - 12ms/step
# Epoch 99/150
# 290/290 - 3s - loss: 0.0041 - 3s/epoch - 11ms/step
# Epoch 100/150
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 9ms/step
# Epoch 101/150
# 290/290 - 3s - loss: 0.0038 - 3s/epoch - 9ms/step
# Epoch 102/150
# 290/290 - 3s - loss: 0.0041 - 3s/epoch - 9ms/step
# Epoch 103/150
# 290/290 - 4s - loss: 0.0037 - 4s/epoch - 13ms/step
# Epoch 104/150
# 290/290 - 3s - loss: 0.0032 - 3s/epoch - 9ms/step
# Epoch 105/150
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 9ms/step
# Epoch 106/150
# 290/290 - 3s - loss: 0.0023 - 3s/epoch - 9ms/step
# Epoch 107/150
# 290/290 - 4s - loss: 0.0017 - 4s/epoch - 13ms/step
# Epoch 108/150
# 290/290 - 3s - loss: 0.0015 - 3s/epoch - 11ms/step
# Epoch 109/150
# 290/290 - 3s - loss: 0.0017 - 3s/epoch - 9ms/step
# Epoch 110/150
# 290/290 - 3s - loss: 0.0020 - 3s/epoch - 9ms/step
# Epoch 111/150
# 290/290 - 3s - loss: 0.0028 - 3s/epoch - 10ms/step
# Epoch 112/150
# 290/290 - 4s - loss: 0.0028 - 4s/epoch - 13ms/step
# Epoch 113/150
# 290/290 - 3s - loss: 0.0053 - 3s/epoch - 9ms/step
# Epoch 114/150
# 290/290 - 3s - loss: 0.0049 - 3s/epoch - 9ms/step
# Epoch 115/150
# 290/290 - 3s - loss: 0.0085 - 3s/epoch - 9ms/step
# Epoch 116/150
# 290/290 - 4s - loss: 0.0058 - 4s/epoch - 13ms/step
# Epoch 117/150
# 290/290 - 3s - loss: 0.0039 - 3s/epoch - 11ms/step
# Epoch 118/150
# 290/290 - 3s - loss: 0.0028 - 3s/epoch - 9ms/step
# Epoch 119/150
# 290/290 - 3s - loss: 0.0025 - 3s/epoch - 9ms/step
# Epoch 120/150
# 290/290 - 3s - loss: 0.0020 - 3s/epoch - 10ms/step
# Epoch 121/150
# 290/290 - 4s - loss: 0.0017 - 4s/epoch - 13ms/step
# Epoch 122/150
# 290/290 - 3s - loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 123/150
# 290/290 - 3s - loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 124/150
# 290/290 - 3s - loss: 0.0020 - 3s/epoch - 9ms/step
# Epoch 125/150
# 290/290 - 4s - loss: 0.0034 - 4s/epoch - 13ms/step
# Epoch 126/150
# 290/290 - 3s - loss: 0.0056 - 3s/epoch - 10ms/step
# Epoch 127/150
# 290/290 - 3s - loss: 0.0073 - 3s/epoch - 10ms/step
# Epoch 128/150
# 290/290 - 3s - loss: 0.0073 - 3s/epoch - 9ms/step
# Epoch 129/150
# 290/290 - 3s - loss: 0.0039 - 3s/epoch - 10ms/step
# Epoch 130/150
# 290/290 - 4s - loss: 0.0026 - 4s/epoch - 13ms/step
# Epoch 131/150
# 290/290 - 3s - loss: 0.0022 - 3s/epoch - 9ms/step
# Epoch 132/150
# 290/290 - 3s - loss: 0.0022 - 3s/epoch - 9ms/step
# Epoch 133/150
# 290/290 - 3s - loss: 0.0022 - 3s/epoch - 9ms/step
# Epoch 134/150
# 290/290 - 4s - loss: 0.0019 - 4s/epoch - 13ms/step
# Epoch 135/150
# 290/290 - 3s - loss: 0.0015 - 3s/epoch - 10ms/step
# Epoch 136/150
# 290/290 - 3s - loss: 0.0014 - 3s/epoch - 10ms/step
# Epoch 137/150
# 290/290 - 3s - loss: 0.0014 - 3s/epoch - 9ms/step
# Epoch 138/150
# 290/290 - 3s - loss: 0.0016 - 3s/epoch - 10ms/step
# Epoch 139/150
# 290/290 - 4s - loss: 0.0028 - 4s/epoch - 13ms/step
# Epoch 140/150
# 290/290 - 3s - loss: 0.0067 - 3s/epoch - 10ms/step
# Epoch 141/150
# 290/290 - 3s - loss: 0.0055 - 3s/epoch - 9ms/step
# Epoch 142/150
# 290/290 - 3s - loss: 0.0068 - 3s/epoch - 9ms/step
# Epoch 143/150
# 290/290 - 4s - loss: 0.0043 - 4s/epoch - 13ms/step
# Epoch 144/150
# 290/290 - 3s - loss: 0.0033 - 3s/epoch - 10ms/step
# Epoch 145/150
# 290/290 - 3s - loss: 0.0027 - 3s/epoch - 9ms/step
# Epoch 146/150
# 290/290 - 3s - loss: 0.0022 - 3s/epoch - 9ms/step
# Epoch 147/150
# 290/290 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 148/150
# 290/290 - 4s - loss: 0.0020 - 4s/epoch - 13ms/step
# Epoch 149/150
# 290/290 - 3s - loss: 0.0017 - 3s/epoch - 9ms/step
# Epoch 150/150
# 290/290 - 3s - loss: 0.0014 - 3s/epoch - 9ms/step

# %%
plt.plot(history.history['loss'])
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# #### 3.2.3 Evaluation

# %%
# Make predictions
y_pred = lstm.predict(X_test)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(X_test_date, y_test, label='True Values', color='blue')
plt.plot(X_test_date, y_pred, label='Predicted Values', color='red')
plt.title('True Values vs Predicted Values')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 10/10 [==============================] - 0s 5ms/step

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
mape = mean_absolute_percentage_error(y_test, y_pred)
print("RMSE: ", rmse)
print("MAPE: ", mape)
# Out:
# RMSE:  0.050302566184981266
# MAPE:  0.31406618889019566

# %%
# Save Model
lstm.save("predict_nflx.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# #### 3.2.4 Compare Performance

# %%
n_steps_list = [2, 6, 13, 20]
results = []
models = []

for n_steps in n_steps_list:
    X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

    split_idx = int(np.ceil(len(X1) * 0.8))
    X_train, X_test = X1[:split_idx], X1[split_idx:]
    y_train, y_test = y1[:split_idx], y1[split_idx:]

    lstm = Sequential()
    lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
    lstm.add(LSTM(50, activation='relu'))
    lstm.add(Dense(1))
    lstm.compile(loss='mean_squared_error', optimizer='adam')

    lstm.fit(X_train, y_train, epochs=100, batch_size=4, verbose=2, shuffle=False)

    y_pred = lstm.predict(X_test)
    y_pred = y_pred.flatten()  # Ensure y_pred is a 1D array

    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mape = mean_absolute_percentage_error(y_test, y_pred)

    results.append((n_steps, rmse, mape))
    models.append(lstm)
# Out:
# Epoch 1/100
# 292/292 - 3s - loss: 0.2757 - 3s/epoch - 10ms/step
# Epoch 2/100
# 292/292 - 1s - loss: 0.0346 - 895ms/epoch - 3ms/step
# Epoch 3/100
# 292/292 - 1s - loss: 0.0224 - 904ms/epoch - 3ms/step
# Epoch 4/100
# 292/292 - 1s - loss: 0.0126 - 904ms/epoch - 3ms/step
# Epoch 5/100
# 292/292 - 1s - loss: 0.0146 - 889ms/epoch - 3ms/step
# Epoch 6/100
# 292/292 - 1s - loss: 0.0084 - 893ms/epoch - 3ms/step
# Epoch 7/100
# 292/292 - 1s - loss: 0.0107 - 1s/epoch - 4ms/step
# Epoch 8/100
# 292/292 - 1s - loss: 0.0081 - 1s/epoch - 5ms/step
# Epoch 9/100
# 292/292 - 1s - loss: 0.0081 - 1s/epoch - 4ms/step
# Epoch 10/100
# 292/292 - 1s - loss: 0.0070 - 827ms/epoch - 3ms/step
# Epoch 11/100
# 292/292 - 1s - loss: 0.0061 - 879ms/epoch - 3ms/step
# Epoch 12/100
# 292/292 - 1s - loss: 0.0058 - 891ms/epoch - 3ms/step
# Epoch 13/100
# 292/292 - 1s - loss: 0.0050 - 864ms/epoch - 3ms/step
# Epoch 14/100
# 292/292 - 1s - loss: 0.0044 - 912ms/epoch - 3ms/step
# Epoch 15/100
# 292/292 - 1s - loss: 0.0040 - 863ms/epoch - 3ms/step
# Epoch 16/100
# 292/292 - 1s - loss: 0.0035 - 895ms/epoch - 3ms/step
# Epoch 17/100
# 292/292 - 1s - loss: 0.0033 - 920ms/epoch - 3ms/step
# Epoch 18/100
# 292/292 - 1s - loss: 0.0033 - 907ms/epoch - 3ms/step
# Epoch 19/100
# 292/292 - 1s - loss: 0.0034 - 899ms/epoch - 3ms/step
# Epoch 20/100
# 292/292 - 1s - loss: 0.0035 - 926ms/epoch - 3ms/step
# Epoch 21/100
# 292/292 - 1s - loss: 0.0032 - 1s/epoch - 5ms/step
# Epoch 22/100
# 292/292 - 1s - loss: 0.0032 - 1s/epoch - 5ms/step
# Epoch 23/100
# 292/292 - 1s - loss: 0.0033 - 1s/epoch - 3ms/step
# Epoch 24/100
# 292/292 - 1s - loss: 0.0034 - 902ms/epoch - 3ms/step
# Epoch 25/100
# 292/292 - 1s - loss: 0.0036 - 908ms/epoch - 3ms/step
# Epoch 26/100
# 292/292 - 1s - loss: 0.0034 - 892ms/epoch - 3ms/step
# Epoch 27/100
# 292/292 - 1s - loss: 0.0038 - 889ms/epoch - 3ms/step
# Epoch 28/100
# 292/292 - 1s - loss: 0.0038 - 915ms/epoch - 3ms/step
# Epoch 29/100
# 292/292 - 1s - loss: 0.0038 - 909ms/epoch - 3ms/step
# Epoch 30/100
# 292/292 - 1s - loss: 0.0036 - 899ms/epoch - 3ms/step
# Epoch 31/100
# 292/292 - 1s - loss: 0.0032 - 832ms/epoch - 3ms/step
# Epoch 32/100
# 292/292 - 1s - loss: 0.0029 - 863ms/epoch - 3ms/step
# Epoch 33/100
# 292/292 - 1s - loss: 0.0029 - 869ms/epoch - 3ms/step
# Epoch 34/100
# 292/292 - 1s - loss: 0.0033 - 1s/epoch - 4ms/step
# Epoch 35/100
# 292/292 - 1s - loss: 0.0032 - 1s/epoch - 5ms/step
# Epoch 36/100
# 292/292 - 1s - loss: 0.0033 - 1s/epoch - 5ms/step
# Epoch 37/100
# 292/292 - 1s - loss: 0.0030 - 926ms/epoch - 3ms/step
# Epoch 38/100
# 292/292 - 1s - loss: 0.0027 - 907ms/epoch - 3ms/step
# Epoch 39/100
# 292/292 - 1s - loss: 0.0023 - 902ms/epoch - 3ms/step
# Epoch 40/100
# 292/292 - 1s - loss: 0.0027 - 896ms/epoch - 3ms/step
# Epoch 41/100
# 292/292 - 1s - loss: 0.0027 - 902ms/epoch - 3ms/step
# Epoch 42/100
# 292/292 - 1s - loss: 0.0026 - 905ms/epoch - 3ms/step
# Epoch 43/100
# 292/292 - 1s - loss: 0.0027 - 872ms/epoch - 3ms/step
# Epoch 44/100
# 292/292 - 1s - loss: 0.0026 - 897ms/epoch - 3ms/step
# Epoch 45/100
# 292/292 - 1s - loss: 0.0024 - 899ms/epoch - 3ms/step
# Epoch 46/100
# 292/292 - 1s - loss: 0.0023 - 910ms/epoch - 3ms/step
# Epoch 47/100
# 292/292 - 1s - loss: 0.0023 - 938ms/epoch - 3ms/step
# Epoch 48/100
# 292/292 - 1s - loss: 0.0025 - 1s/epoch - 5ms/step
# Epoch 49/100
# 292/292 - 1s - loss: 0.0025 - 1s/epoch - 5ms/step
# Epoch 50/100
# 292/292 - 1s - loss: 0.0029 - 1s/epoch - 3ms/step
# Epoch 51/100
# 292/292 - 1s - loss: 0.0028 - 918ms/epoch - 3ms/step
# Epoch 52/100
# 292/292 - 1s - loss: 0.0023 - 916ms/epoch - 3ms/step
# Epoch 53/100
# 292/292 - 1s - loss: 0.0023 - 871ms/epoch - 3ms/step
# Epoch 54/100
# 292/292 - 1s - loss: 0.0035 - 846ms/epoch - 3ms/step
# Epoch 55/100
# 292/292 - 1s - loss: 0.0027 - 927ms/epoch - 3ms/step
# Epoch 56/100
# 292/292 - 1s - loss: 0.0020 - 878ms/epoch - 3ms/step
# Epoch 57/100
# 292/292 - 1s - loss: 0.0021 - 874ms/epoch - 3ms/step
# Epoch 58/100
# 292/292 - 1s - loss: 0.0023 - 872ms/epoch - 3ms/step
# Epoch 59/100
# 292/292 - 1s - loss: 0.0022 - 881ms/epoch - 3ms/step
# Epoch 60/100
# 292/292 - 1s - loss: 0.0023 - 902ms/epoch - 3ms/step
# Epoch 61/100
# 292/292 - 1s - loss: 0.0026 - 1s/epoch - 4ms/step
# Epoch 62/100
# 292/292 - 1s - loss: 0.0023 - 1s/epoch - 5ms/step
# Epoch 63/100
# 292/292 - 1s - loss: 0.0023 - 1s/epoch - 4ms/step
# Epoch 64/100
# 292/292 - 1s - loss: 0.0022 - 876ms/epoch - 3ms/step
# Epoch 65/100
# 292/292 - 1s - loss: 0.0031 - 875ms/epoch - 3ms/step
# Epoch 66/100
# 292/292 - 1s - loss: 0.0020 - 885ms/epoch - 3ms/step
# Epoch 67/100
# 292/292 - 1s - loss: 0.0019 - 854ms/epoch - 3ms/step
# Epoch 68/100
# 292/292 - 1s - loss: 0.0021 - 869ms/epoch - 3ms/step
# Epoch 69/100
# 292/292 - 1s - loss: 0.0023 - 905ms/epoch - 3ms/step
# Epoch 70/100
# 292/292 - 1s - loss: 0.0024 - 873ms/epoch - 3ms/step
# Epoch 71/100
# 292/292 - 1s - loss: 0.0023 - 843ms/epoch - 3ms/step
# Epoch 72/100
# 292/292 - 1s - loss: 0.0023 - 870ms/epoch - 3ms/step
# Epoch 73/100
# 292/292 - 1s - loss: 0.0022 - 876ms/epoch - 3ms/step
# Epoch 74/100
# 292/292 - 1s - loss: 0.0023 - 973ms/epoch - 3ms/step
# Epoch 75/100
# 292/292 - 1s - loss: 0.0021 - 1s/epoch - 5ms/step
# Epoch 76/100
# 292/292 - 1s - loss: 0.0021 - 1s/epoch - 5ms/step
# Epoch 77/100
# 292/292 - 1s - loss: 0.0021 - 879ms/epoch - 3ms/step
# Epoch 78/100
# 292/292 - 1s - loss: 0.0022 - 889ms/epoch - 3ms/step
# Epoch 79/100
# 292/292 - 1s - loss: 0.0022 - 856ms/epoch - 3ms/step
# Epoch 80/100
# 292/292 - 1s - loss: 0.0023 - 856ms/epoch - 3ms/step
# Epoch 81/100
# 292/292 - 1s - loss: 0.0025 - 900ms/epoch - 3ms/step
# Epoch 82/100
# 292/292 - 1s - loss: 0.0032 - 890ms/epoch - 3ms/step
# Epoch 83/100
# 292/292 - 1s - loss: 0.0022 - 858ms/epoch - 3ms/step
# Epoch 84/100
# 292/292 - 1s - loss: 0.0020 - 863ms/epoch - 3ms/step
# Epoch 85/100
# 292/292 - 1s - loss: 0.0025 - 883ms/epoch - 3ms/step
# Epoch 86/100
# 292/292 - 1s - loss: 0.0025 - 931ms/epoch - 3ms/step
# Epoch 87/100
# 292/292 - 1s - loss: 0.0029 - 915ms/epoch - 3ms/step
# Epoch 88/100
# 292/292 - 1s - loss: 0.0033 - 1s/epoch - 5ms/step
# Epoch 89/100
# 292/292 - 2s - loss: 0.0038 - 2s/epoch - 5ms/step
# Epoch 90/100
# 292/292 - 1s - loss: 0.0049 - 1s/epoch - 4ms/step
# Epoch 91/100
# 292/292 - 1s - loss: 0.0045 - 847ms/epoch - 3ms/step
# Epoch 92/100
# 292/292 - 1s - loss: 0.0051 - 824ms/epoch - 3ms/step
# Epoch 93/100
# 292/292 - 1s - loss: 0.0049 - 912ms/epoch - 3ms/step
# Epoch 94/100
# 292/292 - 1s - loss: 0.0044 - 848ms/epoch - 3ms/step
# Epoch 95/100
# 292/292 - 1s - loss: 0.0047 - 842ms/epoch - 3ms/step
# Epoch 96/100
# 292/292 - 1s - loss: 0.0049 - 859ms/epoch - 3ms/step
# Epoch 97/100
# 292/292 - 1s - loss: 0.0052 - 878ms/epoch - 3ms/step
# Epoch 98/100
# 292/292 - 1s - loss: 0.0057 - 883ms/epoch - 3ms/step
# Epoch 99/100
# 292/292 - 1s - loss: 0.0068 - 867ms/epoch - 3ms/step
# Epoch 100/100
# 292/292 - 1s - loss: 0.0086 - 880ms/epoch - 3ms/step
# 10/10 [==============================] - 0s 4ms/step
# Epoch 1/100
# 291/291 - 4s - loss: 0.3165 - 4s/epoch - 13ms/step
# Epoch 2/100
# 291/291 - 2s - loss: 0.1314 - 2s/epoch - 8ms/step
# Epoch 3/100
# 291/291 - 2s - loss: 0.0400 - 2s/epoch - 5ms/step
# Epoch 4/100
# 291/291 - 1s - loss: 0.0257 - 1s/epoch - 5ms/step
# Epoch 5/100
# 291/291 - 1s - loss: 0.0152 - 1s/epoch - 5ms/step
# Epoch 6/100
# 291/291 - 1s - loss: 0.0135 - 1s/epoch - 5ms/step
# Epoch 7/100
# 291/291 - 1s - loss: 0.0165 - 1s/epoch - 5ms/step
# Epoch 8/100
# 291/291 - 2s - loss: 0.0146 - 2s/epoch - 5ms/step
# Epoch 9/100
# 291/291 - 2s - loss: 0.0146 - 2s/epoch - 5ms/step
# Epoch 10/100
# 291/291 - 2s - loss: 0.0159 - 2s/epoch - 8ms/step
# Epoch 11/100
# 291/291 - 2s - loss: 0.0159 - 2s/epoch - 6ms/step
# Epoch 12/100
# 291/291 - 2s - loss: 0.0175 - 2s/epoch - 5ms/step
# Epoch 13/100
# 291/291 - 1s - loss: 0.0176 - 1s/epoch - 5ms/step
# Epoch 14/100
# 291/291 - 2s - loss: 0.0163 - 2s/epoch - 5ms/step
# Epoch 15/100
# 291/291 - 1s - loss: 0.0172 - 1s/epoch - 5ms/step
# Epoch 16/100
# 291/291 - 2s - loss: 0.0178 - 2s/epoch - 5ms/step
# Epoch 17/100
# 291/291 - 1s - loss: 0.0180 - 1s/epoch - 5ms/step
# Epoch 18/100
# 291/291 - 2s - loss: 0.0245 - 2s/epoch - 7ms/step
# Epoch 19/100
# 291/291 - 2s - loss: 0.0291 - 2s/epoch - 8ms/step
# Epoch 20/100
# 291/291 - 1s - loss: 0.0214 - 1s/epoch - 5ms/step
# Epoch 21/100
# 291/291 - 1s - loss: 0.0279 - 1s/epoch - 5ms/step
# Epoch 22/100
# 291/291 - 1s - loss: 0.0234 - 1s/epoch - 5ms/step
# Epoch 23/100
# 291/291 - 1s - loss: 0.0311 - 1s/epoch - 5ms/step
# Epoch 24/100
# 291/291 - 1s - loss: 0.0258 - 1s/epoch - 5ms/step
# Epoch 25/100
# 291/291 - 2s - loss: 0.0305 - 2s/epoch - 5ms/step
# Epoch 26/100
# 291/291 - 2s - loss: 0.0165 - 2s/epoch - 6ms/step
# Epoch 27/100
# 291/291 - 2s - loss: 0.0235 - 2s/epoch - 8ms/step
# Epoch 28/100
# 291/291 - 2s - loss: 0.0250 - 2s/epoch - 6ms/step
# Epoch 29/100
# 291/291 - 1s - loss: 0.0308 - 1s/epoch - 5ms/step
# Epoch 30/100
# 291/291 - 2s - loss: 0.0252 - 2s/epoch - 5ms/step
# Epoch 31/100
# 291/291 - 1s - loss: 0.0283 - 1s/epoch - 5ms/step
# Epoch 32/100
# 291/291 - 1s - loss: 0.0234 - 1s/epoch - 5ms/step
# Epoch 33/100
# 291/291 - 1s - loss: 0.0161 - 1s/epoch - 5ms/step
# Epoch 34/100
# 291/291 - 2s - loss: 0.0124 - 2s/epoch - 6ms/step
# Epoch 35/100
# 291/291 - 2s - loss: 0.0135 - 2s/epoch - 8ms/step
# Epoch 36/100
# 291/291 - 2s - loss: 0.0166 - 2s/epoch - 6ms/step
# Epoch 37/100
# 291/291 - 1s - loss: 0.0173 - 1s/epoch - 5ms/step
# Epoch 38/100
# 291/291 - 1s - loss: 0.0172 - 1s/epoch - 5ms/step
# Epoch 39/100
# 291/291 - 1s - loss: 0.0086 - 1s/epoch - 5ms/step
# Epoch 40/100
# 291/291 - 1s - loss: 0.0140 - 1s/epoch - 5ms/step
# Epoch 41/100
# 291/291 - 2s - loss: 0.0180 - 2s/epoch - 5ms/step
# Epoch 42/100
# 291/291 - 2s - loss: 0.0181 - 2s/epoch - 5ms/step
# Epoch 43/100
# 291/291 - 2s - loss: 0.0178 - 2s/epoch - 8ms/step
# Epoch 44/100
# 291/291 - 2s - loss: 0.0180 - 2s/epoch - 7ms/step
# Epoch 45/100
# 291/291 - 1s - loss: 0.0179 - 1s/epoch - 5ms/step
# Epoch 46/100
# 291/291 - 1s - loss: 0.0174 - 1s/epoch - 5ms/step
# Epoch 47/100
# 291/291 - 1s - loss: 0.0101 - 1s/epoch - 5ms/step
# Epoch 48/100
# 291/291 - 2s - loss: 0.0143 - 2s/epoch - 5ms/step
# Epoch 49/100
# 291/291 - 2s - loss: 0.0146 - 2s/epoch - 5ms/step
# Epoch 50/100
# 291/291 - 2s - loss: 0.0102 - 2s/epoch - 6ms/step
# Epoch 51/100
# 291/291 - 2s - loss: 0.0132 - 2s/epoch - 8ms/step
# Epoch 52/100
# 291/291 - 2s - loss: 0.0108 - 2s/epoch - 7ms/step
# Epoch 53/100
# 291/291 - 1s - loss: 0.0139 - 1s/epoch - 5ms/step
# Epoch 54/100
# 291/291 - 2s - loss: 0.0118 - 2s/epoch - 7ms/step
# Epoch 55/100
# 291/291 - 2s - loss: 0.0131 - 2s/epoch - 6ms/step
# Epoch 56/100
# 291/291 - 1s - loss: 0.0145 - 1s/epoch - 5ms/step
# Epoch 57/100
# 291/291 - 1s - loss: 0.0120 - 1s/epoch - 5ms/step
# Epoch 58/100
# 291/291 - 2s - loss: 0.0088 - 2s/epoch - 6ms/step
# Epoch 59/100
# 291/291 - 2s - loss: 0.0118 - 2s/epoch - 8ms/step
# Epoch 60/100
# 291/291 - 2s - loss: 0.0111 - 2s/epoch - 6ms/step
# Epoch 61/100
# 291/291 - 1s - loss: 0.0107 - 1s/epoch - 5ms/step
# Epoch 62/100
# 291/291 - 1s - loss: 0.0104 - 1s/epoch - 5ms/step
# Epoch 63/100
# 291/291 - 1s - loss: 0.0068 - 1s/epoch - 5ms/step
# Epoch 64/100
# 291/291 - 1s - loss: 0.0083 - 1s/epoch - 5ms/step
# Epoch 65/100
# 291/291 - 1s - loss: 0.0105 - 1s/epoch - 5ms/step
# Epoch 66/100
# 291/291 - 1s - loss: 0.0098 - 1s/epoch - 5ms/step
# Epoch 67/100
# 291/291 - 2s - loss: 0.0092 - 2s/epoch - 7ms/step
# Epoch 68/100
# 291/291 - 2s - loss: 0.0097 - 2s/epoch - 7ms/step
# Epoch 69/100
# 291/291 - 2s - loss: 0.0084 - 2s/epoch - 5ms/step
# Epoch 70/100
# 291/291 - 2s - loss: 0.0097 - 2s/epoch - 6ms/step
# Epoch 71/100
# 291/291 - 1s - loss: 0.0091 - 1s/epoch - 5ms/step
# Epoch 72/100
# 291/291 - 1s - loss: 0.0090 - 1s/epoch - 5ms/step
# Epoch 73/100
# 291/291 - 2s - loss: 0.0075 - 2s/epoch - 5ms/step
# Epoch 74/100
# 291/291 - 1s - loss: 0.0092 - 1s/epoch - 5ms/step
# Epoch 75/100
# 291/291 - 2s - loss: 0.0077 - 2s/epoch - 7ms/step
# Epoch 76/100
# 291/291 - 2s - loss: 0.0081 - 2s/epoch - 7ms/step
# Epoch 77/100
# 291/291 - 1s - loss: 0.0077 - 1s/epoch - 5ms/step
# Epoch 78/100
# 291/291 - 1s - loss: 0.0068 - 1s/epoch - 5ms/step
# Epoch 79/100
# 291/291 - 1s - loss: 0.0074 - 1s/epoch - 5ms/step
# Epoch 80/100
# 291/291 - 1s - loss: 0.0067 - 1s/epoch - 5ms/step
# Epoch 81/100
# 291/291 - 1s - loss: 0.0071 - 1s/epoch - 5ms/step
# Epoch 82/100
# 291/291 - 1s - loss: 0.0061 - 1s/epoch - 5ms/step
# Epoch 83/100
# 291/291 - 2s - loss: 0.0069 - 2s/epoch - 6ms/step
# Epoch 84/100
# 291/291 - 2s - loss: 0.0062 - 2s/epoch - 8ms/step
# Epoch 85/100
# 291/291 - 2s - loss: 0.0072 - 2s/epoch - 6ms/step
# Epoch 86/100
# 291/291 - 2s - loss: 0.0062 - 2s/epoch - 5ms/step
# Epoch 87/100
# 291/291 - 2s - loss: 0.0068 - 2s/epoch - 5ms/step
# Epoch 88/100
# 291/291 - 2s - loss: 0.0061 - 2s/epoch - 5ms/step
# Epoch 89/100
# 291/291 - 1s - loss: 0.0068 - 1s/epoch - 5ms/step
# Epoch 90/100
# 291/291 - 2s - loss: 0.0058 - 2s/epoch - 5ms/step
# Epoch 91/100
# 291/291 - 2s - loss: 0.0060 - 2s/epoch - 6ms/step
# Epoch 92/100
# 291/291 - 2s - loss: 0.0055 - 2s/epoch - 8ms/step
# Epoch 93/100
# 291/291 - 2s - loss: 0.0049 - 2s/epoch - 6ms/step
# Epoch 94/100
# 291/291 - 1s - loss: 0.0052 - 1s/epoch - 5ms/step
# Epoch 95/100
# 291/291 - 1s - loss: 0.0054 - 1s/epoch - 5ms/step
# Epoch 96/100
# 291/291 - 1s - loss: 0.0046 - 1s/epoch - 5ms/step
# Epoch 97/100
# 291/291 - 1s - loss: 0.0049 - 1s/epoch - 5ms/step
# Epoch 98/100
# 291/291 - 1s - loss: 0.0058 - 1s/epoch - 5ms/step
# Epoch 99/100
# 291/291 - 1s - loss: 0.0053 - 1s/epoch - 5ms/step
# Epoch 100/100
# 291/291 - 2s - loss: 0.0049 - 2s/epoch - 7ms/step
# 10/10 [==============================] - 1s 5ms/step
# Epoch 1/100
# 290/290 - 6s - loss: 0.1411 - 6s/epoch - 20ms/step
# Epoch 2/100
# 290/290 - 3s - loss: 0.0755 - 3s/epoch - 10ms/step
# Epoch 3/100
# 290/290 - 4s - loss: 0.0246 - 4s/epoch - 12ms/step
# Epoch 4/100
# 290/290 - 3s - loss: 0.0243 - 3s/epoch - 11ms/step
# Epoch 5/100
# 290/290 - 3s - loss: 0.0246 - 3s/epoch - 10ms/step
# Epoch 6/100
# 290/290 - 3s - loss: 0.0273 - 3s/epoch - 10ms/step
# Epoch 7/100
# 290/290 - 3s - loss: 0.0239 - 3s/epoch - 10ms/step
# Epoch 8/100
# 290/290 - 4s - loss: 0.0277 - 4s/epoch - 13ms/step
# Epoch 9/100
# 290/290 - 3s - loss: 0.0263 - 3s/epoch - 10ms/step
# Epoch 10/100
# 290/290 - 3s - loss: 0.0255 - 3s/epoch - 10ms/step
# Epoch 11/100
# 290/290 - 3s - loss: 0.0295 - 3s/epoch - 10ms/step
# Epoch 12/100
# 290/290 - 4s - loss: 0.0246 - 4s/epoch - 14ms/step
# Epoch 13/100
# 290/290 - 3s - loss: 0.0295 - 3s/epoch - 10ms/step
# Epoch 14/100
# 290/290 - 3s - loss: 0.0251 - 3s/epoch - 10ms/step
# Epoch 15/100
# 290/290 - 3s - loss: 0.0338 - 3s/epoch - 10ms/step
# Epoch 16/100
# 290/290 - 3s - loss: 0.0263 - 3s/epoch - 12ms/step
# Epoch 17/100
# 290/290 - 3s - loss: 0.0337 - 3s/epoch - 12ms/step
# Epoch 18/100
# 290/290 - 3s - loss: 0.0285 - 3s/epoch - 10ms/step
# Epoch 19/100
# 290/290 - 3s - loss: 0.0159 - 3s/epoch - 10ms/step
# Epoch 20/100
# 290/290 - 3s - loss: 0.0180 - 3s/epoch - 10ms/step
# Epoch 21/100
# 290/290 - 4s - loss: 0.0281 - 4s/epoch - 13ms/step
# Epoch 22/100
# 290/290 - 3s - loss: 0.0143 - 3s/epoch - 10ms/step
# Epoch 23/100
# 290/290 - 3s - loss: 0.0233 - 3s/epoch - 10ms/step
# Epoch 24/100
# 290/290 - 3s - loss: 0.0206 - 3s/epoch - 10ms/step
# Epoch 25/100
# 290/290 - 4s - loss: 0.0127 - 4s/epoch - 13ms/step
# Epoch 26/100
# 290/290 - 3s - loss: 0.0224 - 3s/epoch - 10ms/step
# Epoch 27/100
# 290/290 - 3s - loss: 0.0251 - 3s/epoch - 10ms/step
# Epoch 28/100
# 290/290 - 3s - loss: 0.0215 - 3s/epoch - 10ms/step
# Epoch 29/100
# 290/290 - 4s - loss: 0.0230 - 4s/epoch - 15ms/step
# Epoch 30/100
# 290/290 - 3s - loss: 0.0061 - 3s/epoch - 10ms/step
# Epoch 31/100
# 290/290 - 3s - loss: 0.0141 - 3s/epoch - 10ms/step
# Epoch 32/100
# 290/290 - 3s - loss: 0.0230 - 3s/epoch - 10ms/step
# Epoch 33/100
# 290/290 - 4s - loss: 0.0178 - 4s/epoch - 13ms/step
# Epoch 34/100
# 290/290 - 3s - loss: 0.0227 - 3s/epoch - 11ms/step
# Epoch 35/100
# 290/290 - 3s - loss: 0.0151 - 3s/epoch - 10ms/step
# Epoch 36/100
# 290/290 - 3s - loss: 0.0145 - 3s/epoch - 10ms/step
# Epoch 37/100
# 290/290 - 3s - loss: 0.0169 - 3s/epoch - 11ms/step
# Epoch 38/100
# 290/290 - 4s - loss: 0.0062 - 4s/epoch - 13ms/step
# Epoch 39/100
# 290/290 - 3s - loss: 0.0120 - 3s/epoch - 10ms/step
# Epoch 40/100
# 290/290 - 3s - loss: 0.0179 - 3s/epoch - 10ms/step
# Epoch 41/100
# 290/290 - 3s - loss: 0.0040 - 3s/epoch - 10ms/step
# Epoch 42/100
# 290/290 - 4s - loss: 0.0062 - 4s/epoch - 14ms/step
# Epoch 43/100
# 290/290 - 3s - loss: 0.0141 - 3s/epoch - 10ms/step
# Epoch 44/100
# 290/290 - 3s - loss: 0.0191 - 3s/epoch - 10ms/step
# Epoch 45/100
# 290/290 - 3s - loss: 0.0124 - 3s/epoch - 10ms/step
# Epoch 46/100
# 290/290 - 4s - loss: 0.0196 - 4s/epoch - 15ms/step
# Epoch 47/100
# 290/290 - 3s - loss: 0.0170 - 3s/epoch - 10ms/step
# Epoch 48/100
# 290/290 - 3s - loss: 0.0073 - 3s/epoch - 11ms/step
# Epoch 49/100
# 290/290 - 3s - loss: 0.0118 - 3s/epoch - 11ms/step
# Epoch 50/100
# 290/290 - 4s - loss: 0.0112 - 4s/epoch - 15ms/step
# Epoch 51/100
# 290/290 - 3s - loss: 0.0111 - 3s/epoch - 10ms/step
# Epoch 52/100
# 290/290 - 3s - loss: 0.0133 - 3s/epoch - 10ms/step
# Epoch 53/100
# 290/290 - 3s - loss: 0.0133 - 3s/epoch - 11ms/step
# Epoch 54/100
# 290/290 - 4s - loss: 0.0106 - 4s/epoch - 14ms/step
# Epoch 55/100
# 290/290 - 3s - loss: 0.0122 - 3s/epoch - 10ms/step
# Epoch 56/100
# 290/290 - 3s - loss: 0.0050 - 3s/epoch - 10ms/step
# Epoch 57/100
# 290/290 - 3s - loss: 0.0109 - 3s/epoch - 10ms/step
# Epoch 58/100
# 290/290 - 3s - loss: 0.0115 - 3s/epoch - 12ms/step
# Epoch 59/100
# 290/290 - 4s - loss: 0.0118 - 4s/epoch - 12ms/step
# Epoch 60/100
# 290/290 - 3s - loss: 0.0085 - 3s/epoch - 10ms/step
# Epoch 61/100
# 290/290 - 3s - loss: 0.0095 - 3s/epoch - 10ms/step
# Epoch 62/100
# 290/290 - 3s - loss: 0.0077 - 3s/epoch - 10ms/step
# Epoch 63/100
# 290/290 - 4s - loss: 0.0072 - 4s/epoch - 14ms/step
# Epoch 64/100
# 290/290 - 3s - loss: 0.0071 - 3s/epoch - 10ms/step
# Epoch 65/100
# 290/290 - 3s - loss: 0.0065 - 3s/epoch - 10ms/step
# Epoch 66/100
# 290/290 - 3s - loss: 0.0064 - 3s/epoch - 10ms/step
# Epoch 67/100
# 290/290 - 4s - loss: 0.0060 - 4s/epoch - 14ms/step
# Epoch 68/100
# 290/290 - 3s - loss: 0.0061 - 3s/epoch - 10ms/step
# Epoch 69/100
# 290/290 - 3s - loss: 0.0060 - 3s/epoch - 10ms/step
# Epoch 70/100
# 290/290 - 3s - loss: 0.0061 - 3s/epoch - 9ms/step
# Epoch 71/100
# 290/290 - 3s - loss: 0.0063 - 3s/epoch - 12ms/step
# Epoch 72/100
# 290/290 - 3s - loss: 0.0062 - 3s/epoch - 12ms/step
# Epoch 73/100
# 290/290 - 3s - loss: 0.0032 - 3s/epoch - 9ms/step
# Epoch 74/100
# 290/290 - 3s - loss: 0.0061 - 3s/epoch - 9ms/step
# Epoch 75/100
# 290/290 - 3s - loss: 0.0067 - 3s/epoch - 10ms/step
# Epoch 76/100
# 290/290 - 4s - loss: 0.0070 - 4s/epoch - 14ms/step
# Epoch 77/100
# 290/290 - 3s - loss: 0.0056 - 3s/epoch - 10ms/step
# Epoch 78/100
# 290/290 - 3s - loss: 0.0048 - 3s/epoch - 10ms/step
# Epoch 79/100
# 290/290 - 3s - loss: 0.0038 - 3s/epoch - 9ms/step
# Epoch 80/100
# 290/290 - 4s - loss: 0.0036 - 4s/epoch - 13ms/step
# Epoch 81/100
# 290/290 - 3s - loss: 0.0024 - 3s/epoch - 11ms/step
# Epoch 82/100
# 290/290 - 3s - loss: 0.0020 - 3s/epoch - 10ms/step
# Epoch 83/100
# 290/290 - 3s - loss: 0.0019 - 3s/epoch - 10ms/step
# Epoch 84/100
# 290/290 - 3s - loss: 0.0019 - 3s/epoch - 11ms/step
# Epoch 85/100
# 290/290 - 4s - loss: 0.0019 - 4s/epoch - 13ms/step
# Epoch 86/100
# 290/290 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 87/100
# 290/290 - 3s - loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 88/100
# 290/290 - 3s - loss: 0.0039 - 3s/epoch - 10ms/step
# Epoch 89/100
# 290/290 - 4s - loss: 0.0052 - 4s/epoch - 14ms/step
# Epoch 90/100
# 290/290 - 3s - loss: 0.0042 - 3s/epoch - 10ms/step
# Epoch 91/100
# 290/290 - 3s - loss: 0.0083 - 3s/epoch - 10ms/step
# Epoch 92/100
# 290/290 - 3s - loss: 0.0070 - 3s/epoch - 9ms/step
# Epoch 93/100
# 290/290 - 4s - loss: 0.0061 - 4s/epoch - 13ms/step
# Epoch 94/100
# 290/290 - 3s - loss: 0.0082 - 3s/epoch - 11ms/step
# Epoch 95/100
# 290/290 - 3s - loss: 0.0059 - 3s/epoch - 10ms/step
# Epoch 96/100
# 290/290 - 3s - loss: 0.0044 - 3s/epoch - 10ms/step
# Epoch 97/100
# 290/290 - 3s - loss: 0.0029 - 3s/epoch - 11ms/step
# Epoch 98/100
# 290/290 - 4s - loss: 0.0030 - 4s/epoch - 13ms/step
# Epoch 99/100
# 290/290 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 100/100
# 290/290 - 3s - loss: 0.0017 - 3s/epoch - 10ms/step
# 10/10 [==============================] - 0s 5ms/step
# Epoch 1/100
# 289/289 - 7s - loss: 0.1240 - 7s/epoch - 23ms/step
# Epoch 2/100
# 289/289 - 4s - loss: 0.0366 - 4s/epoch - 15ms/step
# Epoch 3/100
# 289/289 - 4s - loss: 0.0300 - 4s/epoch - 13ms/step
# Epoch 4/100
# 289/289 - 4s - loss: 0.0241 - 4s/epoch - 13ms/step
# Epoch 5/100
# 289/289 - 5s - loss: 0.0225 - 5s/epoch - 18ms/step
# Epoch 6/100
# 289/289 - 4s - loss: 0.0240 - 4s/epoch - 13ms/step
# Epoch 7/100
# 289/289 - 4s - loss: 0.0237 - 4s/epoch - 13ms/step
# Epoch 8/100
# 289/289 - 5s - loss: 0.0251 - 5s/epoch - 17ms/step
# Epoch 9/100
# 289/289 - 4s - loss: 0.0284 - 4s/epoch - 13ms/step
# Epoch 10/100
# 289/289 - 4s - loss: 0.0179 - 4s/epoch - 13ms/step
# Epoch 11/100
# 289/289 - 5s - loss: 0.0218 - 5s/epoch - 17ms/step
# Epoch 12/100
# 289/289 - 4s - loss: 0.0195 - 4s/epoch - 14ms/step
# Epoch 13/100
# 289/289 - 4s - loss: 0.0279 - 4s/epoch - 13ms/step
# Epoch 14/100
# 289/289 - 4s - loss: 0.0191 - 4s/epoch - 15ms/step
# Epoch 15/100
# 289/289 - 4s - loss: 0.0161 - 4s/epoch - 15ms/step
# Epoch 16/100
# 289/289 - 4s - loss: 0.0238 - 4s/epoch - 13ms/step
# Epoch 17/100
# 289/289 - 4s - loss: 0.0185 - 4s/epoch - 13ms/step
# Epoch 18/100
# 289/289 - 5s - loss: 0.0265 - 5s/epoch - 17ms/step
# Epoch 19/100
# 289/289 - 4s - loss: 0.0253 - 4s/epoch - 13ms/step
# Epoch 20/100
# 289/289 - 4s - loss: 0.0134 - 4s/epoch - 13ms/step
# Epoch 21/100
# 289/289 - 5s - loss: 0.0118 - 5s/epoch - 17ms/step
# Epoch 22/100
# 289/289 - 4s - loss: 0.0187 - 4s/epoch - 13ms/step
# Epoch 23/100
# 289/289 - 4s - loss: 0.0163 - 4s/epoch - 13ms/step
# Epoch 24/100
# 289/289 - 5s - loss: 0.0149 - 5s/epoch - 17ms/step
# Epoch 25/100
# 289/289 - 4s - loss: 0.0201 - 4s/epoch - 13ms/step
# Epoch 26/100
# 289/289 - 4s - loss: 0.0170 - 4s/epoch - 13ms/step
# Epoch 27/100
# 289/289 - 4s - loss: 0.0125 - 4s/epoch - 15ms/step
# Epoch 28/100
# 289/289 - 4s - loss: 0.0186 - 4s/epoch - 15ms/step
# Epoch 29/100
# 289/289 - 4s - loss: 0.0158 - 4s/epoch - 13ms/step
# Epoch 30/100
# 289/289 - 4s - loss: 0.0254 - 4s/epoch - 14ms/step
# Epoch 31/100
# 289/289 - 5s - loss: 0.0085 - 5s/epoch - 17ms/step
# Epoch 32/100
# 289/289 - 4s - loss: 0.0210 - 4s/epoch - 13ms/step
# Epoch 33/100
# 289/289 - 4s - loss: 0.0241 - 4s/epoch - 13ms/step
# Epoch 34/100
# 289/289 - 5s - loss: 0.0195 - 5s/epoch - 18ms/step
# Epoch 35/100
# 289/289 - 4s - loss: 0.0246 - 4s/epoch - 13ms/step
# Epoch 36/100
# 289/289 - 4s - loss: 0.0149 - 4s/epoch - 13ms/step
# Epoch 37/100
# 289/289 - 5s - loss: 0.0122 - 5s/epoch - 18ms/step
# Epoch 38/100
# 289/289 - 4s - loss: 0.0087 - 4s/epoch - 13ms/step
# Epoch 39/100
# 289/289 - 4s - loss: 0.0171 - 4s/epoch - 13ms/step
# Epoch 40/100
# 289/289 - 5s - loss: 0.0196 - 5s/epoch - 16ms/step
# Epoch 41/100
# 289/289 - 4s - loss: 0.0172 - 4s/epoch - 14ms/step
# Epoch 42/100
# 289/289 - 4s - loss: 0.0136 - 4s/epoch - 13ms/step
# Epoch 43/100
# 289/289 - 4s - loss: 0.0131 - 4s/epoch - 14ms/step
# Epoch 44/100
# 289/289 - 5s - loss: 0.0080 - 5s/epoch - 16ms/step
# Epoch 45/100
# 289/289 - 4s - loss: 0.0075 - 4s/epoch - 14ms/step
# Epoch 46/100
# 289/289 - 4s - loss: 0.0061 - 4s/epoch - 13ms/step
# Epoch 47/100
# 289/289 - 5s - loss: 0.0054 - 5s/epoch - 18ms/step
# Epoch 48/100
# 289/289 - 4s - loss: 0.0047 - 4s/epoch - 13ms/step
# Epoch 49/100
# 289/289 - 4s - loss: 0.0044 - 4s/epoch - 13ms/step
# Epoch 50/100
# 289/289 - 5s - loss: 0.0042 - 5s/epoch - 17ms/step
# Epoch 51/100
# 289/289 - 4s - loss: 0.0044 - 4s/epoch - 13ms/step
# Epoch 52/100
# 289/289 - 4s - loss: 0.0046 - 4s/epoch - 13ms/step
# Epoch 53/100
# 289/289 - 5s - loss: 0.0043 - 5s/epoch - 16ms/step
# Epoch 54/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 14ms/step
# Epoch 55/100
# 289/289 - 4s - loss: 0.0030 - 4s/epoch - 13ms/step
# Epoch 56/100
# 289/289 - 4s - loss: 0.0027 - 4s/epoch - 15ms/step
# Epoch 57/100
# 289/289 - 4s - loss: 0.0027 - 4s/epoch - 15ms/step
# Epoch 58/100
# 289/289 - 4s - loss: 0.0040 - 4s/epoch - 13ms/step
# Epoch 59/100
# 289/289 - 4s - loss: 0.0077 - 4s/epoch - 13ms/step
# Epoch 60/100
# 289/289 - 5s - loss: 0.0060 - 5s/epoch - 17ms/step
# Epoch 61/100
# 289/289 - 4s - loss: 0.0076 - 4s/epoch - 13ms/step
# Epoch 62/100
# 289/289 - 4s - loss: 0.0160 - 4s/epoch - 13ms/step
# Epoch 63/100
# 289/289 - 5s - loss: 0.0064 - 5s/epoch - 17ms/step
# Epoch 64/100
# 289/289 - 4s - loss: 0.0060 - 4s/epoch - 13ms/step
# Epoch 65/100
# 289/289 - 4s - loss: 0.0112 - 4s/epoch - 13ms/step
# Epoch 66/100
# 289/289 - 5s - loss: 0.0229 - 5s/epoch - 17ms/step
# Epoch 67/100
# 289/289 - 4s - loss: 0.0126 - 4s/epoch - 14ms/step
# Epoch 68/100
# 289/289 - 4s - loss: 0.0110 - 4s/epoch - 13ms/step
# Epoch 69/100
# 289/289 - 4s - loss: 0.0066 - 4s/epoch - 15ms/step
# Epoch 70/100
# 289/289 - 4s - loss: 0.0034 - 4s/epoch - 15ms/step
# Epoch 71/100
# 289/289 - 4s - loss: 0.0031 - 4s/epoch - 13ms/step
# Epoch 72/100
# 289/289 - 4s - loss: 0.0053 - 4s/epoch - 14ms/step
# Epoch 73/100
# 289/289 - 5s - loss: 0.0047 - 5s/epoch - 17ms/step
# Epoch 74/100
# 289/289 - 4s - loss: 0.0028 - 4s/epoch - 13ms/step
# Epoch 75/100
# 289/289 - 4s - loss: 0.0021 - 4s/epoch - 13ms/step
# Epoch 76/100
# 289/289 - 5s - loss: 0.0018 - 5s/epoch - 18ms/step
# Epoch 77/100
# 289/289 - 4s - loss: 0.0018 - 4s/epoch - 13ms/step
# Epoch 78/100
# 289/289 - 4s - loss: 0.0027 - 4s/epoch - 13ms/step
# Epoch 79/100
# 289/289 - 5s - loss: 0.0054 - 5s/epoch - 18ms/step
# Epoch 80/100
# 289/289 - 4s - loss: 0.0136 - 4s/epoch - 14ms/step
# Epoch 81/100
# 289/289 - 4s - loss: 0.0042 - 4s/epoch - 13ms/step
# Epoch 82/100
# 289/289 - 5s - loss: 0.0024 - 5s/epoch - 17ms/step
# Epoch 83/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 15ms/step
# Epoch 84/100
# 289/289 - 4s - loss: 0.0064 - 4s/epoch - 13ms/step
# Epoch 85/100
# 289/289 - 4s - loss: 0.0140 - 4s/epoch - 15ms/step
# Epoch 86/100
# 289/289 - 5s - loss: 0.0081 - 5s/epoch - 16ms/step
# Epoch 87/100
# 289/289 - 4s - loss: 0.0079 - 4s/epoch - 13ms/step
# Epoch 88/100
# 289/289 - 4s - loss: 0.0043 - 4s/epoch - 13ms/step
# Epoch 89/100
# 289/289 - 5s - loss: 0.0029 - 5s/epoch - 18ms/step
# Epoch 90/100
# 289/289 - 4s - loss: 0.0061 - 4s/epoch - 13ms/step
# Epoch 91/100
# 289/289 - 4s - loss: 0.0073 - 4s/epoch - 14ms/step
# Epoch 92/100
# 289/289 - 5s - loss: 0.0079 - 5s/epoch - 18ms/step
# Epoch 93/100
# 289/289 - 4s - loss: 0.0018 - 4s/epoch - 13ms/step
# Epoch 94/100
# 289/289 - 4s - loss: 0.0016 - 4s/epoch - 13ms/step
# Epoch 95/100
# 289/289 - 5s - loss: 0.0015 - 5s/epoch - 18ms/step
# Epoch 96/100
# 289/289 - 4s - loss: 0.0016 - 4s/epoch - 13ms/step
# Epoch 97/100
# 289/289 - 4s - loss: 0.0018 - 4s/epoch - 13ms/step
# Epoch 98/100
# 289/289 - 5s - loss: 0.0022 - 5s/epoch - 18ms/step
# Epoch 99/100
# 289/289 - 4s - loss: 0.0038 - 4s/epoch - 14ms/step
# Epoch 100/100
# 289/289 - 4s - loss: 0.0091 - 4s/epoch - 13ms/step
# 9/9 [==============================] - 0s 8ms/step

# %%
for result in results:
    print(f"n_steps: {result[0]}, RMSE: {result[1]}, MAPE: {result[2]}")
# Out:
# n_steps: 2, RMSE: 0.2592831356484487, MAPE: 0.8050786903666224
# n_steps: 6, RMSE: 0.14445313345068164, MAPE: 0.20342007871697743
# n_steps: 13, RMSE: 0.05423468049481343, MAPE: 0.4765427968151997
# n_steps: 20, RMSE: 0.17400713776476615, MAPE: 0.34873273636283914

# %%
plt.figure(figsize=(10, 5))
plt.plot([result[0] for result in results], [result[1] for result in results], marker='o', label='RMSE')
plt.plot([result[0] for result in results], [result[2] for result in results], marker='o', label='MAPE')
plt.xlabel('n_steps')
plt.ylabel('Error')
plt.title('Error vs. n_steps')
plt.legend()
plt.show()

# %% [markdown]
# The result shows that n_steps = n will reach the most accurate prediction, means that predicting the n+1th days is the best choice

# %% [markdown]
# #### 3.2.5 Cross Validation

# %%
# n_steps = 6
# X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

# %%
# tscv = TimeSeriesSplit(n_splits=5)
# rmse_scores = []
# mape_scores = []

# for train_index, test_index in tscv.split(X1):
#     X_train, X_test = X1[train_index], X1[test_index]
#     y_train, y_test = y1[train_index], y1[test_index]

#     # Define the model
#     model = Sequential()
#     model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
#     model.add(LSTM(50, activation='relu'))
#     model.add(Dense(1))
#     model.compile(loss='mean_squared_error', optimizer='adam')

#     # Train the model
#     model.fit(X_train, y_train, epochs=100, batch_size=4, verbose=0, shuffle=False)

#     # Predict
#     y_pred = model.predict(X_test)
#     y_pred = y_pred[:, 0]

#     # Calculate RMSE and MAPE
#     rmse = mean_squared_error(y_test, y_pred, squared=False)
#     mape = mean_absolute_percentage_error(y_test, y_pred)

#     rmse_scores.append(rmse)
#     mape_scores.append(mape)

# print(f"Average RMSE: {np.mean(rmse_scores)}, Average MAPE: {np.mean(mape_scores)}")

# %% [markdown]
# ###3.3 Run Saved Model

# %%
# Load the SavedModel
model = load_model('predict_nflx.h5')
sc = joblib.load('standard_scaler.pkl')

# %%
def prepare_input_data(ticker, end_date, n_steps):
    stock_data = yf.download(ticker, end=end_date)
    X_feat = stock_data[['Open', 'High', 'Low']]
    target_y = stock_data['Close']

    X_ft = sc.fit_transform(X_feat.values)
    stock_data_ft = pd.DataFrame(columns=X_feat.columns, data=X_ft, index=X_feat.index)
    stock_data_ft['Close'] = target_y.values

    input_data = stock_data_ft.values[-n_steps:, :-1]
    input_data = np.expand_dims(input_data, axis=0)

    return input_data, stock_data_ft.index[-1]

# %%
# Parameter prediksi
ticker = 'SOL-USD'
end_date = '2024-05-02'
n_steps = 13

# Menyiapkan data input
input_data, last_date = prepare_input_data(ticker, end_date, n_steps)

# Melakukan prediksi
predicted_price_scaled = model.predict(input_data).flatten()[0]

# Mengembalikan hasil prediksi ke skala semula
predicted_price = sc.inverse_transform([[np.nan, predicted_price_scaled, np.nan]])[0][1]

# Menampilkan hasil prediksi
print(f"Harga saham {ticker} yang diprediksi untuk tanggal {end_date} adalah: {predicted_price:.2f}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 21ms/step
# Harga saham SOL-USD yang diprediksi untuk tanggal 2024-05-02 adalah: 132.79
