# %% [markdown]
# #Try Stock Prediction - NETFLIX

# %%
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import datetime as dt
import joblib
import yfinance as yf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 1. Read Data

# %%
# stock_data = pd.read_csv('/content/NFLX.csv', index_col='Date')
# stock_data

ticker = 'LINK-USD'
# start_date = '2020-05-20'
# end_date = pd.Timestamp.now().strftime('%Y-%m-%d')
start_date = '2020-05-21'
end_date = '2024-05-21'
stock_data = yf.download(ticker, start=start_date, end=end_date)
stock_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2020-05-21   4.074099   4.149265   3.767087   3.847751   3.847751   475890242
# 2020-05-22   3.846107   4.118734   3.812580   4.070282   4.070282   391293983
# 2020-05-23   4.067676   4.097221   3.926330   3.955061   3.955061   350387118
# 2020-05-24   3.953498   4.022676   3.835857   3.836322   3.836322   338608148
# 2020-05-25   3.827350   3.901874   3.802169   3.869933   3.869933   319542427
# ...               ...        ...        ...        ...        ...         ...
# 2024-05-16  13.888228  15.821798  13.565376  15.509692  15.509692   768021706
# 2024-05-17  15.509694  16.721472  15.509694  16.252932  16.252932  1042969872
# 2024-05-18  16.252888  16.543102  16.074989  16.311008  16.311008   450272670
# 2024-05-19  16.311014  17.089281  16.311014  16.581558  16.581558   641616268
# 2024-05-20  16.581558  17.422253  16.415466  17.277952  17.277952   824464152
#
# [1461 rows x 6 columns]

# %% [markdown]
# ## 2. Plotting Data

# %% [markdown]
# ### 2.1 Plot High & Low

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
# x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]
x_dates = stock_data.index

plt.plot(x_dates, stock_data['High'], label='High')
plt.plot(x_dates, stock_data['Low'], label='Low')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ### 2.2 Plot Open & Close

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
# x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]
x_dates = stock_data.index

plt.plot(x_dates, stock_data['Open'], label='Open')
plt.plot(x_dates, stock_data['Close'], label='Close')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ## 3. Stock Prediction

# %% [markdown]
# ### 3.1 Normalize or Rescale

# %%
features = stock_data.iloc[:, 0:4]
sc = StandardScaler()
features_scaled = sc.fit_transform(features.values)
stock_data_ft = pd.DataFrame(columns=features.columns, data=features_scaled, index=features.index)

# Simpan objek StandardScaler
joblib.dump(sc, 'standard_scaler.pkl')
# Out:
# ['standard_scaler.pkl']

# %% [markdown]
# ### 3.2 Train & Test

# %% [markdown]
# #### 3.2.1 Splitting

# %%
def lstm_split(data, n_steps):
  X, y = [], []
  for i in range(len(data) - n_steps):
    X.append(data[i:i + n_steps, :-1])
    y.append(data[i + n_steps-1, -1])

  return np.array(X), np.array(y)

# %%
n_steps = 20
X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

train_split = 0.8
split_idx = int(np.ceil(len(X1)*train_split))
date_index = stock_data_ft.index

X_train, X_test = X1[:split_idx], X1[split_idx:]
y_train, y_test = y1[:split_idx], y1[split_idx:]
X_train_date, X_test_date = date_index[n_steps-1:split_idx + n_steps-1], date_index[split_idx + n_steps-1:len(X1) + n_steps-1]

print(X1.shape, X_train.shape, X_test.shape, y_test.shape)
# Out:
# (1441, 20, 3) (1153, 20, 3) (288, 20, 3) (288,)

# %% [markdown]
# #### 3.2.2 Training

# %%
lstm = Sequential()
lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
lstm.add(LSTM(50, activation="relu"))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error', optimizer='adam')
lstm.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 20, 50)            10800
#
#  lstm_13 (LSTM)              (None, 50)                20200
#
#  dense_6 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 31051 (121.29 KB)
# Trainable params: 31051 (121.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = lstm.fit(X_train, y_train, epochs=90, batch_size=4, verbose=2, shuffle=False)
# Out:
# Epoch 1/90
# 289/289 - 8s - loss: 0.2567 - 8s/epoch - 28ms/step
# Epoch 2/90
# 289/289 - 4s - loss: 0.1074 - 4s/epoch - 14ms/step
# Epoch 3/90
# 289/289 - 4s - loss: 0.1274 - 4s/epoch - 15ms/step
# Epoch 4/90
# 289/289 - 5s - loss: 0.1068 - 5s/epoch - 18ms/step
# Epoch 5/90
# 289/289 - 4s - loss: 0.0630 - 4s/epoch - 14ms/step
# Epoch 6/90
# 289/289 - 4s - loss: 0.0476 - 4s/epoch - 14ms/step
# Epoch 7/90
# 289/289 - 5s - loss: 0.0389 - 5s/epoch - 18ms/step
# Epoch 8/90
# 289/289 - 4s - loss: 0.0327 - 4s/epoch - 14ms/step
# Epoch 9/90
# 289/289 - 4s - loss: 0.0226 - 4s/epoch - 14ms/step
# Epoch 10/90
# 289/289 - 5s - loss: 0.0231 - 5s/epoch - 19ms/step
# Epoch 11/90
# 289/289 - 4s - loss: 0.0153 - 4s/epoch - 14ms/step
# Epoch 12/90
# 289/289 - 4s - loss: 0.0138 - 4s/epoch - 14ms/step
# Epoch 13/90
# 289/289 - 5s - loss: 0.0125 - 5s/epoch - 19ms/step
# Epoch 14/90
# 289/289 - 4s - loss: 0.0112 - 4s/epoch - 14ms/step
# Epoch 15/90
# 289/289 - 4s - loss: 0.0106 - 4s/epoch - 14ms/step
# Epoch 16/90
# 289/289 - 5s - loss: 0.0100 - 5s/epoch - 19ms/step
# Epoch 17/90
# 289/289 - 4s - loss: 0.0092 - 4s/epoch - 14ms/step
# Epoch 18/90
# 289/289 - 4s - loss: 0.0091 - 4s/epoch - 14ms/step
# Epoch 19/90
# 289/289 - 5s - loss: 0.0088 - 5s/epoch - 19ms/step
# Epoch 20/90
# 289/289 - 4s - loss: 0.0091 - 4s/epoch - 14ms/step
# Epoch 21/90
# 289/289 - 4s - loss: 0.0075 - 4s/epoch - 14ms/step
# Epoch 22/90
# 289/289 - 5s - loss: 0.0069 - 5s/epoch - 19ms/step
# Epoch 23/90
# 289/289 - 4s - loss: 0.0074 - 4s/epoch - 14ms/step
# Epoch 24/90
# 289/289 - 4s - loss: 0.0068 - 4s/epoch - 14ms/step
# Epoch 25/90
# 289/289 - 5s - loss: 0.0072 - 5s/epoch - 19ms/step
# Epoch 26/90
# 289/289 - 4s - loss: 0.0073 - 4s/epoch - 14ms/step
# Epoch 27/90
# 289/289 - 4s - loss: 0.0085 - 4s/epoch - 14ms/step
# Epoch 28/90
# 289/289 - 5s - loss: 0.0075 - 5s/epoch - 18ms/step
# Epoch 29/90
# 289/289 - 4s - loss: 0.0063 - 4s/epoch - 15ms/step
# Epoch 30/90
# 289/289 - 4s - loss: 0.0067 - 4s/epoch - 14ms/step
# Epoch 31/90
# 289/289 - 5s - loss: 0.0116 - 5s/epoch - 17ms/step
# Epoch 32/90
# 289/289 - 4s - loss: 0.0081 - 4s/epoch - 15ms/step
# Epoch 33/90
# 289/289 - 4s - loss: 0.0060 - 4s/epoch - 14ms/step
# Epoch 34/90
# 289/289 - 5s - loss: 0.0069 - 5s/epoch - 17ms/step
# Epoch 35/90
# 289/289 - 5s - loss: 0.0077 - 5s/epoch - 16ms/step
# Epoch 36/90
# 289/289 - 4s - loss: 0.0088 - 4s/epoch - 14ms/step
# Epoch 37/90
# 289/289 - 5s - loss: 0.0062 - 5s/epoch - 16ms/step
# Epoch 38/90
# 289/289 - 5s - loss: 0.0055 - 5s/epoch - 17ms/step
# Epoch 39/90
# 289/289 - 4s - loss: 0.0047 - 4s/epoch - 14ms/step
# Epoch 40/90
# 289/289 - 5s - loss: 0.0047 - 5s/epoch - 16ms/step
# Epoch 41/90
# 289/289 - 5s - loss: 0.0049 - 5s/epoch - 17ms/step
# Epoch 42/90
# 289/289 - 4s - loss: 0.0048 - 4s/epoch - 14ms/step
# Epoch 43/90
# 289/289 - 4s - loss: 0.0046 - 4s/epoch - 15ms/step
# Epoch 44/90
# 289/289 - 5s - loss: 0.0063 - 5s/epoch - 18ms/step
# Epoch 45/90
# 289/289 - 4s - loss: 0.0056 - 4s/epoch - 14ms/step
# Epoch 46/90
# 289/289 - 4s - loss: 0.0047 - 4s/epoch - 14ms/step
# Epoch 47/90
# 289/289 - 5s - loss: 0.0048 - 5s/epoch - 19ms/step
# Epoch 48/90
# 289/289 - 4s - loss: 0.0044 - 4s/epoch - 14ms/step
# Epoch 49/90
# 289/289 - 4s - loss: 0.0049 - 4s/epoch - 14ms/step
# Epoch 50/90
# 289/289 - 5s - loss: 0.0047 - 5s/epoch - 19ms/step
# Epoch 51/90
# 289/289 - 4s - loss: 0.0052 - 4s/epoch - 14ms/step
# Epoch 52/90
# 289/289 - 4s - loss: 0.0053 - 4s/epoch - 14ms/step
# Epoch 53/90
# 289/289 - 5s - loss: 0.0044 - 5s/epoch - 19ms/step
# Epoch 54/90
# 289/289 - 4s - loss: 0.0046 - 4s/epoch - 14ms/step
# Epoch 55/90
# 289/289 - 4s - loss: 0.0051 - 4s/epoch - 14ms/step
# Epoch 56/90
# 289/289 - 5s - loss: 0.0044 - 5s/epoch - 19ms/step
# Epoch 57/90
# 289/289 - 4s - loss: 0.0046 - 4s/epoch - 14ms/step
# Epoch 58/90
# 289/289 - 4s - loss: 0.0048 - 4s/epoch - 14ms/step
# Epoch 59/90
# 289/289 - 5s - loss: 0.0042 - 5s/epoch - 19ms/step
# Epoch 60/90
# 289/289 - 4s - loss: 0.0045 - 4s/epoch - 14ms/step
# Epoch 61/90
# 289/289 - 4s - loss: 0.0048 - 4s/epoch - 14ms/step
# Epoch 62/90
# 289/289 - 5s - loss: 0.0038 - 5s/epoch - 19ms/step
# Epoch 63/90
# 289/289 - 4s - loss: 0.0038 - 4s/epoch - 14ms/step
# Epoch 64/90
# 289/289 - 4s - loss: 0.0047 - 4s/epoch - 14ms/step
# Epoch 65/90
# 289/289 - 5s - loss: 0.0041 - 5s/epoch - 18ms/step
# Epoch 66/90
# 289/289 - 4s - loss: 0.0038 - 4s/epoch - 14ms/step
# Epoch 67/90
# 289/289 - 4s - loss: 0.0042 - 4s/epoch - 14ms/step
# Epoch 68/90
# 289/289 - 5s - loss: 0.0044 - 5s/epoch - 18ms/step
# Epoch 69/90
# 289/289 - 4s - loss: 0.0036 - 4s/epoch - 14ms/step
# Epoch 70/90
# 289/289 - 4s - loss: 0.0038 - 4s/epoch - 14ms/step
# Epoch 71/90
# 289/289 - 5s - loss: 0.0049 - 5s/epoch - 17ms/step
# Epoch 72/90
# 289/289 - 4s - loss: 0.0035 - 4s/epoch - 15ms/step
# Epoch 73/90
# 289/289 - 4s - loss: 0.0035 - 4s/epoch - 14ms/step
# Epoch 74/90
# 289/289 - 5s - loss: 0.0038 - 5s/epoch - 17ms/step
# Epoch 75/90
# 289/289 - 4s - loss: 0.0035 - 4s/epoch - 15ms/step
# Epoch 76/90
# 289/289 - 4s - loss: 0.0033 - 4s/epoch - 14ms/step
# Epoch 77/90
# 289/289 - 5s - loss: 0.0037 - 5s/epoch - 17ms/step
# Epoch 78/90
# 289/289 - 4s - loss: 0.0035 - 4s/epoch - 15ms/step
# Epoch 79/90
# 289/289 - 4s - loss: 0.0032 - 4s/epoch - 14ms/step
# Epoch 80/90
# 289/289 - 5s - loss: 0.0038 - 5s/epoch - 17ms/step
# Epoch 81/90
# 289/289 - 5s - loss: 0.0039 - 5s/epoch - 16ms/step
# Epoch 82/90
# 289/289 - 4s - loss: 0.0041 - 4s/epoch - 14ms/step
# Epoch 83/90
# 289/289 - 5s - loss: 0.0035 - 5s/epoch - 16ms/step
# Epoch 84/90
# 289/289 - 5s - loss: 0.0036 - 5s/epoch - 16ms/step
# Epoch 85/90
# 289/289 - 4s - loss: 0.0032 - 4s/epoch - 14ms/step
# Epoch 86/90
# 289/289 - 5s - loss: 0.0032 - 5s/epoch - 16ms/step
# Epoch 87/90
# 289/289 - 5s - loss: 0.0030 - 5s/epoch - 17ms/step
# Epoch 88/90
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 14ms/step
# Epoch 89/90
# 289/289 - 4s - loss: 0.0031 - 4s/epoch - 15ms/step
# Epoch 90/90
# 289/289 - 5s - loss: 0.0030 - 5s/epoch - 18ms/step

# %%
plt.plot(history.history['loss'])
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# #### 3.2.3 Evaluation

# %%
# Make predictions
y_pred = lstm.predict(X_test)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(X_test_date, y_test, label='True Values', color='blue')
plt.plot(X_test_date, y_pred, label='Predicted Values', color='red')
plt.title('True Values vs Predicted Values')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 9/9 [==============================] - 0s 8ms/step

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
mape = mean_absolute_percentage_error(y_test, y_pred)
print("RMSE: ", rmse)
print("MAPE: ", mape)
# Out:
# RMSE:  0.06176300356618123
# MAPE:  0.9543680480676137

# %%
# Save Model
lstm.save("predict_link.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# #### 3.2.4 Compare Performance

# %%
n_steps_list = [2, 6, 13, 20]
results = []
models = []

for n_steps in n_steps_list:
    X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

    split_idx = int(np.ceil(len(X1) * 0.8))
    X_train, X_test = X1[:split_idx], X1[split_idx:]
    y_train, y_test = y1[:split_idx], y1[split_idx:]

    lstm = Sequential()
    lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
    lstm.add(LSTM(50, activation='relu'))
    lstm.add(Dense(1))
    lstm.compile(loss='mean_squared_error', optimizer='adam')

    lstm.fit(X_train, y_train, epochs=100, batch_size=4, verbose=2, shuffle=False)

    y_pred = lstm.predict(X_test)
    y_pred = y_pred.flatten()  # Ensure y_pred is a 1D array

    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mape = mean_absolute_percentage_error(y_test, y_pred)

    results.append((n_steps, rmse, mape))
    models.append(lstm)
# Out:
# Epoch 1/100
# 292/292 - 3s - loss: 0.3137 - 3s/epoch - 11ms/step
# Epoch 2/100
# 292/292 - 1s - loss: 0.0881 - 1s/epoch - 4ms/step
# Epoch 3/100
# 292/292 - 1s - loss: 0.0360 - 1s/epoch - 4ms/step
# Epoch 4/100
# 292/292 - 1s - loss: 0.0194 - 1s/epoch - 5ms/step
# Epoch 5/100
# 292/292 - 1s - loss: 0.0196 - 1s/epoch - 4ms/step
# Epoch 6/100
# 292/292 - 1s - loss: 0.0166 - 1s/epoch - 4ms/step
# Epoch 7/100
# 292/292 - 1s - loss: 0.0138 - 814ms/epoch - 3ms/step
# Epoch 8/100
# 292/292 - 1s - loss: 0.0118 - 911ms/epoch - 3ms/step
# Epoch 9/100
# 292/292 - 1s - loss: 0.0102 - 1s/epoch - 4ms/step
# Epoch 10/100
# 292/292 - 1s - loss: 0.0093 - 1s/epoch - 4ms/step
# Epoch 11/100
# 292/292 - 1s - loss: 0.0099 - 969ms/epoch - 3ms/step
# Epoch 12/100
# 292/292 - 1s - loss: 0.0098 - 989ms/epoch - 3ms/step
# Epoch 13/100
# 292/292 - 1s - loss: 0.0098 - 1s/epoch - 4ms/step
# Epoch 14/100
# 292/292 - 1s - loss: 0.0094 - 1s/epoch - 4ms/step
# Epoch 15/100
# 292/292 - 1s - loss: 0.0091 - 823ms/epoch - 3ms/step
# Epoch 16/100
# 292/292 - 1s - loss: 0.0089 - 931ms/epoch - 3ms/step
# Epoch 17/100
# 292/292 - 2s - loss: 0.0087 - 2s/epoch - 5ms/step
# Epoch 18/100
# 292/292 - 1s - loss: 0.0084 - 1s/epoch - 5ms/step
# Epoch 19/100
# 292/292 - 1s - loss: 0.0082 - 1s/epoch - 5ms/step
# Epoch 20/100
# 292/292 - 1s - loss: 0.0076 - 782ms/epoch - 3ms/step
# Epoch 21/100
# 292/292 - 1s - loss: 0.0075 - 893ms/epoch - 3ms/step
# Epoch 22/100
# 292/292 - 1s - loss: 0.0073 - 1s/epoch - 3ms/step
# Epoch 23/100
# 292/292 - 1s - loss: 0.0066 - 952ms/epoch - 3ms/step
# Epoch 24/100
# 292/292 - 1s - loss: 0.0067 - 1s/epoch - 4ms/step
# Epoch 25/100
# 292/292 - 1s - loss: 0.0065 - 1s/epoch - 4ms/step
# Epoch 26/100
# 292/292 - 1s - loss: 0.0065 - 1s/epoch - 4ms/step
# Epoch 27/100
# 292/292 - 1s - loss: 0.0061 - 902ms/epoch - 3ms/step
# Epoch 28/100
# 292/292 - 1s - loss: 0.0059 - 877ms/epoch - 3ms/step
# Epoch 29/100
# 292/292 - 1s - loss: 0.0058 - 956ms/epoch - 3ms/step
# Epoch 30/100
# 292/292 - 2s - loss: 0.0056 - 2s/epoch - 6ms/step
# Epoch 31/100
# 292/292 - 2s - loss: 0.0055 - 2s/epoch - 7ms/step
# Epoch 32/100
# 292/292 - 1s - loss: 0.0053 - 1s/epoch - 5ms/step
# Epoch 33/100
# 292/292 - 1s - loss: 0.0053 - 1s/epoch - 4ms/step
# Epoch 34/100
# 292/292 - 1s - loss: 0.0052 - 1s/epoch - 4ms/step
# Epoch 35/100
# 292/292 - 1s - loss: 0.0053 - 1s/epoch - 4ms/step
# Epoch 36/100
# 292/292 - 1s - loss: 0.0053 - 1s/epoch - 4ms/step
# Epoch 37/100
# 292/292 - 1s - loss: 0.0056 - 1s/epoch - 4ms/step
# Epoch 38/100
# 292/292 - 1s - loss: 0.0054 - 1s/epoch - 4ms/step
# Epoch 39/100
# 292/292 - 1s - loss: 0.0053 - 876ms/epoch - 3ms/step
# Epoch 40/100
# 292/292 - 1s - loss: 0.0053 - 819ms/epoch - 3ms/step
# Epoch 41/100
# 292/292 - 1s - loss: 0.0053 - 866ms/epoch - 3ms/step
# Epoch 42/100
# 292/292 - 1s - loss: 0.0049 - 1s/epoch - 5ms/step
# Epoch 43/100
# 292/292 - 1s - loss: 0.0047 - 1s/epoch - 5ms/step
# Epoch 44/100
# 292/292 - 1s - loss: 0.0048 - 1s/epoch - 4ms/step
# Epoch 45/100
# 292/292 - 1s - loss: 0.0046 - 830ms/epoch - 3ms/step
# Epoch 46/100
# 292/292 - 1s - loss: 0.0048 - 801ms/epoch - 3ms/step
# Epoch 47/100
# 292/292 - 1s - loss: 0.0046 - 918ms/epoch - 3ms/step
# Epoch 48/100
# 292/292 - 1s - loss: 0.0046 - 966ms/epoch - 3ms/step
# Epoch 49/100
# 292/292 - 2s - loss: 0.0048 - 2s/epoch - 7ms/step
# Epoch 50/100
# 292/292 - 1s - loss: 0.0045 - 1s/epoch - 4ms/step
# Epoch 51/100
# 292/292 - 1s - loss: 0.0046 - 1s/epoch - 4ms/step
# Epoch 52/100
# 292/292 - 1s - loss: 0.0046 - 1s/epoch - 4ms/step
# Epoch 53/100
# 292/292 - 1s - loss: 0.0046 - 1s/epoch - 4ms/step
# Epoch 54/100
# 292/292 - 2s - loss: 0.0045 - 2s/epoch - 6ms/step
# Epoch 55/100
# 292/292 - 2s - loss: 0.0045 - 2s/epoch - 6ms/step
# Epoch 56/100
# 292/292 - 1s - loss: 0.0047 - 966ms/epoch - 3ms/step
# Epoch 57/100
# 292/292 - 1s - loss: 0.0047 - 806ms/epoch - 3ms/step
# Epoch 58/100
# 292/292 - 1s - loss: 0.0045 - 794ms/epoch - 3ms/step
# Epoch 59/100
# 292/292 - 1s - loss: 0.0048 - 807ms/epoch - 3ms/step
# Epoch 60/100
# 292/292 - 1s - loss: 0.0045 - 780ms/epoch - 3ms/step
# Epoch 61/100
# 292/292 - 1s - loss: 0.0047 - 784ms/epoch - 3ms/step
# Epoch 62/100
# 292/292 - 1s - loss: 0.0045 - 842ms/epoch - 3ms/step
# Epoch 63/100
# 292/292 - 1s - loss: 0.0057 - 794ms/epoch - 3ms/step
# Epoch 64/100
# 292/292 - 1s - loss: 0.0052 - 1s/epoch - 4ms/step
# Epoch 65/100
# 292/292 - 1s - loss: 0.0054 - 1s/epoch - 4ms/step
# Epoch 66/100
# 292/292 - 1s - loss: 0.0050 - 1s/epoch - 4ms/step
# Epoch 67/100
# 292/292 - 2s - loss: 0.0051 - 2s/epoch - 5ms/step
# Epoch 68/100
# 292/292 - 2s - loss: 0.0053 - 2s/epoch - 6ms/step
# Epoch 69/100
# 292/292 - 1s - loss: 0.0055 - 1s/epoch - 4ms/step
# Epoch 70/100
# 292/292 - 1s - loss: 0.0061 - 953ms/epoch - 3ms/step
# Epoch 71/100
# 292/292 - 1s - loss: 0.0066 - 1s/epoch - 4ms/step
# Epoch 72/100
# 292/292 - 1s - loss: 0.0066 - 948ms/epoch - 3ms/step
# Epoch 73/100
# 292/292 - 1s - loss: 0.0068 - 782ms/epoch - 3ms/step
# Epoch 74/100
# 292/292 - 1s - loss: 0.0069 - 826ms/epoch - 3ms/step
# Epoch 75/100
# 292/292 - 1s - loss: 0.0068 - 835ms/epoch - 3ms/step
# Epoch 76/100
# 292/292 - 1s - loss: 0.0061 - 800ms/epoch - 3ms/step
# Epoch 77/100
# 292/292 - 1s - loss: 0.0057 - 983ms/epoch - 3ms/step
# Epoch 78/100
# 292/292 - 1s - loss: 0.0054 - 946ms/epoch - 3ms/step
# Epoch 79/100
# 292/292 - 1s - loss: 0.0054 - 929ms/epoch - 3ms/step
# Epoch 80/100
# 292/292 - 1s - loss: 0.0056 - 1s/epoch - 5ms/step
# Epoch 81/100
# 292/292 - 2s - loss: 0.0052 - 2s/epoch - 7ms/step
# Epoch 82/100
# 292/292 - 1s - loss: 0.0052 - 1s/epoch - 4ms/step
# Epoch 83/100
# 292/292 - 1s - loss: 0.0052 - 844ms/epoch - 3ms/step
# Epoch 84/100
# 292/292 - 1s - loss: 0.0058 - 1s/epoch - 4ms/step
# Epoch 85/100
# 292/292 - 1s - loss: 0.0058 - 1s/epoch - 4ms/step
# Epoch 86/100
# 292/292 - 1s - loss: 0.0055 - 1s/epoch - 4ms/step
# Epoch 87/100
# 292/292 - 1s - loss: 0.0057 - 788ms/epoch - 3ms/step
# Epoch 88/100
# 292/292 - 1s - loss: 0.0056 - 1s/epoch - 4ms/step
# Epoch 89/100
# 292/292 - 1s - loss: 0.0055 - 824ms/epoch - 3ms/step
# Epoch 90/100
# 292/292 - 1s - loss: 0.0055 - 1s/epoch - 4ms/step
# Epoch 91/100
# 292/292 - 1s - loss: 0.0052 - 822ms/epoch - 3ms/step
# Epoch 92/100
# 292/292 - 1s - loss: 0.0051 - 1s/epoch - 3ms/step
# Epoch 93/100
# 292/292 - 1s - loss: 0.0050 - 1s/epoch - 5ms/step
# Epoch 94/100
# 292/292 - 1s - loss: 0.0051 - 1s/epoch - 5ms/step
# Epoch 95/100
# 292/292 - 1s - loss: 0.0051 - 1s/epoch - 5ms/step
# Epoch 96/100
# 292/292 - 1s - loss: 0.0052 - 838ms/epoch - 3ms/step
# Epoch 97/100
# 292/292 - 1s - loss: 0.0052 - 816ms/epoch - 3ms/step
# Epoch 98/100
# 292/292 - 1s - loss: 0.0052 - 795ms/epoch - 3ms/step
# Epoch 99/100
# 292/292 - 1s - loss: 0.0050 - 791ms/epoch - 3ms/step
# Epoch 100/100
# 292/292 - 1s - loss: 0.0051 - 811ms/epoch - 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# Epoch 1/100
# 291/291 - 4s - loss: 0.1559 - 4s/epoch - 13ms/step
# Epoch 2/100
# 291/291 - 1s - loss: 0.0687 - 1s/epoch - 5ms/step
# Epoch 3/100
# 291/291 - 1s - loss: 0.0443 - 1s/epoch - 5ms/step
# Epoch 4/100
# 291/291 - 1s - loss: 0.0378 - 1s/epoch - 5ms/step
# Epoch 5/100
# 291/291 - 3s - loss: 0.0315 - 3s/epoch - 9ms/step
# Epoch 6/100
# 291/291 - 2s - loss: 0.0294 - 2s/epoch - 7ms/step
# Epoch 7/100
# 291/291 - 1s - loss: 0.0230 - 1s/epoch - 5ms/step
# Epoch 8/100
# 291/291 - 1s - loss: 0.0220 - 1s/epoch - 5ms/step
# Epoch 9/100
# 291/291 - 1s - loss: 0.0204 - 1s/epoch - 4ms/step
# Epoch 10/100
# 291/291 - 1s - loss: 0.0202 - 1s/epoch - 5ms/step
# Epoch 11/100
# 291/291 - 1s - loss: 0.0238 - 1s/epoch - 5ms/step
# Epoch 12/100
# 291/291 - 2s - loss: 0.0224 - 2s/epoch - 5ms/step
# Epoch 13/100
# 291/291 - 2s - loss: 0.0185 - 2s/epoch - 6ms/step
# Epoch 14/100
# 291/291 - 2s - loss: 0.0193 - 2s/epoch - 8ms/step
# Epoch 15/100
# 291/291 - 2s - loss: 0.0149 - 2s/epoch - 6ms/step
# Epoch 16/100
# 291/291 - 1s - loss: 0.0121 - 1s/epoch - 5ms/step
# Epoch 17/100
# 291/291 - 1s - loss: 0.0108 - 1s/epoch - 5ms/step
# Epoch 18/100
# 291/291 - 1s - loss: 0.0097 - 1s/epoch - 5ms/step
# Epoch 19/100
# 291/291 - 2s - loss: 0.0080 - 2s/epoch - 5ms/step
# Epoch 20/100
# 291/291 - 2s - loss: 0.0077 - 2s/epoch - 5ms/step
# Epoch 21/100
# 291/291 - 1s - loss: 0.0082 - 1s/epoch - 5ms/step
# Epoch 22/100
# 291/291 - 2s - loss: 0.0076 - 2s/epoch - 8ms/step
# Epoch 23/100
# 291/291 - 2s - loss: 0.0071 - 2s/epoch - 7ms/step
# Epoch 24/100
# 291/291 - 1s - loss: 0.0075 - 1s/epoch - 5ms/step
# Epoch 25/100
# 291/291 - 1s - loss: 0.0068 - 1s/epoch - 5ms/step
# Epoch 26/100
# 291/291 - 1s - loss: 0.0071 - 1s/epoch - 5ms/step
# Epoch 27/100
# 291/291 - 1s - loss: 0.0073 - 1s/epoch - 5ms/step
# Epoch 28/100
# 291/291 - 1s - loss: 0.0076 - 1s/epoch - 5ms/step
# Epoch 29/100
# 291/291 - 1s - loss: 0.0073 - 1s/epoch - 5ms/step
# Epoch 30/100
# 291/291 - 2s - loss: 0.0072 - 2s/epoch - 7ms/step
# Epoch 31/100
# 291/291 - 2s - loss: 0.0084 - 2s/epoch - 8ms/step
# Epoch 32/100
# 291/291 - 1s - loss: 0.0088 - 1s/epoch - 5ms/step
# Epoch 33/100
# 291/291 - 1s - loss: 0.0070 - 1s/epoch - 5ms/step
# Epoch 34/100
# 291/291 - 1s - loss: 0.0055 - 1s/epoch - 5ms/step
# Epoch 35/100
# 291/291 - 1s - loss: 0.0060 - 1s/epoch - 5ms/step
# Epoch 36/100
# 291/291 - 1s - loss: 0.0050 - 1s/epoch - 5ms/step
# Epoch 37/100
# 291/291 - 1s - loss: 0.0062 - 1s/epoch - 5ms/step
# Epoch 38/100
# 291/291 - 2s - loss: 0.0060 - 2s/epoch - 5ms/step
# Epoch 39/100
# 291/291 - 2s - loss: 0.0053 - 2s/epoch - 8ms/step
# Epoch 40/100
# 291/291 - 2s - loss: 0.0046 - 2s/epoch - 6ms/step
# Epoch 41/100
# 291/291 - 1s - loss: 0.0052 - 1s/epoch - 5ms/step
# Epoch 42/100
# 291/291 - 1s - loss: 0.0046 - 1s/epoch - 5ms/step
# Epoch 43/100
# 291/291 - 1s - loss: 0.0054 - 1s/epoch - 5ms/step
# Epoch 44/100
# 291/291 - 1s - loss: 0.0043 - 1s/epoch - 5ms/step
# Epoch 45/100
# 291/291 - 1s - loss: 0.0048 - 1s/epoch - 5ms/step
# Epoch 46/100
# 291/291 - 1s - loss: 0.0043 - 1s/epoch - 5ms/step
# Epoch 47/100
# 291/291 - 2s - loss: 0.0045 - 2s/epoch - 7ms/step
# Epoch 48/100
# 291/291 - 2s - loss: 0.0043 - 2s/epoch - 8ms/step
# Epoch 49/100
# 291/291 - 1s - loss: 0.0041 - 1s/epoch - 5ms/step
# Epoch 50/100
# 291/291 - 1s - loss: 0.0042 - 1s/epoch - 5ms/step
# Epoch 51/100
# 291/291 - 1s - loss: 0.0039 - 1s/epoch - 5ms/step
# Epoch 52/100
# 291/291 - 2s - loss: 0.0045 - 2s/epoch - 5ms/step
# Epoch 53/100
# 291/291 - 1s - loss: 0.0041 - 1s/epoch - 5ms/step
# Epoch 54/100
# 291/291 - 1s - loss: 0.0055 - 1s/epoch - 5ms/step
# Epoch 55/100
# 291/291 - 2s - loss: 0.0042 - 2s/epoch - 6ms/step
# Epoch 56/100
# 291/291 - 2s - loss: 0.0046 - 2s/epoch - 8ms/step
# Epoch 57/100
# 291/291 - 2s - loss: 0.0043 - 2s/epoch - 6ms/step
# Epoch 58/100
# 291/291 - 1s - loss: 0.0070 - 1s/epoch - 5ms/step
# Epoch 59/100
# 291/291 - 1s - loss: 0.0046 - 1s/epoch - 5ms/step
# Epoch 60/100
# 291/291 - 1s - loss: 0.0043 - 1s/epoch - 5ms/step
# Epoch 61/100
# 291/291 - 1s - loss: 0.0037 - 1s/epoch - 5ms/step
# Epoch 62/100
# 291/291 - 1s - loss: 0.0037 - 1s/epoch - 5ms/step
# Epoch 63/100
# 291/291 - 1s - loss: 0.0041 - 1s/epoch - 5ms/step
# Epoch 64/100
# 291/291 - 2s - loss: 0.0040 - 2s/epoch - 8ms/step
# Epoch 65/100
# 291/291 - 2s - loss: 0.0052 - 2s/epoch - 7ms/step
# Epoch 66/100
# 291/291 - 1s - loss: 0.0045 - 1s/epoch - 5ms/step
# Epoch 67/100
# 291/291 - 1s - loss: 0.0041 - 1s/epoch - 5ms/step
# Epoch 68/100
# 291/291 - 1s - loss: 0.0047 - 1s/epoch - 5ms/step
# Epoch 69/100
# 291/291 - 1s - loss: 0.0044 - 1s/epoch - 5ms/step
# Epoch 70/100
# 291/291 - 1s - loss: 0.0037 - 1s/epoch - 5ms/step
# Epoch 71/100
# 291/291 - 1s - loss: 0.0041 - 1s/epoch - 5ms/step
# Epoch 72/100
# 291/291 - 2s - loss: 0.0036 - 2s/epoch - 6ms/step
# Epoch 73/100
# 291/291 - 2s - loss: 0.0042 - 2s/epoch - 8ms/step
# Epoch 74/100
# 291/291 - 2s - loss: 0.0036 - 2s/epoch - 6ms/step
# Epoch 75/100
# 291/291 - 2s - loss: 0.0037 - 2s/epoch - 5ms/step
# Epoch 76/100
# 291/291 - 1s - loss: 0.0040 - 1s/epoch - 5ms/step
# Epoch 77/100
# 291/291 - 1s - loss: 0.0038 - 1s/epoch - 5ms/step
# Epoch 78/100
# 291/291 - 1s - loss: 0.0035 - 1s/epoch - 5ms/step
# Epoch 79/100
# 291/291 - 1s - loss: 0.0039 - 1s/epoch - 5ms/step
# Epoch 80/100
# 291/291 - 2s - loss: 0.0034 - 2s/epoch - 6ms/step
# Epoch 81/100
# 291/291 - 2s - loss: 0.0034 - 2s/epoch - 8ms/step
# Epoch 82/100
# 291/291 - 2s - loss: 0.0037 - 2s/epoch - 6ms/step
# Epoch 83/100
# 291/291 - 1s - loss: 0.0036 - 1s/epoch - 5ms/step
# Epoch 84/100
# 291/291 - 2s - loss: 0.0054 - 2s/epoch - 5ms/step
# Epoch 85/100
# 291/291 - 1s - loss: 0.0039 - 1s/epoch - 5ms/step
# Epoch 86/100
# 291/291 - 1s - loss: 0.0040 - 1s/epoch - 5ms/step
# Epoch 87/100
# 291/291 - 1s - loss: 0.0034 - 1s/epoch - 5ms/step
# Epoch 88/100
# 291/291 - 1s - loss: 0.0038 - 1s/epoch - 5ms/step
# Epoch 89/100
# 291/291 - 2s - loss: 0.0036 - 2s/epoch - 7ms/step
# Epoch 90/100
# 291/291 - 2s - loss: 0.0037 - 2s/epoch - 8ms/step
# Epoch 91/100
# 291/291 - 2s - loss: 0.0032 - 2s/epoch - 5ms/step
# Epoch 92/100
# 291/291 - 1s - loss: 0.0040 - 1s/epoch - 5ms/step
# Epoch 93/100
# 291/291 - 1s - loss: 0.0034 - 1s/epoch - 5ms/step
# Epoch 94/100
# 291/291 - 1s - loss: 0.0040 - 1s/epoch - 5ms/step
# Epoch 95/100
# 291/291 - 1s - loss: 0.0034 - 1s/epoch - 5ms/step
# Epoch 96/100
# 291/291 - 1s - loss: 0.0033 - 1s/epoch - 5ms/step
# Epoch 97/100
# 291/291 - 2s - loss: 0.0031 - 2s/epoch - 6ms/step
# Epoch 98/100
# 291/291 - 2s - loss: 0.0034 - 2s/epoch - 8ms/step
# Epoch 99/100
# 291/291 - 2s - loss: 0.0036 - 2s/epoch - 5ms/step
# Epoch 100/100
# 291/291 - 1s - loss: 0.0033 - 1s/epoch - 5ms/step
# 10/10 [==============================] - 0s 4ms/step
# Epoch 1/100
# 290/290 - 7s - loss: 0.2827 - 7s/epoch - 23ms/step
# Epoch 2/100
# 290/290 - 3s - loss: 0.1058 - 3s/epoch - 10ms/step
# Epoch 3/100
# 290/290 - 3s - loss: 0.0947 - 3s/epoch - 10ms/step
# Epoch 4/100
# 290/290 - 3s - loss: 0.0808 - 3s/epoch - 12ms/step
# Epoch 5/100
# 290/290 - 4s - loss: 0.0739 - 4s/epoch - 13ms/step
# Epoch 6/100
# 290/290 - 3s - loss: 0.0533 - 3s/epoch - 10ms/step
# Epoch 7/100
# 290/290 - 3s - loss: 0.0383 - 3s/epoch - 10ms/step
# Epoch 8/100
# 290/290 - 3s - loss: 0.0315 - 3s/epoch - 10ms/step
# Epoch 9/100
# 290/290 - 4s - loss: 0.0244 - 4s/epoch - 15ms/step
# Epoch 10/100
# 290/290 - 3s - loss: 0.0180 - 3s/epoch - 10ms/step
# Epoch 11/100
# 290/290 - 3s - loss: 0.0139 - 3s/epoch - 10ms/step
# Epoch 12/100
# 290/290 - 3s - loss: 0.0127 - 3s/epoch - 10ms/step
# Epoch 13/100
# 290/290 - 4s - loss: 0.0129 - 4s/epoch - 15ms/step
# Epoch 14/100
# 290/290 - 3s - loss: 0.0120 - 3s/epoch - 10ms/step
# Epoch 15/100
# 290/290 - 3s - loss: 0.0112 - 3s/epoch - 10ms/step
# Epoch 16/100
# 290/290 - 3s - loss: 0.0103 - 3s/epoch - 10ms/step
# Epoch 17/100
# 290/290 - 4s - loss: 0.0100 - 4s/epoch - 15ms/step
# Epoch 18/100
# 290/290 - 3s - loss: 0.0096 - 3s/epoch - 11ms/step
# Epoch 19/100
# 290/290 - 3s - loss: 0.0098 - 3s/epoch - 10ms/step
# Epoch 20/100
# 290/290 - 3s - loss: 0.0098 - 3s/epoch - 10ms/step
# Epoch 21/100
# 290/290 - 4s - loss: 0.0096 - 4s/epoch - 12ms/step
# Epoch 22/100
# 290/290 - 4s - loss: 0.0090 - 4s/epoch - 12ms/step
# Epoch 23/100
# 290/290 - 3s - loss: 0.0084 - 3s/epoch - 10ms/step
# Epoch 24/100
# 290/290 - 3s - loss: 0.0085 - 3s/epoch - 10ms/step
# Epoch 25/100
# 290/290 - 3s - loss: 0.0086 - 3s/epoch - 11ms/step
# Epoch 26/100
# 290/290 - 4s - loss: 0.0078 - 4s/epoch - 14ms/step
# Epoch 27/100
# 290/290 - 3s - loss: 0.0073 - 3s/epoch - 10ms/step
# Epoch 28/100
# 290/290 - 3s - loss: 0.0071 - 3s/epoch - 10ms/step
# Epoch 29/100
# 290/290 - 3s - loss: 0.0075 - 3s/epoch - 10ms/step
# Epoch 30/100
# 290/290 - 4s - loss: 0.0071 - 4s/epoch - 15ms/step
# Epoch 31/100
# 290/290 - 3s - loss: 0.0064 - 3s/epoch - 10ms/step
# Epoch 32/100
# 290/290 - 4s - loss: 0.0072 - 4s/epoch - 12ms/step
# Epoch 33/100
# 290/290 - 4s - loss: 0.0069 - 4s/epoch - 12ms/step
# Epoch 34/100
# 290/290 - 6s - loss: 0.0081 - 6s/epoch - 20ms/step
# Epoch 35/100
# 290/290 - 3s - loss: 0.0065 - 3s/epoch - 10ms/step
# Epoch 36/100
# 290/290 - 3s - loss: 0.0066 - 3s/epoch - 10ms/step
# Epoch 37/100
# 290/290 - 3s - loss: 0.0076 - 3s/epoch - 10ms/step
# Epoch 38/100
# 290/290 - 4s - loss: 0.0068 - 4s/epoch - 13ms/step
# Epoch 39/100
# 290/290 - 3s - loss: 0.0076 - 3s/epoch - 11ms/step
# Epoch 40/100
# 290/290 - 3s - loss: 0.0100 - 3s/epoch - 10ms/step
# Epoch 41/100
# 290/290 - 3s - loss: 0.0069 - 3s/epoch - 10ms/step
# Epoch 42/100
# 290/290 - 3s - loss: 0.0077 - 3s/epoch - 12ms/step
# Epoch 43/100
# 290/290 - 4s - loss: 0.0071 - 4s/epoch - 13ms/step
# Epoch 44/100
# 290/290 - 3s - loss: 0.0052 - 3s/epoch - 10ms/step
# Epoch 45/100
# 290/290 - 3s - loss: 0.0062 - 3s/epoch - 10ms/step
# Epoch 46/100
# 290/290 - 3s - loss: 0.0062 - 3s/epoch - 10ms/step
# Epoch 47/100
# 290/290 - 4s - loss: 0.0056 - 4s/epoch - 14ms/step
# Epoch 48/100
# 290/290 - 3s - loss: 0.0049 - 3s/epoch - 10ms/step
# Epoch 49/100
# 290/290 - 3s - loss: 0.0047 - 3s/epoch - 10ms/step
# Epoch 50/100
# 290/290 - 3s - loss: 0.0054 - 3s/epoch - 10ms/step
# Epoch 51/100
# 290/290 - 4s - loss: 0.0049 - 4s/epoch - 15ms/step
# Epoch 52/100
# 290/290 - 3s - loss: 0.0048 - 3s/epoch - 10ms/step
# Epoch 53/100
# 290/290 - 3s - loss: 0.0047 - 3s/epoch - 10ms/step
# Epoch 54/100
# 290/290 - 3s - loss: 0.0046 - 3s/epoch - 10ms/step
# Epoch 55/100
# 290/290 - 4s - loss: 0.0050 - 4s/epoch - 14ms/step
# Epoch 56/100
# 290/290 - 3s - loss: 0.0046 - 3s/epoch - 11ms/step
# Epoch 57/100
# 290/290 - 3s - loss: 0.0047 - 3s/epoch - 10ms/step
# Epoch 58/100
# 290/290 - 3s - loss: 0.0051 - 3s/epoch - 10ms/step
# Epoch 59/100
# 290/290 - 4s - loss: 0.0048 - 4s/epoch - 12ms/step
# Epoch 60/100
# 290/290 - 4s - loss: 0.0041 - 4s/epoch - 12ms/step
# Epoch 61/100
# 290/290 - 3s - loss: 0.0048 - 3s/epoch - 10ms/step
# Epoch 62/100
# 290/290 - 3s - loss: 0.0045 - 3s/epoch - 10ms/step
# Epoch 63/100
# 290/290 - 3s - loss: 0.0040 - 3s/epoch - 11ms/step
# Epoch 64/100
# 290/290 - 4s - loss: 0.0047 - 4s/epoch - 14ms/step
# Epoch 65/100
# 290/290 - 3s - loss: 0.0042 - 3s/epoch - 10ms/step
# Epoch 66/100
# 290/290 - 3s - loss: 0.0042 - 3s/epoch - 10ms/step
# Epoch 67/100
# 290/290 - 3s - loss: 0.0043 - 3s/epoch - 10ms/step
# Epoch 68/100
# 290/290 - 4s - loss: 0.0038 - 4s/epoch - 15ms/step
# Epoch 69/100
# 290/290 - 3s - loss: 0.0039 - 3s/epoch - 10ms/step
# Epoch 70/100
# 290/290 - 3s - loss: 0.0039 - 3s/epoch - 12ms/step
# Epoch 71/100
# 290/290 - 4s - loss: 0.0041 - 4s/epoch - 12ms/step
# Epoch 72/100
# 290/290 - 4s - loss: 0.0043 - 4s/epoch - 15ms/step
# Epoch 73/100
# 290/290 - 3s - loss: 0.0046 - 3s/epoch - 10ms/step
# Epoch 74/100
# 290/290 - 3s - loss: 0.0044 - 3s/epoch - 11ms/step
# Epoch 75/100
# 290/290 - 3s - loss: 0.0045 - 3s/epoch - 10ms/step
# Epoch 76/100
# 290/290 - 4s - loss: 0.0044 - 4s/epoch - 15ms/step
# Epoch 77/100
# 290/290 - 3s - loss: 0.0040 - 3s/epoch - 11ms/step
# Epoch 78/100
# 290/290 - 3s - loss: 0.0042 - 3s/epoch - 10ms/step
# Epoch 79/100
# 290/290 - 3s - loss: 0.0039 - 3s/epoch - 10ms/step
# Epoch 80/100
# 290/290 - 4s - loss: 0.0035 - 4s/epoch - 15ms/step
# Epoch 81/100
# 290/290 - 3s - loss: 0.0035 - 3s/epoch - 11ms/step
# Epoch 82/100
# 290/290 - 3s - loss: 0.0035 - 3s/epoch - 10ms/step
# Epoch 83/100
# 290/290 - 3s - loss: 0.0034 - 3s/epoch - 10ms/step
# Epoch 84/100
# 290/290 - 5s - loss: 0.0033 - 5s/epoch - 16ms/step
# Epoch 85/100
# 290/290 - 3s - loss: 0.0035 - 3s/epoch - 11ms/step
# Epoch 86/100
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 10ms/step
# Epoch 87/100
# 290/290 - 3s - loss: 0.0035 - 3s/epoch - 10ms/step
# Epoch 88/100
# 290/290 - 4s - loss: 0.0036 - 4s/epoch - 13ms/step
# Epoch 89/100
# 290/290 - 3s - loss: 0.0039 - 3s/epoch - 11ms/step
# Epoch 90/100
# 290/290 - 3s - loss: 0.0033 - 3s/epoch - 11ms/step
# Epoch 91/100
# 290/290 - 3s - loss: 0.0033 - 3s/epoch - 10ms/step
# Epoch 92/100
# 290/290 - 4s - loss: 0.0033 - 4s/epoch - 12ms/step
# Epoch 93/100
# 290/290 - 4s - loss: 0.0034 - 4s/epoch - 13ms/step
# Epoch 94/100
# 290/290 - 3s - loss: 0.0048 - 3s/epoch - 10ms/step
# Epoch 95/100
# 290/290 - 3s - loss: 0.0047 - 3s/epoch - 10ms/step
# Epoch 96/100
# 290/290 - 3s - loss: 0.0038 - 3s/epoch - 11ms/step
# Epoch 97/100
# 290/290 - 5s - loss: 0.0038 - 5s/epoch - 16ms/step
# Epoch 98/100
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 10ms/step
# Epoch 99/100
# 290/290 - 3s - loss: 0.0033 - 3s/epoch - 10ms/step
# Epoch 100/100
# 290/290 - 3s - loss: 0.0034 - 3s/epoch - 10ms/step
# 10/10 [==============================] - 0s 7ms/step
# Epoch 1/100
# 289/289 - 8s - loss: 0.3380 - 8s/epoch - 29ms/step
# Epoch 2/100
# 289/289 - 4s - loss: 0.0874 - 4s/epoch - 14ms/step
# Epoch 3/100
# 289/289 - 4s - loss: 0.0726 - 4s/epoch - 14ms/step
# Epoch 4/100
# 289/289 - 5s - loss: 0.0881 - 5s/epoch - 19ms/step
# Epoch 5/100
# 289/289 - 4s - loss: 0.0785 - 4s/epoch - 15ms/step
# Epoch 6/100
# 289/289 - 4s - loss: 0.1020 - 4s/epoch - 14ms/step
# Epoch 7/100
# 289/289 - 5s - loss: 0.0613 - 5s/epoch - 17ms/step
# Epoch 8/100
# 289/289 - 4s - loss: 0.0480 - 4s/epoch - 15ms/step
# Epoch 9/100
# 289/289 - 4s - loss: 0.0396 - 4s/epoch - 13ms/step
# Epoch 10/100
# 289/289 - 5s - loss: 0.0258 - 5s/epoch - 16ms/step
# Epoch 11/100
# 289/289 - 5s - loss: 0.0187 - 5s/epoch - 17ms/step
# Epoch 12/100
# 289/289 - 4s - loss: 0.0224 - 4s/epoch - 15ms/step
# Epoch 13/100
# 289/289 - 5s - loss: 0.0196 - 5s/epoch - 17ms/step
# Epoch 14/100
# 289/289 - 5s - loss: 0.0140 - 5s/epoch - 16ms/step
# Epoch 15/100
# 289/289 - 4s - loss: 0.0147 - 4s/epoch - 13ms/step
# Epoch 16/100
# 289/289 - 5s - loss: 0.0125 - 5s/epoch - 16ms/step
# Epoch 17/100
# 289/289 - 5s - loss: 0.0101 - 5s/epoch - 16ms/step
# Epoch 18/100
# 289/289 - 4s - loss: 0.0091 - 4s/epoch - 14ms/step
# Epoch 19/100
# 289/289 - 4s - loss: 0.0076 - 4s/epoch - 15ms/step
# Epoch 20/100
# 289/289 - 5s - loss: 0.0069 - 5s/epoch - 18ms/step
# Epoch 21/100
# 289/289 - 4s - loss: 0.0078 - 4s/epoch - 14ms/step
# Epoch 22/100
# 289/289 - 5s - loss: 0.0071 - 5s/epoch - 16ms/step
# Epoch 23/100
# 289/289 - 5s - loss: 0.0059 - 5s/epoch - 18ms/step
# Epoch 24/100
# 289/289 - 4s - loss: 0.0073 - 4s/epoch - 13ms/step
# Epoch 25/100
# 289/289 - 4s - loss: 0.0052 - 4s/epoch - 13ms/step
# Epoch 26/100
# 289/289 - 6s - loss: 0.0064 - 6s/epoch - 19ms/step
# Epoch 27/100
# 289/289 - 4s - loss: 0.0055 - 4s/epoch - 15ms/step
# Epoch 28/100
# 289/289 - 4s - loss: 0.0053 - 4s/epoch - 14ms/step
# Epoch 29/100
# 289/289 - 5s - loss: 0.0050 - 5s/epoch - 19ms/step
# Epoch 30/100
# 289/289 - 4s - loss: 0.0053 - 4s/epoch - 15ms/step
# Epoch 31/100
# 289/289 - 4s - loss: 0.0050 - 4s/epoch - 13ms/step
# Epoch 32/100
# 289/289 - 5s - loss: 0.0062 - 5s/epoch - 18ms/step
# Epoch 33/100
# 289/289 - 5s - loss: 0.0062 - 5s/epoch - 16ms/step
# Epoch 34/100
# 289/289 - 4s - loss: 0.0049 - 4s/epoch - 14ms/step
# Epoch 35/100
# 289/289 - 6s - loss: 0.0056 - 6s/epoch - 20ms/step
# Epoch 36/100
# 289/289 - 5s - loss: 0.0074 - 5s/epoch - 16ms/step
# Epoch 37/100
# 289/289 - 4s - loss: 0.0071 - 4s/epoch - 14ms/step
# Epoch 38/100
# 289/289 - 6s - loss: 0.0067 - 6s/epoch - 20ms/step
# Epoch 39/100
# 289/289 - 4s - loss: 0.0074 - 4s/epoch - 15ms/step
# Epoch 40/100
# 289/289 - 4s - loss: 0.0075 - 4s/epoch - 14ms/step
# Epoch 41/100
# 289/289 - 5s - loss: 0.0089 - 5s/epoch - 17ms/step
# Epoch 42/100
# 289/289 - 4s - loss: 0.0062 - 4s/epoch - 14ms/step
# Epoch 43/100
# 289/289 - 4s - loss: 0.0058 - 4s/epoch - 15ms/step
# Epoch 44/100
# 289/289 - 5s - loss: 0.0050 - 5s/epoch - 18ms/step
# Epoch 45/100
# 289/289 - 4s - loss: 0.0051 - 4s/epoch - 14ms/step
# Epoch 46/100
# 289/289 - 4s - loss: 0.0048 - 4s/epoch - 14ms/step
# Epoch 47/100
# 289/289 - 6s - loss: 0.0046 - 6s/epoch - 19ms/step
# Epoch 48/100
# 289/289 - 4s - loss: 0.0047 - 4s/epoch - 14ms/step
# Epoch 49/100
# 289/289 - 4s - loss: 0.0050 - 4s/epoch - 13ms/step
# Epoch 50/100
# 289/289 - 5s - loss: 0.0049 - 5s/epoch - 18ms/step
# Epoch 51/100
# 289/289 - 4s - loss: 0.0047 - 4s/epoch - 15ms/step
# Epoch 52/100
# 289/289 - 4s - loss: 0.0066 - 4s/epoch - 14ms/step
# Epoch 53/100
# 289/289 - 5s - loss: 0.0061 - 5s/epoch - 19ms/step
# Epoch 54/100
# 289/289 - 4s - loss: 0.0053 - 4s/epoch - 14ms/step
# Epoch 55/100
# 289/289 - 4s - loss: 0.0055 - 4s/epoch - 14ms/step
# Epoch 56/100
# 289/289 - 5s - loss: 0.0067 - 5s/epoch - 19ms/step
# Epoch 57/100
# 289/289 - 4s - loss: 0.0050 - 4s/epoch - 14ms/step
# Epoch 58/100
# 289/289 - 4s - loss: 0.0044 - 4s/epoch - 15ms/step
# Epoch 59/100
# 289/289 - 5s - loss: 0.0037 - 5s/epoch - 19ms/step
# Epoch 60/100
# 289/289 - 4s - loss: 0.0038 - 4s/epoch - 15ms/step
# Epoch 61/100
# 289/289 - 4s - loss: 0.0035 - 4s/epoch - 13ms/step
# Epoch 62/100
# 289/289 - 6s - loss: 0.0032 - 6s/epoch - 20ms/step
# Epoch 63/100
# 289/289 - 4s - loss: 0.0034 - 4s/epoch - 13ms/step
# Epoch 64/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 15ms/step
# Epoch 65/100
# 289/289 - 6s - loss: 0.0037 - 6s/epoch - 20ms/step
# Epoch 66/100
# 289/289 - 4s - loss: 0.0039 - 4s/epoch - 14ms/step
# Epoch 67/100
# 289/289 - 4s - loss: 0.0034 - 4s/epoch - 15ms/step
# Epoch 68/100
# 289/289 - 5s - loss: 0.0034 - 5s/epoch - 19ms/step
# Epoch 69/100
# 289/289 - 4s - loss: 0.0033 - 4s/epoch - 14ms/step
# Epoch 70/100
# 289/289 - 5s - loss: 0.0033 - 5s/epoch - 17ms/step
# Epoch 71/100
# 289/289 - 6s - loss: 0.0035 - 6s/epoch - 19ms/step
# Epoch 72/100
# 289/289 - 4s - loss: 0.0036 - 4s/epoch - 15ms/step
# Epoch 73/100
# 289/289 - 6s - loss: 0.0033 - 6s/epoch - 22ms/step
# Epoch 74/100
# 289/289 - 6s - loss: 0.0036 - 6s/epoch - 20ms/step
# Epoch 75/100
# 289/289 - 4s - loss: 0.0036 - 4s/epoch - 14ms/step
# Epoch 76/100
# 289/289 - 5s - loss: 0.0031 - 5s/epoch - 17ms/step
# Epoch 77/100
# 289/289 - 5s - loss: 0.0029 - 5s/epoch - 18ms/step
# Epoch 78/100
# 289/289 - 4s - loss: 0.0030 - 4s/epoch - 14ms/step
# Epoch 79/100
# 289/289 - 5s - loss: 0.0031 - 5s/epoch - 16ms/step
# Epoch 80/100
# 289/289 - 5s - loss: 0.0039 - 5s/epoch - 17ms/step
# Epoch 81/100
# 289/289 - 4s - loss: 0.0046 - 4s/epoch - 14ms/step
# Epoch 82/100
# 289/289 - 4s - loss: 0.0048 - 4s/epoch - 15ms/step
# Epoch 83/100
# 289/289 - 5s - loss: 0.0057 - 5s/epoch - 18ms/step
# Epoch 84/100
# 289/289 - 4s - loss: 0.0040 - 4s/epoch - 13ms/step
# Epoch 85/100
# 289/289 - 4s - loss: 0.0038 - 4s/epoch - 15ms/step
# Epoch 86/100
# 289/289 - 5s - loss: 0.0034 - 5s/epoch - 18ms/step
# Epoch 87/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 14ms/step
# Epoch 88/100
# 289/289 - 4s - loss: 0.0034 - 4s/epoch - 15ms/step
# Epoch 89/100
# 289/289 - 5s - loss: 0.0032 - 5s/epoch - 18ms/step
# Epoch 90/100
# 289/289 - 4s - loss: 0.0038 - 4s/epoch - 13ms/step
# Epoch 91/100
# 289/289 - 4s - loss: 0.0030 - 4s/epoch - 13ms/step
# Epoch 92/100
# 289/289 - 5s - loss: 0.0034 - 5s/epoch - 18ms/step
# Epoch 93/100
# 289/289 - 4s - loss: 0.0036 - 4s/epoch - 15ms/step
# Epoch 94/100
# 289/289 - 4s - loss: 0.0042 - 4s/epoch - 14ms/step
# Epoch 95/100
# 289/289 - 5s - loss: 0.0042 - 5s/epoch - 19ms/step
# Epoch 96/100
# 289/289 - 4s - loss: 0.0038 - 4s/epoch - 14ms/step
# Epoch 97/100
# 289/289 - 4s - loss: 0.0030 - 4s/epoch - 14ms/step
# Epoch 98/100
# 289/289 - 5s - loss: 0.0027 - 5s/epoch - 19ms/step
# Epoch 99/100
# 289/289 - 4s - loss: 0.0028 - 4s/epoch - 14ms/step
# Epoch 100/100
# 289/289 - 4s - loss: 0.0027 - 4s/epoch - 15ms/step
# 9/9 [==============================] - 0s 8ms/step

# %%
for result in results:
    print(f"n_steps: {result[0]}, RMSE: {result[1]}, MAPE: {result[2]}")
# Out:
# n_steps: 2, RMSE: 0.04428142026315253, MAPE: 0.7293058392038275
# n_steps: 6, RMSE: 0.03618091172315377, MAPE: 0.6926885308480597
# n_steps: 13, RMSE: 0.03663132171236444, MAPE: 0.6230138436159506
# n_steps: 20, RMSE: 0.031910075812609136, MAPE: 0.5913377672088647

# %%
plt.figure(figsize=(10, 5))
plt.plot([result[0] for result in results], [result[1] for result in results], marker='o', label='RMSE')
plt.plot([result[0] for result in results], [result[2] for result in results], marker='o', label='MAPE')
plt.xlabel('n_steps')
plt.ylabel('Error')
plt.title('Error vs. n_steps')
plt.legend()
plt.show()

# %% [markdown]
# The result shows that n_steps = n will reach the most accurate prediction, means that predicting the n+1th days is the best choice

# %% [markdown]
# #### 3.2.5 Cross Validation

# %%
# n_steps = 6
# X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

# %%
# tscv = TimeSeriesSplit(n_splits=5)
# rmse_scores = []
# mape_scores = []

# for train_index, test_index in tscv.split(X1):
#     X_train, X_test = X1[train_index], X1[test_index]
#     y_train, y_test = y1[train_index], y1[test_index]

#     # Define the model
#     model = Sequential()
#     model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
#     model.add(LSTM(50, activation='relu'))
#     model.add(Dense(1))
#     model.compile(loss='mean_squared_error', optimizer='adam')

#     # Train the model
#     model.fit(X_train, y_train, epochs=100, batch_size=4, verbose=0, shuffle=False)

#     # Predict
#     y_pred = model.predict(X_test)
#     y_pred = y_pred[:, 0]

#     # Calculate RMSE and MAPE
#     rmse = mean_squared_error(y_test, y_pred, squared=False)
#     mape = mean_absolute_percentage_error(y_test, y_pred)

#     rmse_scores.append(rmse)
#     mape_scores.append(mape)

# print(f"Average RMSE: {np.mean(rmse_scores)}, Average MAPE: {np.mean(mape_scores)}")

# %% [markdown]
# ###3.3 Run Saved Model

# %%
# Load the SavedModel
model = load_model('predict_link.h5')
sc = joblib.load('standard_scaler.pkl')

# %%
def prepare_input_data(ticker, end_date, n_steps):
    stock_data = yf.download(ticker, end=end_date)
    X_feat = stock_data[['Open', 'High', 'Low']]
    target_y = stock_data['Close']

    X_ft = sc.fit_transform(X_feat.values)
    stock_data_ft = pd.DataFrame(columns=X_feat.columns, data=X_ft, index=X_feat.index)
    stock_data_ft['Close'] = target_y.values

    input_data = stock_data_ft.values[-n_steps:, :-1]
    input_data = np.expand_dims(input_data, axis=0)

    return input_data, stock_data_ft.index[-1]

# %%
# Parameter prediksi
ticker = 'LINK-USD'
end_date = '2024-05-29'
n_steps = 20

# Menyiapkan data input
input_data, last_date = prepare_input_data(ticker, end_date, n_steps)

# Melakukan prediksi
predicted_price_scaled = model.predict(input_data).flatten()[0]

# Mengembalikan hasil prediksi ke skala semula
predicted_price = sc.inverse_transform([[np.nan, predicted_price_scaled, np.nan]])[0][1]

# Menampilkan hasil prediksi
print(f"Harga saham {ticker} yang diprediksi untuk tanggal {end_date} adalah: {predicted_price:.2f}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 23ms/step
# Harga saham LINK-USD yang diprediksi untuk tanggal 2024-05-29 adalah: 18.15
