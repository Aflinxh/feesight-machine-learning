# %% [markdown]
# #Try Stock Prediction - NETFLIX

# %%
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import datetime as dt
import joblib
import yfinance as yf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 1. Read Data

# %%
# stock_data = pd.read_csv('/content/NFLX.csv', index_col='Date')
# stock_data

ticker = 'NEAR-USD'
# start_date = '2020-05-20'
# end_date = pd.Timestamp.now().strftime('%Y-%m-%d')
start_date = '2020-05-21'
end_date = '2024-05-21'
stock_data = yf.download(ticker, start=start_date, end=end_date)
stock_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2020-10-14  1.694560  1.694560  1.064818  1.185806   1.185806   94692273
# 2020-10-15  1.177929  1.249225  1.088780  1.125557   1.125557   34933419
# 2020-10-16  1.124601  1.151711  0.814550  0.817511   0.817511   37020875
# 2020-10-17  0.817511  0.853755  0.727224  0.808136   0.808136   23630173
# 2020-10-18  0.809037  0.873260  0.802059  0.871674   0.871674   14376473
# ...              ...       ...       ...       ...        ...        ...
# 2024-05-16  8.048687  8.290097  7.863945  8.012919   8.012919  687325863
# 2024-05-17  8.012919  8.507907  7.919199  8.036335   8.036335  694120548
# 2024-05-18  8.036335  8.088616  7.831680  7.925786   7.925786  323273190
# 2024-05-19  7.925802  7.990855  7.679978  7.781747   7.781747  339064307
# 2024-05-20  7.781747  8.315604  7.718782  8.281798   8.281798  710606433
#
# [1315 rows x 6 columns]

# %% [markdown]
# ## 2. Plotting Data

# %% [markdown]
# ### 2.1 Plot High & Low

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
# x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]
x_dates = stock_data.index

plt.plot(x_dates, stock_data['High'], label='High')
plt.plot(x_dates, stock_data['Low'], label='Low')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ### 2.2 Plot Open & Close

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
# x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]
x_dates = stock_data.index

plt.plot(x_dates, stock_data['Open'], label='Open')
plt.plot(x_dates, stock_data['Close'], label='Close')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ## 3. Stock Prediction

# %% [markdown]
# ### 3.1 Normalize or Rescale

# %%
features = stock_data.iloc[:, 0:4]
sc = StandardScaler()
features_scaled = sc.fit_transform(features.values)
stock_data_ft = pd.DataFrame(columns=features.columns, data=features_scaled, index=features.index)

# Simpan objek StandardScaler
joblib.dump(sc, 'standard_scaler.pkl')
# Out:
# ['standard_scaler.pkl']

# %% [markdown]
# ### 3.2 Train & Test

# %% [markdown]
# #### 3.2.1 Splitting

# %%
def lstm_split(data, n_steps):
  X, y = [], []
  for i in range(len(data) - n_steps):
    X.append(data[i:i + n_steps, :-1])
    y.append(data[i + n_steps-1, -1])

  return np.array(X), np.array(y)

# %%
n_steps = 13
X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

train_split = 0.8
split_idx = int(np.ceil(len(X1)*train_split))
date_index = stock_data_ft.index

X_train, X_test = X1[:split_idx], X1[split_idx:]
y_train, y_test = y1[:split_idx], y1[split_idx:]
X_train_date, X_test_date = date_index[n_steps-1:split_idx + n_steps-1], date_index[split_idx + n_steps-1:len(X1) + n_steps-1]

print(X1.shape, X_train.shape, X_test.shape, y_test.shape)
# Out:
# (1302, 13, 3) (1042, 13, 3) (260, 13, 3) (260,)

# %% [markdown]
# #### 3.2.2 Training

# %%
lstm = Sequential()
lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
lstm.add(LSTM(50, activation="relu"))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error', optimizer='adam')
lstm.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 13, 50)            10800
#
#  lstm_13 (LSTM)              (None, 50)                20200
#
#  dense_6 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 31051 (121.29 KB)
# Trainable params: 31051 (121.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = lstm.fit(X_train, y_train, epochs=150, batch_size=4, verbose=2, shuffle=False)
# Out:
# Epoch 1/150
# 261/261 - 7s - loss: 0.2587 - 7s/epoch - 26ms/step
# Epoch 2/150
# 261/261 - 3s - loss: 0.0821 - 3s/epoch - 13ms/step
# Epoch 3/150
# 261/261 - 3s - loss: 0.0471 - 3s/epoch - 11ms/step
# Epoch 4/150
# 261/261 - 3s - loss: 0.0584 - 3s/epoch - 11ms/step
# Epoch 5/150
# 261/261 - 3s - loss: 0.0415 - 3s/epoch - 12ms/step
# Epoch 6/150
# 261/261 - 4s - loss: 0.0222 - 4s/epoch - 15ms/step
# Epoch 7/150
# 261/261 - 3s - loss: 0.0284 - 3s/epoch - 12ms/step
# Epoch 8/150
# 261/261 - 3s - loss: 0.0161 - 3s/epoch - 11ms/step
# Epoch 9/150
# 261/261 - 3s - loss: 0.0169 - 3s/epoch - 11ms/step
# Epoch 10/150
# 261/261 - 4s - loss: 0.0192 - 4s/epoch - 17ms/step
# Epoch 11/150
# 261/261 - 3s - loss: 0.0158 - 3s/epoch - 12ms/step
# Epoch 12/150
# 261/261 - 3s - loss: 0.0127 - 3s/epoch - 11ms/step
# Epoch 13/150
# 261/261 - 3s - loss: 0.0127 - 3s/epoch - 11ms/step
# Epoch 14/150
# 261/261 - 4s - loss: 0.0131 - 4s/epoch - 14ms/step
# Epoch 15/150
# 261/261 - 4s - loss: 0.0117 - 4s/epoch - 14ms/step
# Epoch 16/150
# 261/261 - 3s - loss: 0.0142 - 3s/epoch - 11ms/step
# Epoch 17/150
# 261/261 - 3s - loss: 0.0155 - 3s/epoch - 11ms/step
# Epoch 18/150
# 261/261 - 3s - loss: 0.0142 - 3s/epoch - 11ms/step
# Epoch 19/150
# 261/261 - 4s - loss: 0.0106 - 4s/epoch - 17ms/step
# Epoch 20/150
# 261/261 - 3s - loss: 0.0106 - 3s/epoch - 11ms/step
# Epoch 21/150
# 261/261 - 3s - loss: 0.0079 - 3s/epoch - 11ms/step
# Epoch 22/150
# 261/261 - 3s - loss: 0.0069 - 3s/epoch - 11ms/step
# Epoch 23/150
# 261/261 - 4s - loss: 0.0076 - 4s/epoch - 13ms/step
# Epoch 24/150
# 261/261 - 3s - loss: 0.0118 - 3s/epoch - 13ms/step
# Epoch 25/150
# 261/261 - 3s - loss: 0.0130 - 3s/epoch - 11ms/step
# Epoch 26/150
# 261/261 - 3s - loss: 0.0112 - 3s/epoch - 10ms/step
# Epoch 27/150
# 261/261 - 3s - loss: 0.0083 - 3s/epoch - 10ms/step
# Epoch 28/150
# 261/261 - 4s - loss: 0.0060 - 4s/epoch - 15ms/step
# Epoch 29/150
# 261/261 - 3s - loss: 0.0055 - 3s/epoch - 11ms/step
# Epoch 30/150
# 261/261 - 3s - loss: 0.0060 - 3s/epoch - 11ms/step
# Epoch 31/150
# 261/261 - 3s - loss: 0.0095 - 3s/epoch - 13ms/step
# Epoch 32/150
# 261/261 - 4s - loss: 0.0132 - 4s/epoch - 14ms/step
# Epoch 33/150
# 261/261 - 3s - loss: 0.0103 - 3s/epoch - 13ms/step
# Epoch 34/150
# 261/261 - 3s - loss: 0.0071 - 3s/epoch - 11ms/step
# Epoch 35/150
# 261/261 - 3s - loss: 0.0057 - 3s/epoch - 11ms/step
# Epoch 36/150
# 261/261 - 3s - loss: 0.0054 - 3s/epoch - 11ms/step
# Epoch 37/150
# 261/261 - 4s - loss: 0.0048 - 4s/epoch - 15ms/step
# Epoch 38/150
# 261/261 - 3s - loss: 0.0063 - 3s/epoch - 11ms/step
# Epoch 39/150
# 261/261 - 3s - loss: 0.0086 - 3s/epoch - 11ms/step
# Epoch 40/150
# 261/261 - 3s - loss: 0.0090 - 3s/epoch - 11ms/step
# Epoch 41/150
# 261/261 - 4s - loss: 0.0070 - 4s/epoch - 15ms/step
# Epoch 42/150
# 261/261 - 3s - loss: 0.0051 - 3s/epoch - 12ms/step
# Epoch 43/150
# 261/261 - 3s - loss: 0.0067 - 3s/epoch - 11ms/step
# Epoch 44/150
# 261/261 - 3s - loss: 0.0081 - 3s/epoch - 11ms/step
# Epoch 45/150
# 261/261 - 3s - loss: 0.0049 - 3s/epoch - 11ms/step
# Epoch 46/150
# 261/261 - 4s - loss: 0.0090 - 4s/epoch - 16ms/step
# Epoch 47/150
# 261/261 - 3s - loss: 0.0068 - 3s/epoch - 11ms/step
# Epoch 48/150
# 261/261 - 3s - loss: 0.0067 - 3s/epoch - 11ms/step
# Epoch 49/150
# 261/261 - 3s - loss: 0.0045 - 3s/epoch - 11ms/step
# Epoch 50/150
# 261/261 - 4s - loss: 0.0044 - 4s/epoch - 14ms/step
# Epoch 51/150
# 261/261 - 3s - loss: 0.0042 - 3s/epoch - 13ms/step
# Epoch 52/150
# 261/261 - 3s - loss: 0.0041 - 3s/epoch - 11ms/step
# Epoch 53/150
# 261/261 - 3s - loss: 0.0061 - 3s/epoch - 11ms/step
# Epoch 54/150
# 261/261 - 3s - loss: 0.0084 - 3s/epoch - 12ms/step
# Epoch 55/150
# 261/261 - 4s - loss: 0.0081 - 4s/epoch - 16ms/step
# Epoch 56/150
# 261/261 - 3s - loss: 0.0064 - 3s/epoch - 11ms/step
# Epoch 57/150
# 261/261 - 3s - loss: 0.0053 - 3s/epoch - 11ms/step
# Epoch 58/150
# 261/261 - 3s - loss: 0.0045 - 3s/epoch - 11ms/step
# Epoch 59/150
# 261/261 - 4s - loss: 0.0042 - 4s/epoch - 15ms/step
# Epoch 60/150
# 261/261 - 3s - loss: 0.0051 - 3s/epoch - 13ms/step
# Epoch 61/150
# 261/261 - 3s - loss: 0.0043 - 3s/epoch - 11ms/step
# Epoch 62/150
# 261/261 - 3s - loss: 0.0038 - 3s/epoch - 11ms/step
# Epoch 63/150
# 261/261 - 3s - loss: 0.0037 - 3s/epoch - 13ms/step
# Epoch 64/150
# 261/261 - 4s - loss: 0.0038 - 4s/epoch - 15ms/step
# Epoch 65/150
# 261/261 - 3s - loss: 0.0045 - 3s/epoch - 11ms/step
# Epoch 66/150
# 261/261 - 3s - loss: 0.0066 - 3s/epoch - 11ms/step
# Epoch 67/150
# 261/261 - 3s - loss: 0.0092 - 3s/epoch - 11ms/step
# Epoch 68/150
# 261/261 - 4s - loss: 0.0067 - 4s/epoch - 15ms/step
# Epoch 69/150
# 261/261 - 3s - loss: 0.0039 - 3s/epoch - 13ms/step
# Epoch 70/150
# 261/261 - 3s - loss: 0.0041 - 3s/epoch - 11ms/step
# Epoch 71/150
# 261/261 - 3s - loss: 0.0041 - 3s/epoch - 11ms/step
# Epoch 72/150
# 261/261 - 3s - loss: 0.0034 - 3s/epoch - 13ms/step
# Epoch 73/150
# 261/261 - 4s - loss: 0.0033 - 4s/epoch - 15ms/step
# Epoch 74/150
# 261/261 - 3s - loss: 0.0035 - 3s/epoch - 11ms/step
# Epoch 75/150
# 261/261 - 3s - loss: 0.0040 - 3s/epoch - 11ms/step
# Epoch 76/150
# 261/261 - 3s - loss: 0.0049 - 3s/epoch - 11ms/step
# Epoch 77/150
# 261/261 - 4s - loss: 0.0079 - 4s/epoch - 16ms/step
# Epoch 78/150
# 261/261 - 3s - loss: 0.0066 - 3s/epoch - 11ms/step
# Epoch 79/150
# 261/261 - 3s - loss: 0.0035 - 3s/epoch - 11ms/step
# Epoch 80/150
# 261/261 - 3s - loss: 0.0034 - 3s/epoch - 11ms/step
# Epoch 81/150
# 261/261 - 4s - loss: 0.0035 - 4s/epoch - 16ms/step
# Epoch 82/150
# 261/261 - 3s - loss: 0.0036 - 3s/epoch - 12ms/step
# Epoch 83/150
# 261/261 - 3s - loss: 0.0033 - 3s/epoch - 11ms/step
# Epoch 84/150
# 261/261 - 3s - loss: 0.0033 - 3s/epoch - 11ms/step
# Epoch 85/150
# 261/261 - 3s - loss: 0.0038 - 3s/epoch - 13ms/step
# Epoch 86/150
# 261/261 - 4s - loss: 0.0048 - 4s/epoch - 15ms/step
# Epoch 87/150
# 261/261 - 3s - loss: 0.0070 - 3s/epoch - 11ms/step
# Epoch 88/150
# 261/261 - 3s - loss: 0.0065 - 3s/epoch - 11ms/step
# Epoch 89/150
# 261/261 - 3s - loss: 0.0039 - 3s/epoch - 11ms/step
# Epoch 90/150
# 261/261 - 4s - loss: 0.0042 - 4s/epoch - 16ms/step
# Epoch 91/150
# 261/261 - 3s - loss: 0.0041 - 3s/epoch - 12ms/step
# Epoch 92/150
# 261/261 - 3s - loss: 0.0033 - 3s/epoch - 11ms/step
# Epoch 93/150
# 261/261 - 3s - loss: 0.0033 - 3s/epoch - 11ms/step
# Epoch 94/150
# 261/261 - 4s - loss: 0.0033 - 4s/epoch - 14ms/step
# Epoch 95/150
# 261/261 - 4s - loss: 0.0034 - 4s/epoch - 14ms/step
# Epoch 96/150
# 261/261 - 3s - loss: 0.0035 - 3s/epoch - 12ms/step
# Epoch 97/150
# 261/261 - 3s - loss: 0.0034 - 3s/epoch - 11ms/step
# Epoch 98/150
# 261/261 - 3s - loss: 0.0033 - 3s/epoch - 12ms/step
# Epoch 99/150
# 261/261 - 4s - loss: 0.0032 - 4s/epoch - 15ms/step
# Epoch 100/150
# 261/261 - 3s - loss: 0.0032 - 3s/epoch - 11ms/step
# Epoch 101/150
# 261/261 - 3s - loss: 0.0032 - 3s/epoch - 11ms/step
# Epoch 102/150
# 261/261 - 3s - loss: 0.0038 - 3s/epoch - 11ms/step
# Epoch 103/150
# 261/261 - 4s - loss: 0.0055 - 4s/epoch - 15ms/step
# Epoch 104/150
# 261/261 - 3s - loss: 0.0052 - 3s/epoch - 12ms/step
# Epoch 105/150
# 261/261 - 3s - loss: 0.0045 - 3s/epoch - 11ms/step
# Epoch 106/150
# 261/261 - 3s - loss: 0.0035 - 3s/epoch - 11ms/step
# Epoch 107/150
# 261/261 - 3s - loss: 0.0035 - 3s/epoch - 13ms/step
# Epoch 108/150
# 261/261 - 4s - loss: 0.0031 - 4s/epoch - 14ms/step
# Epoch 109/150
# 261/261 - 3s - loss: 0.0032 - 3s/epoch - 11ms/step
# Epoch 110/150
# 261/261 - 3s - loss: 0.0031 - 3s/epoch - 11ms/step
# Epoch 111/150
# 261/261 - 3s - loss: 0.0030 - 3s/epoch - 11ms/step
# Epoch 112/150
# 261/261 - 4s - loss: 0.0031 - 4s/epoch - 16ms/step
# Epoch 113/150
# 261/261 - 3s - loss: 0.0030 - 3s/epoch - 11ms/step
# Epoch 114/150
# 261/261 - 3s - loss: 0.0029 - 3s/epoch - 12ms/step
# Epoch 115/150
# 261/261 - 3s - loss: 0.0030 - 3s/epoch - 11ms/step
# Epoch 116/150
# 261/261 - 4s - loss: 0.0031 - 4s/epoch - 14ms/step
# Epoch 117/150
# 261/261 - 3s - loss: 0.0030 - 3s/epoch - 13ms/step
# Epoch 118/150
# 261/261 - 3s - loss: 0.0027 - 3s/epoch - 11ms/step
# Epoch 119/150
# 261/261 - 3s - loss: 0.0026 - 3s/epoch - 11ms/step
# Epoch 120/150
# 261/261 - 3s - loss: 0.0165 - 3s/epoch - 11ms/step
# Epoch 121/150
# 261/261 - 4s - loss: 0.0068 - 4s/epoch - 16ms/step
# Epoch 122/150
# 261/261 - 3s - loss: 0.0048 - 3s/epoch - 11ms/step
# Epoch 123/150
# 261/261 - 3s - loss: 0.0039 - 3s/epoch - 11ms/step
# Epoch 124/150
# 261/261 - 3s - loss: 0.0039 - 3s/epoch - 11ms/step
# Epoch 125/150
# 261/261 - 4s - loss: 0.0036 - 4s/epoch - 14ms/step
# Epoch 126/150
# 261/261 - 3s - loss: 0.0034 - 3s/epoch - 13ms/step
# Epoch 127/150
# 261/261 - 3s - loss: 0.0034 - 3s/epoch - 11ms/step
# Epoch 128/150
# 261/261 - 3s - loss: 0.0033 - 3s/epoch - 11ms/step
# Epoch 129/150
# 261/261 - 3s - loss: 0.0032 - 3s/epoch - 12ms/step
# Epoch 130/150
# 261/261 - 4s - loss: 0.0031 - 4s/epoch - 16ms/step
# Epoch 131/150
# 261/261 - 3s - loss: 0.0031 - 3s/epoch - 11ms/step
# Epoch 132/150
# 261/261 - 3s - loss: 0.0031 - 3s/epoch - 11ms/step
# Epoch 133/150
# 261/261 - 3s - loss: 0.0030 - 3s/epoch - 11ms/step
# Epoch 134/150
# 261/261 - 4s - loss: 0.0030 - 4s/epoch - 15ms/step
# Epoch 135/150
# 261/261 - 3s - loss: 0.0030 - 3s/epoch - 12ms/step
# Epoch 136/150
# 261/261 - 3s - loss: 0.0030 - 3s/epoch - 11ms/step
# Epoch 137/150
# 261/261 - 3s - loss: 0.0030 - 3s/epoch - 11ms/step
# Epoch 138/150
# 261/261 - 3s - loss: 0.0030 - 3s/epoch - 11ms/step
# Epoch 139/150
# 261/261 - 4s - loss: 0.0029 - 4s/epoch - 16ms/step
# Epoch 140/150
# 261/261 - 3s - loss: 0.0028 - 3s/epoch - 11ms/step
# Epoch 141/150
# 261/261 - 3s - loss: 0.0028 - 3s/epoch - 11ms/step
# Epoch 142/150
# 261/261 - 3s - loss: 0.0028 - 3s/epoch - 11ms/step
# Epoch 143/150
# 261/261 - 4s - loss: 0.0029 - 4s/epoch - 14ms/step
# Epoch 144/150
# 261/261 - 3s - loss: 0.0032 - 3s/epoch - 13ms/step
# Epoch 145/150
# 261/261 - 3s - loss: 0.0035 - 3s/epoch - 10ms/step
# Epoch 146/150
# 261/261 - 3s - loss: 0.0038 - 3s/epoch - 11ms/step
# Epoch 147/150
# 261/261 - 3s - loss: 0.0036 - 3s/epoch - 11ms/step
# Epoch 148/150
# 261/261 - 4s - loss: 0.0031 - 4s/epoch - 16ms/step
# Epoch 149/150
# 261/261 - 3s - loss: 0.0032 - 3s/epoch - 11ms/step
# Epoch 150/150
# 261/261 - 3s - loss: 0.0034 - 3s/epoch - 11ms/step

# %%
plt.plot(history.history['loss'])
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# #### 3.2.3 Evaluation

# %%
# Make predictions
y_pred = lstm.predict(X_test)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(X_test_date, y_test, label='True Values', color='blue')
plt.plot(X_test_date, y_pred, label='Predicted Values', color='red')
plt.title('True Values vs Predicted Values')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 9/9 [==============================] - 0s 5ms/step

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
mape = mean_absolute_percentage_error(y_test, y_pred)
print("RMSE: ", rmse)
print("MAPE: ", mape)
# Out:
# RMSE:  0.03558674354743869
# MAPE:  0.07740853944931242

# %%
# Save Model
lstm.save("predict_near.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# #### 3.2.4 Compare Performance

# %%
n_steps_list = [2, 6, 13, 20]
results = []
models = []

for n_steps in n_steps_list:
    X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

    split_idx = int(np.ceil(len(X1) * 0.8))
    X_train, X_test = X1[:split_idx], X1[split_idx:]
    y_train, y_test = y1[:split_idx], y1[split_idx:]

    lstm = Sequential()
    lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
    lstm.add(LSTM(50, activation='relu'))
    lstm.add(Dense(1))
    lstm.compile(loss='mean_squared_error', optimizer='adam')

    lstm.fit(X_train, y_train, epochs=100, batch_size=4, verbose=2, shuffle=False)

    y_pred = lstm.predict(X_test)
    y_pred = y_pred.flatten()  # Ensure y_pred is a 1D array

    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mape = mean_absolute_percentage_error(y_test, y_pred)

    results.append((n_steps, rmse, mape))
    models.append(lstm)
# Out:
# Epoch 1/100
# 263/263 - 4s - loss: 0.2310 - 4s/epoch - 14ms/step
# Epoch 2/100
# 263/263 - 1s - loss: 0.0505 - 1s/epoch - 4ms/step
# Epoch 3/100
# 263/263 - 1s - loss: 0.0382 - 1s/epoch - 5ms/step
# Epoch 4/100
# 263/263 - 2s - loss: 0.0175 - 2s/epoch - 6ms/step
# Epoch 5/100
# 263/263 - 2s - loss: 0.0212 - 2s/epoch - 6ms/step
# Epoch 6/100
# 263/263 - 1s - loss: 0.0252 - 992ms/epoch - 4ms/step
# Epoch 7/100
# 263/263 - 1s - loss: 0.0226 - 996ms/epoch - 4ms/step
# Epoch 8/100
# 263/263 - 1s - loss: 0.0193 - 974ms/epoch - 4ms/step
# Epoch 9/100
# 263/263 - 1s - loss: 0.0204 - 995ms/epoch - 4ms/step
# Epoch 10/100
# 263/263 - 1s - loss: 0.0188 - 1s/epoch - 4ms/step
# Epoch 11/100
# 263/263 - 1s - loss: 0.0174 - 1s/epoch - 4ms/step
# Epoch 12/100
# 263/263 - 1s - loss: 0.0314 - 1s/epoch - 4ms/step
# Epoch 13/100
# 263/263 - 1s - loss: 0.0243 - 1s/epoch - 4ms/step
# Epoch 14/100
# 263/263 - 1s - loss: 0.0168 - 1s/epoch - 4ms/step
# Epoch 15/100
# 263/263 - 1s - loss: 0.0136 - 1s/epoch - 5ms/step
# Epoch 16/100
# 263/263 - 2s - loss: 0.0150 - 2s/epoch - 6ms/step
# Epoch 17/100
# 263/263 - 2s - loss: 0.0147 - 2s/epoch - 6ms/step
# Epoch 18/100
# 263/263 - 1s - loss: 0.0250 - 1s/epoch - 4ms/step
# Epoch 19/100
# 263/263 - 1s - loss: 0.0277 - 1s/epoch - 4ms/step
# Epoch 20/100
# 263/263 - 1s - loss: 0.0115 - 1s/epoch - 4ms/step
# Epoch 21/100
# 263/263 - 1s - loss: 0.0129 - 1s/epoch - 4ms/step
# Epoch 22/100
# 263/263 - 1s - loss: 0.0160 - 1s/epoch - 4ms/step
# Epoch 23/100
# 263/263 - 1s - loss: 0.0102 - 1s/epoch - 4ms/step
# Epoch 24/100
# 263/263 - 1s - loss: 0.0141 - 1s/epoch - 4ms/step
# Epoch 25/100
# 263/263 - 1s - loss: 0.0109 - 1s/epoch - 4ms/step
# Epoch 26/100
# 263/263 - 1s - loss: 0.0170 - 1s/epoch - 4ms/step
# Epoch 27/100
# 263/263 - 1s - loss: 0.0102 - 1s/epoch - 5ms/step
# Epoch 28/100
# 263/263 - 2s - loss: 0.0143 - 2s/epoch - 6ms/step
# Epoch 29/100
# 263/263 - 1s - loss: 0.0116 - 1s/epoch - 5ms/step
# Epoch 30/100
# 263/263 - 1s - loss: 0.0159 - 995ms/epoch - 4ms/step
# Epoch 31/100
# 263/263 - 1s - loss: 0.0121 - 1s/epoch - 4ms/step
# Epoch 32/100
# 263/263 - 1s - loss: 0.0151 - 1s/epoch - 4ms/step
# Epoch 33/100
# 263/263 - 1s - loss: 0.0083 - 1s/epoch - 4ms/step
# Epoch 34/100
# 263/263 - 1s - loss: 0.0089 - 1s/epoch - 4ms/step
# Epoch 35/100
# 263/263 - 1s - loss: 0.0077 - 1s/epoch - 4ms/step
# Epoch 36/100
# 263/263 - 1s - loss: 0.0089 - 1s/epoch - 4ms/step
# Epoch 37/100
# 263/263 - 1s - loss: 0.0115 - 1s/epoch - 4ms/step
# Epoch 38/100
# 263/263 - 1s - loss: 0.0134 - 1s/epoch - 4ms/step
# Epoch 39/100
# 263/263 - 2s - loss: 0.0126 - 2s/epoch - 6ms/step
# Epoch 40/100
# 263/263 - 2s - loss: 0.0112 - 2s/epoch - 6ms/step
# Epoch 41/100
# 263/263 - 1s - loss: 0.0090 - 1s/epoch - 5ms/step
# Epoch 42/100
# 263/263 - 1s - loss: 0.0071 - 1s/epoch - 4ms/step
# Epoch 43/100
# 263/263 - 1s - loss: 0.0082 - 1s/epoch - 4ms/step
# Epoch 44/100
# 263/263 - 1s - loss: 0.0080 - 1s/epoch - 4ms/step
# Epoch 45/100
# 263/263 - 1s - loss: 0.0099 - 1s/epoch - 4ms/step
# Epoch 46/100
# 263/263 - 1s - loss: 0.0091 - 1s/epoch - 4ms/step
# Epoch 47/100
# 263/263 - 1s - loss: 0.0102 - 1s/epoch - 4ms/step
# Epoch 48/100
# 263/263 - 1s - loss: 0.0083 - 1s/epoch - 4ms/step
# Epoch 49/100
# 263/263 - 1s - loss: 0.0080 - 1s/epoch - 4ms/step
# Epoch 50/100
# 263/263 - 1s - loss: 0.0072 - 1s/epoch - 4ms/step
# Epoch 51/100
# 263/263 - 2s - loss: 0.0089 - 2s/epoch - 6ms/step
# Epoch 52/100
# 263/263 - 2s - loss: 0.0080 - 2s/epoch - 6ms/step
# Epoch 53/100
# 263/263 - 1s - loss: 0.0095 - 1s/epoch - 5ms/step
# Epoch 54/100
# 263/263 - 1s - loss: 0.0075 - 979ms/epoch - 4ms/step
# Epoch 55/100
# 263/263 - 1s - loss: 0.0075 - 1s/epoch - 4ms/step
# Epoch 56/100
# 263/263 - 1s - loss: 0.0067 - 1s/epoch - 4ms/step
# Epoch 57/100
# 263/263 - 1s - loss: 0.0079 - 1s/epoch - 4ms/step
# Epoch 58/100
# 263/263 - 1s - loss: 0.0075 - 1s/epoch - 4ms/step
# Epoch 59/100
# 263/263 - 1s - loss: 0.0091 - 1s/epoch - 4ms/step
# Epoch 60/100
# 263/263 - 1s - loss: 0.0073 - 981ms/epoch - 4ms/step
# Epoch 61/100
# 263/263 - 1s - loss: 0.0071 - 1s/epoch - 4ms/step
# Epoch 62/100
# 263/263 - 1s - loss: 0.0062 - 1s/epoch - 4ms/step
# Epoch 63/100
# 263/263 - 1s - loss: 0.0071 - 1s/epoch - 5ms/step
# Epoch 64/100
# 263/263 - 2s - loss: 0.0069 - 2s/epoch - 6ms/step
# Epoch 65/100
# 263/263 - 1s - loss: 0.0073 - 1s/epoch - 6ms/step
# Epoch 66/100
# 263/263 - 1s - loss: 0.0069 - 1s/epoch - 4ms/step
# Epoch 67/100
# 263/263 - 1s - loss: 0.0072 - 981ms/epoch - 4ms/step
# Epoch 68/100
# 263/263 - 1s - loss: 0.0081 - 1s/epoch - 4ms/step
# Epoch 69/100
# 263/263 - 1s - loss: 0.0076 - 1s/epoch - 4ms/step
# Epoch 70/100
# 263/263 - 1s - loss: 0.0059 - 1s/epoch - 4ms/step
# Epoch 71/100
# 263/263 - 1s - loss: 0.0056 - 991ms/epoch - 4ms/step
# Epoch 72/100
# 263/263 - 1s - loss: 0.0054 - 1s/epoch - 4ms/step
# Epoch 73/100
# 263/263 - 1s - loss: 0.0055 - 1s/epoch - 4ms/step
# Epoch 74/100
# 263/263 - 1s - loss: 0.0063 - 1s/epoch - 4ms/step
# Epoch 75/100
# 263/263 - 1s - loss: 0.0078 - 1s/epoch - 5ms/step
# Epoch 76/100
# 263/263 - 2s - loss: 0.0087 - 2s/epoch - 6ms/step
# Epoch 77/100
# 263/263 - 2s - loss: 0.0063 - 2s/epoch - 6ms/step
# Epoch 78/100
# 263/263 - 1s - loss: 0.0052 - 1s/epoch - 4ms/step
# Epoch 79/100
# 263/263 - 1s - loss: 0.0045 - 982ms/epoch - 4ms/step
# Epoch 80/100
# 263/263 - 1s - loss: 0.0044 - 992ms/epoch - 4ms/step
# Epoch 81/100
# 263/263 - 1s - loss: 0.0047 - 992ms/epoch - 4ms/step
# Epoch 82/100
# 263/263 - 1s - loss: 0.0060 - 1s/epoch - 4ms/step
# Epoch 83/100
# 263/263 - 1s - loss: 0.0093 - 999ms/epoch - 4ms/step
# Epoch 84/100
# 263/263 - 1s - loss: 0.0088 - 985ms/epoch - 4ms/step
# Epoch 85/100
# 263/263 - 1s - loss: 0.0054 - 969ms/epoch - 4ms/step
# Epoch 86/100
# 263/263 - 1s - loss: 0.0041 - 1s/epoch - 4ms/step
# Epoch 87/100
# 263/263 - 1s - loss: 0.0038 - 1s/epoch - 4ms/step
# Epoch 88/100
# 263/263 - 2s - loss: 0.0038 - 2s/epoch - 6ms/step
# Epoch 89/100
# 263/263 - 2s - loss: 0.0041 - 2s/epoch - 6ms/step
# Epoch 90/100
# 263/263 - 1s - loss: 0.0049 - 1000ms/epoch - 4ms/step
# Epoch 91/100
# 263/263 - 1s - loss: 0.0081 - 1s/epoch - 4ms/step
# Epoch 92/100
# 263/263 - 1s - loss: 0.0117 - 1s/epoch - 4ms/step
# Epoch 93/100
# 263/263 - 1s - loss: 0.0057 - 1s/epoch - 4ms/step
# Epoch 94/100
# 263/263 - 1s - loss: 0.0040 - 1s/epoch - 4ms/step
# Epoch 95/100
# 263/263 - 1s - loss: 0.0037 - 995ms/epoch - 4ms/step
# Epoch 96/100
# 263/263 - 1s - loss: 0.0036 - 1s/epoch - 4ms/step
# Epoch 97/100
# 263/263 - 1s - loss: 0.0036 - 1s/epoch - 4ms/step
# Epoch 98/100
# 263/263 - 1s - loss: 0.0039 - 981ms/epoch - 4ms/step
# Epoch 99/100
# 263/263 - 1s - loss: 0.0048 - 1s/epoch - 4ms/step
# Epoch 100/100
# 263/263 - 1s - loss: 0.0086 - 1s/epoch - 6ms/step
# 9/9 [==============================] - 1s 4ms/step
# Epoch 1/100
# 262/262 - 4s - loss: 0.2385 - 4s/epoch - 14ms/step
# Epoch 2/100
# 262/262 - 1s - loss: 0.0870 - 1s/epoch - 6ms/step
# Epoch 3/100
# 262/262 - 1s - loss: 0.0343 - 1s/epoch - 5ms/step
# Epoch 4/100
# 262/262 - 1s - loss: 0.0528 - 1s/epoch - 5ms/step
# Epoch 5/100
# 262/262 - 1s - loss: 0.0741 - 1s/epoch - 5ms/step
# Epoch 6/100
# 262/262 - 1s - loss: 0.0363 - 1s/epoch - 6ms/step
# Epoch 7/100
# 262/262 - 2s - loss: 0.0434 - 2s/epoch - 8ms/step
# Epoch 8/100
# 262/262 - 2s - loss: 0.0436 - 2s/epoch - 8ms/step
# Epoch 9/100
# 262/262 - 1s - loss: 0.0343 - 1s/epoch - 5ms/step
# Epoch 10/100
# 262/262 - 1s - loss: 0.0314 - 1s/epoch - 5ms/step
# Epoch 11/100
# 262/262 - 1s - loss: 0.0225 - 1s/epoch - 5ms/step
# Epoch 12/100
# 262/262 - 1s - loss: 0.0164 - 1s/epoch - 5ms/step
# Epoch 13/100
# 262/262 - 1s - loss: 0.0137 - 1s/epoch - 5ms/step
# Epoch 14/100
# 262/262 - 1s - loss: 0.0137 - 1s/epoch - 5ms/step
# Epoch 15/100
# 262/262 - 2s - loss: 0.0157 - 2s/epoch - 6ms/step
# Epoch 16/100
# Epoch 17/100
# 262/262 - 2s - loss: 0.0152 - 2s/epoch - 7ms/step
# Epoch 18/100
# 262/262 - 1s - loss: 0.0145 - 1s/epoch - 5ms/step
# Epoch 19/100
# 262/262 - 1s - loss: 0.0152 - 1s/epoch - 5ms/step
# Epoch 20/100
# 262/262 - 1s - loss: 0.0163 - 1s/epoch - 5ms/step
# Epoch 21/100
# 262/262 - 1s - loss: 0.0200 - 1s/epoch - 5ms/step
# Epoch 22/100
# 262/262 - 1s - loss: 0.0156 - 1s/epoch - 5ms/step
# Epoch 23/100
# 262/262 - 1s - loss: 0.0150 - 1s/epoch - 5ms/step
# Epoch 24/100
# 262/262 - 1s - loss: 0.0126 - 1s/epoch - 5ms/step
# Epoch 25/100
# 262/262 - 2s - loss: 0.0107 - 2s/epoch - 8ms/step
# Epoch 26/100
# 262/262 - 2s - loss: 0.0082 - 2s/epoch - 8ms/step
# Epoch 27/100
# 262/262 - 1s - loss: 0.0076 - 1s/epoch - 5ms/step
# Epoch 28/100
# 262/262 - 1s - loss: 0.0089 - 1s/epoch - 5ms/step
# Epoch 29/100
# 262/262 - 1s - loss: 0.0112 - 1s/epoch - 5ms/step
# Epoch 30/100
# 262/262 - 1s - loss: 0.0133 - 1s/epoch - 5ms/step
# Epoch 31/100
# 262/262 - 1s - loss: 0.0124 - 1s/epoch - 5ms/step
# Epoch 32/100
# 262/262 - 1s - loss: 0.0085 - 1s/epoch - 5ms/step
# Epoch 33/100
# 262/262 - 1s - loss: 0.0071 - 1s/epoch - 5ms/step
# Epoch 34/100
# 262/262 - 2s - loss: 0.0076 - 2s/epoch - 7ms/step
# Epoch 35/100
# 262/262 - 2s - loss: 0.0085 - 2s/epoch - 8ms/step
# Epoch 36/100
# 262/262 - 1s - loss: 0.0095 - 1s/epoch - 6ms/step
# Epoch 37/100
# 262/262 - 1s - loss: 0.0094 - 1s/epoch - 5ms/step
# Epoch 38/100
# 262/262 - 1s - loss: 0.0135 - 1s/epoch - 5ms/step
# Epoch 39/100
# 262/262 - 1s - loss: 0.0137 - 1s/epoch - 5ms/step
# Epoch 40/100
# 262/262 - 1s - loss: 0.0119 - 1s/epoch - 5ms/step
# Epoch 41/100
# 262/262 - 1s - loss: 0.0053 - 1s/epoch - 5ms/step
# Epoch 42/100
# 262/262 - 1s - loss: 0.0064 - 1s/epoch - 5ms/step
# Epoch 43/100
# 262/262 - 2s - loss: 0.0057 - 2s/epoch - 6ms/step
# Epoch 44/100
# 262/262 - 2s - loss: 0.0058 - 2s/epoch - 8ms/step
# Epoch 45/100
# 262/262 - 2s - loss: 0.0065 - 2s/epoch - 6ms/step
# Epoch 46/100
# 262/262 - 1s - loss: 0.0076 - 1s/epoch - 5ms/step
# Epoch 47/100
# 262/262 - 1s - loss: 0.0083 - 1s/epoch - 5ms/step
# Epoch 48/100
# 262/262 - 1s - loss: 0.0095 - 1s/epoch - 5ms/step
# Epoch 49/100
# 262/262 - 1s - loss: 0.0090 - 1s/epoch - 5ms/step
# Epoch 50/100
# 262/262 - 1s - loss: 0.0060 - 1s/epoch - 5ms/step
# Epoch 51/100
# 262/262 - 1s - loss: 0.0053 - 1s/epoch - 5ms/step
# Epoch 52/100
# 262/262 - 2s - loss: 0.0051 - 2s/epoch - 7ms/step
# Epoch 53/100
# 262/262 - 2s - loss: 0.0058 - 2s/epoch - 8ms/step
# Epoch 54/100
# 262/262 - 2s - loss: 0.0072 - 2s/epoch - 6ms/step
# Epoch 55/100
# 262/262 - 1s - loss: 0.0086 - 1s/epoch - 5ms/step
# Epoch 56/100
# 262/262 - 1s - loss: 0.0088 - 1s/epoch - 5ms/step
# Epoch 57/100
# 262/262 - 1s - loss: 0.0075 - 1s/epoch - 5ms/step
# Epoch 58/100
# 262/262 - 1s - loss: 0.0049 - 1s/epoch - 5ms/step
# Epoch 59/100
# 262/262 - 1s - loss: 0.0045 - 1s/epoch - 5ms/step
# Epoch 60/100
# 262/262 - 1s - loss: 0.0047 - 1s/epoch - 5ms/step
# Epoch 61/100
# 262/262 - 2s - loss: 0.0056 - 2s/epoch - 6ms/step
# Epoch 62/100
# 262/262 - 2s - loss: 0.0072 - 2s/epoch - 8ms/step
# Epoch 63/100
# 262/262 - 2s - loss: 0.0089 - 2s/epoch - 6ms/step
# Epoch 64/100
# 262/262 - 1s - loss: 0.0078 - 1s/epoch - 5ms/step
# Epoch 65/100
# 262/262 - 1s - loss: 0.0045 - 1s/epoch - 5ms/step
# Epoch 66/100
# 262/262 - 1s - loss: 0.0041 - 1s/epoch - 5ms/step
# Epoch 67/100
# 262/262 - 1s - loss: 0.0041 - 1s/epoch - 5ms/step
# Epoch 68/100
# 262/262 - 1s - loss: 0.0044 - 1s/epoch - 5ms/step
# Epoch 69/100
# 262/262 - 1s - loss: 0.0057 - 1s/epoch - 5ms/step
# Epoch 70/100
# 262/262 - 2s - loss: 0.0086 - 2s/epoch - 7ms/step
# Epoch 71/100
# 262/262 - 2s - loss: 0.0092 - 2s/epoch - 8ms/step
# Epoch 72/100
# 262/262 - 2s - loss: 0.0071 - 2s/epoch - 6ms/step
# Epoch 73/100
# 262/262 - 1s - loss: 0.0043 - 1s/epoch - 5ms/step
# Epoch 74/100
# 262/262 - 1s - loss: 0.0042 - 1s/epoch - 5ms/step
# Epoch 75/100
# 262/262 - 1s - loss: 0.0039 - 1s/epoch - 5ms/step
# Epoch 76/100
# 262/262 - 1s - loss: 0.0038 - 1s/epoch - 5ms/step
# Epoch 77/100
# 262/262 - 1s - loss: 0.0042 - 1s/epoch - 5ms/step
# Epoch 78/100
# 262/262 - 1s - loss: 0.0055 - 1s/epoch - 5ms/step
# Epoch 79/100
# 262/262 - 2s - loss: 0.0079 - 2s/epoch - 7ms/step
# Epoch 80/100
# 262/262 - 2s - loss: 0.0087 - 2s/epoch - 8ms/step
# Epoch 81/100
# 262/262 - 2s - loss: 0.0054 - 2s/epoch - 6ms/step
# Epoch 82/100
# 262/262 - 1s - loss: 0.0038 - 1s/epoch - 5ms/step
# Epoch 83/100
# 262/262 - 1s - loss: 0.0036 - 1s/epoch - 5ms/step
# Epoch 84/100
# 262/262 - 1s - loss: 0.0035 - 1s/epoch - 5ms/step
# Epoch 85/100
# 262/262 - 1s - loss: 0.0034 - 1s/epoch - 5ms/step
# Epoch 86/100
# 262/262 - 1s - loss: 0.0035 - 1s/epoch - 5ms/step
# Epoch 87/100
# 262/262 - 1s - loss: 0.0041 - 1s/epoch - 5ms/step
# Epoch 88/100
# 262/262 - 2s - loss: 0.0069 - 2s/epoch - 6ms/step
# Epoch 89/100
# 262/262 - 2s - loss: 0.0114 - 2s/epoch - 8ms/step
# Epoch 90/100
# 262/262 - 2s - loss: 0.0067 - 2s/epoch - 7ms/step
# Epoch 91/100
# 262/262 - 1s - loss: 0.0038 - 1s/epoch - 5ms/step
# Epoch 92/100
# 262/262 - 1s - loss: 0.0035 - 1s/epoch - 6ms/step
# Epoch 93/100
# 262/262 - 2s - loss: 0.0032 - 2s/epoch - 6ms/step
# Epoch 94/100
# 262/262 - 1s - loss: 0.0032 - 1s/epoch - 6ms/step
# Epoch 95/100
# 262/262 - 1s - loss: 0.0033 - 1s/epoch - 5ms/step
# Epoch 96/100
# 262/262 - 1s - loss: 0.0034 - 1s/epoch - 5ms/step
# Epoch 97/100
# 262/262 - 2s - loss: 0.0040 - 2s/epoch - 6ms/step
# Epoch 98/100
# 262/262 - 2s - loss: 0.0066 - 2s/epoch - 8ms/step
# Epoch 99/100
# 262/262 - 2s - loss: 0.0091 - 2s/epoch - 7ms/step
# Epoch 100/100
# 262/262 - 1s - loss: 0.0051 - 1s/epoch - 5ms/step
# 9/9 [==============================] - 0s 4ms/step
# Epoch 1/100
# 261/261 - 6s - loss: 0.1885 - 6s/epoch - 21ms/step
# Epoch 2/100
# 261/261 - 3s - loss: 0.1029 - 3s/epoch - 13ms/step
# Epoch 3/100
# 261/261 - 4s - loss: 0.1307 - 4s/epoch - 14ms/step
# Epoch 4/100
# 261/261 - 3s - loss: 0.0682 - 3s/epoch - 10ms/step
# Epoch 5/100
# 261/261 - 3s - loss: 0.0408 - 3s/epoch - 10ms/step
# Epoch 6/100
# 261/261 - 3s - loss: 0.0579 - 3s/epoch - 11ms/step
# Epoch 7/100
# 261/261 - 4s - loss: 0.0241 - 4s/epoch - 15ms/step
# Epoch 8/100
# 261/261 - 3s - loss: 0.0228 - 3s/epoch - 11ms/step
# Epoch 9/100
# 261/261 - 3s - loss: 0.0120 - 3s/epoch - 11ms/step
# Epoch 10/100
# 261/261 - 3s - loss: 0.0151 - 3s/epoch - 11ms/step
# Epoch 11/100
# 261/261 - 3s - loss: 0.0132 - 3s/epoch - 12ms/step
# Epoch 12/100
# 261/261 - 4s - loss: 0.0114 - 4s/epoch - 14ms/step
# Epoch 13/100
# 261/261 - 3s - loss: 0.0125 - 3s/epoch - 11ms/step
# Epoch 14/100
# 261/261 - 3s - loss: 0.0130 - 3s/epoch - 10ms/step
# Epoch 15/100
# 261/261 - 3s - loss: 0.0131 - 3s/epoch - 10ms/step
# Epoch 16/100
# 261/261 - 4s - loss: 0.0124 - 4s/epoch - 15ms/step
# Epoch 17/100
# 261/261 - 3s - loss: 0.0116 - 3s/epoch - 11ms/step
# Epoch 18/100
# 261/261 - 3s - loss: 0.0105 - 3s/epoch - 10ms/step
# Epoch 19/100
# 261/261 - 3s - loss: 0.0097 - 3s/epoch - 11ms/step
# Epoch 20/100
# 261/261 - 3s - loss: 0.0091 - 3s/epoch - 11ms/step
# Epoch 21/100
# 261/261 - 4s - loss: 0.0096 - 4s/epoch - 15ms/step
# Epoch 22/100
# 261/261 - 3s - loss: 0.0110 - 3s/epoch - 11ms/step
# Epoch 23/100
# 261/261 - 3s - loss: 0.0129 - 3s/epoch - 11ms/step
# Epoch 24/100
# 261/261 - 3s - loss: 0.0129 - 3s/epoch - 11ms/step
# Epoch 25/100
# 261/261 - 4s - loss: 0.0103 - 4s/epoch - 14ms/step
# Epoch 26/100
# 261/261 - 3s - loss: 0.0094 - 3s/epoch - 13ms/step
# Epoch 27/100
# 261/261 - 3s - loss: 0.0081 - 3s/epoch - 11ms/step
# Epoch 28/100
# 261/261 - 3s - loss: 0.0060 - 3s/epoch - 11ms/step
# Epoch 29/100
# 261/261 - 3s - loss: 0.0055 - 3s/epoch - 11ms/step
# Epoch 30/100
# 261/261 - 4s - loss: 0.0062 - 4s/epoch - 16ms/step
# Epoch 31/100
# 261/261 - 3s - loss: 0.0106 - 3s/epoch - 11ms/step
# Epoch 32/100
# 261/261 - 3s - loss: 0.0140 - 3s/epoch - 11ms/step
# Epoch 33/100
# 261/261 - 3s - loss: 0.0139 - 3s/epoch - 11ms/step
# Epoch 34/100
# 261/261 - 4s - loss: 0.0078 - 4s/epoch - 15ms/step
# Epoch 35/100
# 261/261 - 3s - loss: 0.0065 - 3s/epoch - 13ms/step
# Epoch 36/100
# 261/261 - 3s - loss: 0.0063 - 3s/epoch - 11ms/step
# Epoch 37/100
# 261/261 - 3s - loss: 0.0053 - 3s/epoch - 11ms/step
# Epoch 38/100
# 261/261 - 3s - loss: 0.0065 - 3s/epoch - 13ms/step
# Epoch 39/100
# 261/261 - 4s - loss: 0.0084 - 4s/epoch - 15ms/step
# Epoch 40/100
# 261/261 - 3s - loss: 0.0094 - 3s/epoch - 11ms/step
# Epoch 41/100
# 261/261 - 3s - loss: 0.0077 - 3s/epoch - 12ms/step
# Epoch 42/100
# 261/261 - 3s - loss: 0.0055 - 3s/epoch - 12ms/step
# Epoch 43/100
# 261/261 - 4s - loss: 0.0051 - 4s/epoch - 17ms/step
# Epoch 44/100
# 261/261 - 3s - loss: 0.0050 - 3s/epoch - 12ms/step
# Epoch 45/100
# 261/261 - 3s - loss: 0.0046 - 3s/epoch - 11ms/step
# Epoch 46/100
# 261/261 - 3s - loss: 0.0057 - 3s/epoch - 11ms/step
# Epoch 47/100
# 261/261 - 4s - loss: 0.0117 - 4s/epoch - 14ms/step
# Epoch 48/100
# 261/261 - 3s - loss: 0.0127 - 3s/epoch - 12ms/step
# Epoch 49/100
# 261/261 - 3s - loss: 0.0125 - 3s/epoch - 10ms/step
# Epoch 50/100
# 261/261 - 3s - loss: 0.0069 - 3s/epoch - 11ms/step
# Epoch 51/100
# 261/261 - 3s - loss: 0.0067 - 3s/epoch - 11ms/step
# Epoch 52/100
# 261/261 - 4s - loss: 0.0059 - 4s/epoch - 15ms/step
# Epoch 53/100
# 261/261 - 3s - loss: 0.0064 - 3s/epoch - 10ms/step
# Epoch 54/100
# 261/261 - 3s - loss: 0.0046 - 3s/epoch - 11ms/step
# Epoch 55/100
# 261/261 - 3s - loss: 0.0040 - 3s/epoch - 10ms/step
# Epoch 56/100
# 261/261 - 3s - loss: 0.0039 - 3s/epoch - 13ms/step
# Epoch 57/100
# 261/261 - 3s - loss: 0.0045 - 3s/epoch - 13ms/step
# Epoch 58/100
# 261/261 - 3s - loss: 0.0058 - 3s/epoch - 10ms/step
# Epoch 59/100
# 261/261 - 3s - loss: 0.0075 - 3s/epoch - 10ms/step
# Epoch 60/100
# 261/261 - 3s - loss: 0.0068 - 3s/epoch - 10ms/step
# Epoch 61/100
# 261/261 - 4s - loss: 0.0045 - 4s/epoch - 15ms/step
# Epoch 62/100
# 261/261 - 3s - loss: 0.0039 - 3s/epoch - 11ms/step
# Epoch 63/100
# 261/261 - 3s - loss: 0.0039 - 3s/epoch - 10ms/step
# Epoch 64/100
# 261/261 - 3s - loss: 0.0039 - 3s/epoch - 11ms/step
# Epoch 65/100
# 261/261 - 3s - loss: 0.0062 - 3s/epoch - 12ms/step
# Epoch 66/100
# 261/261 - 4s - loss: 0.0115 - 4s/epoch - 15ms/step
# Epoch 67/100
# 261/261 - 3s - loss: 0.0082 - 3s/epoch - 10ms/step
# Epoch 68/100
# 261/261 - 3s - loss: 0.0040 - 3s/epoch - 11ms/step
# Epoch 69/100
# 261/261 - 3s - loss: 0.0041 - 3s/epoch - 11ms/step
# Epoch 70/100
# 261/261 - 4s - loss: 0.0040 - 4s/epoch - 14ms/step
# Epoch 71/100
# 261/261 - 3s - loss: 0.0036 - 3s/epoch - 13ms/step
# Epoch 72/100
# 261/261 - 3s - loss: 0.0042 - 3s/epoch - 11ms/step
# Epoch 73/100
# 261/261 - 3s - loss: 0.0057 - 3s/epoch - 11ms/step
# Epoch 74/100
# 261/261 - 3s - loss: 0.0062 - 3s/epoch - 11ms/step
# Epoch 75/100
# 261/261 - 4s - loss: 0.0051 - 4s/epoch - 15ms/step
# Epoch 76/100
# 261/261 - 3s - loss: 0.0036 - 3s/epoch - 11ms/step
# Epoch 77/100
# 261/261 - 3s - loss: 0.0035 - 3s/epoch - 10ms/step
# Epoch 78/100
# 261/261 - 3s - loss: 0.0036 - 3s/epoch - 10ms/step
# Epoch 79/100
# 261/261 - 4s - loss: 0.0058 - 4s/epoch - 13ms/step
# Epoch 80/100
# 261/261 - 3s - loss: 0.0051 - 3s/epoch - 13ms/step
# Epoch 81/100
# 261/261 - 3s - loss: 0.0057 - 3s/epoch - 11ms/step
# Epoch 82/100
# 261/261 - 3s - loss: 0.0065 - 3s/epoch - 10ms/step
# Epoch 83/100
# 261/261 - 3s - loss: 0.0042 - 3s/epoch - 11ms/step
# Epoch 84/100
# 261/261 - 4s - loss: 0.0035 - 4s/epoch - 15ms/step
# Epoch 85/100
# 261/261 - 3s - loss: 0.0039 - 3s/epoch - 11ms/step
# Epoch 86/100
# 261/261 - 3s - loss: 0.0043 - 3s/epoch - 11ms/step
# Epoch 87/100
# 261/261 - 3s - loss: 0.0045 - 3s/epoch - 11ms/step
# Epoch 88/100
# 261/261 - 3s - loss: 0.0036 - 3s/epoch - 12ms/step
# Epoch 89/100
# 261/261 - 4s - loss: 0.0040 - 4s/epoch - 14ms/step
# Epoch 90/100
# 261/261 - 3s - loss: 0.0038 - 3s/epoch - 11ms/step
# Epoch 91/100
# 261/261 - 3s - loss: 0.0036 - 3s/epoch - 11ms/step
# Epoch 92/100
# 261/261 - 3s - loss: 0.0035 - 3s/epoch - 11ms/step
# Epoch 93/100
# 261/261 - 4s - loss: 0.0037 - 4s/epoch - 15ms/step
# Epoch 94/100
# 261/261 - 3s - loss: 0.0043 - 3s/epoch - 11ms/step
# Epoch 95/100
# 261/261 - 3s - loss: 0.0053 - 3s/epoch - 11ms/step
# Epoch 96/100
# 261/261 - 3s - loss: 0.0046 - 3s/epoch - 11ms/step
# Epoch 97/100
# 261/261 - 3s - loss: 0.0039 - 3s/epoch - 12ms/step
# Epoch 98/100
# 261/261 - 4s - loss: 0.0032 - 4s/epoch - 14ms/step
# Epoch 99/100
# 261/261 - 3s - loss: 0.0044 - 3s/epoch - 10ms/step
# Epoch 100/100
# 261/261 - 3s - loss: 0.0058 - 3s/epoch - 10ms/step
# 9/9 [==============================] - 0s 6ms/step
# Epoch 1/100
# 259/259 - 7s - loss: 0.1159 - 7s/epoch - 27ms/step
# Epoch 2/100
# 259/259 - 3s - loss: 0.1042 - 3s/epoch - 11ms/step
# Epoch 3/100
# 259/259 - 3s - loss: 0.1086 - 3s/epoch - 11ms/step
# Epoch 4/100
# 259/259 - 3s - loss: 0.1012 - 3s/epoch - 12ms/step
# Epoch 5/100
# 259/259 - 5s - loss: 0.0539 - 5s/epoch - 18ms/step
# Epoch 6/100
# 259/259 - 3s - loss: 0.0265 - 3s/epoch - 11ms/step
# Epoch 7/100
# 259/259 - 3s - loss: 0.0329 - 3s/epoch - 12ms/step
# Epoch 8/100
# 259/259 - 3s - loss: 0.0157 - 3s/epoch - 11ms/step
# Epoch 9/100
# 259/259 - 4s - loss: 0.0129 - 4s/epoch - 17ms/step
# Epoch 10/100
# 259/259 - 3s - loss: 0.0149 - 3s/epoch - 12ms/step
# Epoch 11/100
# 259/259 - 3s - loss: 0.0123 - 3s/epoch - 12ms/step
# Epoch 12/100
# 259/259 - 3s - loss: 0.0105 - 3s/epoch - 11ms/step
# Epoch 13/100
# 259/259 - 4s - loss: 0.0110 - 4s/epoch - 15ms/step
# Epoch 14/100
# 259/259 - 4s - loss: 0.0123 - 4s/epoch - 14ms/step
# Epoch 15/100
# 259/259 - 3s - loss: 0.0132 - 3s/epoch - 11ms/step
# Epoch 16/100
# 259/259 - 3s - loss: 0.0097 - 3s/epoch - 11ms/step
# Epoch 17/100
# 259/259 - 3s - loss: 0.0077 - 3s/epoch - 13ms/step
# Epoch 18/100
# 259/259 - 4s - loss: 0.0083 - 4s/epoch - 16ms/step
# Epoch 19/100
# 259/259 - 3s - loss: 0.0176 - 3s/epoch - 11ms/step
# Epoch 20/100
# 259/259 - 3s - loss: 0.0148 - 3s/epoch - 11ms/step
# Epoch 21/100
# 259/259 - 3s - loss: 0.0162 - 3s/epoch - 12ms/step
# Epoch 22/100
# 259/259 - 4s - loss: 0.0088 - 4s/epoch - 17ms/step
# Epoch 23/100
# 259/259 - 3s - loss: 0.0083 - 3s/epoch - 11ms/step
# Epoch 24/100
# 259/259 - 3s - loss: 0.0089 - 3s/epoch - 11ms/step
# Epoch 25/100
# 259/259 - 3s - loss: 0.0089 - 3s/epoch - 11ms/step
# Epoch 26/100
# 259/259 - 4s - loss: 0.0098 - 4s/epoch - 17ms/step
# Epoch 27/100
# 259/259 - 3s - loss: 0.0091 - 3s/epoch - 12ms/step
# Epoch 28/100
# 259/259 - 3s - loss: 0.0065 - 3s/epoch - 11ms/step
# Epoch 29/100
# 259/259 - 3s - loss: 0.0096 - 3s/epoch - 11ms/step
# Epoch 30/100
# 259/259 - 4s - loss: 0.0090 - 4s/epoch - 15ms/step
# Epoch 31/100
# 259/259 - 3s - loss: 0.0056 - 3s/epoch - 13ms/step
# Epoch 32/100
# 259/259 - 3s - loss: 0.0062 - 3s/epoch - 11ms/step
# Epoch 33/100
# 259/259 - 3s - loss: 0.0095 - 3s/epoch - 11ms/step
# Epoch 34/100
# 259/259 - 3s - loss: 0.0093 - 3s/epoch - 13ms/step
# Epoch 35/100
# 259/259 - 4s - loss: 0.0069 - 4s/epoch - 15ms/step
# Epoch 36/100
# 259/259 - 3s - loss: 0.0061 - 3s/epoch - 11ms/step
# Epoch 37/100
# 259/259 - 3s - loss: 0.0097 - 3s/epoch - 11ms/step
# Epoch 38/100
# 259/259 - 3s - loss: 0.0084 - 3s/epoch - 11ms/step
# Epoch 39/100
# 259/259 - 4s - loss: 0.0075 - 4s/epoch - 17ms/step
# Epoch 40/100
# 259/259 - 3s - loss: 0.0074 - 3s/epoch - 11ms/step
# Epoch 41/100
# 259/259 - 3s - loss: 0.0059 - 3s/epoch - 12ms/step
# Epoch 42/100
# 259/259 - 3s - loss: 0.0079 - 3s/epoch - 11ms/step
# Epoch 43/100
# 259/259 - 4s - loss: 0.0065 - 4s/epoch - 16ms/step
# Epoch 44/100
# 259/259 - 3s - loss: 0.0060 - 3s/epoch - 12ms/step
# Epoch 45/100
# 259/259 - 3s - loss: 0.0061 - 3s/epoch - 11ms/step
# Epoch 46/100
# 259/259 - 3s - loss: 0.0091 - 3s/epoch - 11ms/step
# Epoch 47/100
# 259/259 - 4s - loss: 0.0074 - 4s/epoch - 15ms/step
# Epoch 48/100
# 259/259 - 4s - loss: 0.0087 - 4s/epoch - 14ms/step
# Epoch 49/100
# 259/259 - 3s - loss: 0.0087 - 3s/epoch - 11ms/step
# Epoch 50/100
# 259/259 - 3s - loss: 0.0064 - 3s/epoch - 12ms/step
# Epoch 51/100
# 259/259 - 3s - loss: 0.0055 - 3s/epoch - 13ms/step
# Epoch 52/100
# 259/259 - 4s - loss: 0.0084 - 4s/epoch - 15ms/step
# Epoch 53/100
# 259/259 - 3s - loss: 0.0060 - 3s/epoch - 11ms/step
# Epoch 54/100
# 259/259 - 3s - loss: 0.0053 - 3s/epoch - 12ms/step
# Epoch 55/100
# 259/259 - 3s - loss: 0.0085 - 3s/epoch - 12ms/step
# Epoch 56/100
# 259/259 - 4s - loss: 0.0061 - 4s/epoch - 16ms/step
# Epoch 57/100
# 259/259 - 3s - loss: 0.0050 - 3s/epoch - 11ms/step
# Epoch 58/100
# 259/259 - 3s - loss: 0.0098 - 3s/epoch - 12ms/step
# Epoch 59/100
# 259/259 - 3s - loss: 0.0071 - 3s/epoch - 11ms/step
# Epoch 60/100
# 259/259 - 4s - loss: 0.0051 - 4s/epoch - 17ms/step
# Epoch 61/100
# 259/259 - 3s - loss: 0.0088 - 3s/epoch - 11ms/step
# Epoch 62/100
# 259/259 - 3s - loss: 0.0073 - 3s/epoch - 11ms/step
# Epoch 63/100
# 259/259 - 3s - loss: 0.0054 - 3s/epoch - 11ms/step
# Epoch 64/100
# 259/259 - 4s - loss: 0.0072 - 4s/epoch - 16ms/step
# Epoch 65/100
# 259/259 - 3s - loss: 0.0054 - 3s/epoch - 12ms/step
# Epoch 66/100
# 259/259 - 3s - loss: 0.0051 - 3s/epoch - 11ms/step
# Epoch 67/100
# 259/259 - 3s - loss: 0.0059 - 3s/epoch - 11ms/step
# Epoch 68/100
# 259/259 - 4s - loss: 0.0085 - 4s/epoch - 14ms/step
# Epoch 69/100
# 259/259 - 4s - loss: 0.0079 - 4s/epoch - 14ms/step
# Epoch 70/100
# 259/259 - 3s - loss: 0.0067 - 3s/epoch - 11ms/step
# Epoch 71/100
# 259/259 - 3s - loss: 0.0066 - 3s/epoch - 11ms/step
# Epoch 72/100
# 259/259 - 3s - loss: 0.0070 - 3s/epoch - 13ms/step
# Epoch 73/100
# 259/259 - 4s - loss: 0.0084 - 4s/epoch - 16ms/step
# Epoch 74/100
# 259/259 - 3s - loss: 0.0068 - 3s/epoch - 11ms/step
# Epoch 75/100
# 259/259 - 3s - loss: 0.0102 - 3s/epoch - 11ms/step
# Epoch 76/100
# 259/259 - 3s - loss: 0.0070 - 3s/epoch - 11ms/step
# Epoch 77/100
# 259/259 - 5s - loss: 0.0056 - 5s/epoch - 17ms/step
# Epoch 78/100
# 259/259 - 3s - loss: 0.0053 - 3s/epoch - 11ms/step
# Epoch 79/100
# 259/259 - 3s - loss: 0.0052 - 3s/epoch - 12ms/step
# Epoch 80/100
# 259/259 - 3s - loss: 0.0044 - 3s/epoch - 11ms/step
# Epoch 81/100
# 259/259 - 4s - loss: 0.0042 - 4s/epoch - 16ms/step
# Epoch 82/100
# 259/259 - 3s - loss: 0.0047 - 3s/epoch - 13ms/step
# Epoch 83/100
# 259/259 - 3s - loss: 0.0061 - 3s/epoch - 11ms/step
# Epoch 84/100
# 259/259 - 3s - loss: 0.0062 - 3s/epoch - 11ms/step
# Epoch 85/100
# 259/259 - 4s - loss: 0.0050 - 4s/epoch - 14ms/step
# Epoch 86/100
# 259/259 - 4s - loss: 0.0065 - 4s/epoch - 15ms/step
# Epoch 87/100
# 259/259 - 3s - loss: 0.0085 - 3s/epoch - 11ms/step
# Epoch 88/100
# 259/259 - 3s - loss: 0.0070 - 3s/epoch - 11ms/step
# Epoch 89/100
# 259/259 - 3s - loss: 0.0064 - 3s/epoch - 12ms/step
# Epoch 90/100
# 259/259 - 4s - loss: 0.0118 - 4s/epoch - 17ms/step
# Epoch 91/100
# 259/259 - 3s - loss: 0.0052 - 3s/epoch - 11ms/step
# Epoch 92/100
# 259/259 - 3s - loss: 0.0062 - 3s/epoch - 11ms/step
# Epoch 93/100
# 259/259 - 3s - loss: 0.0043 - 3s/epoch - 11ms/step
# Epoch 94/100
# 259/259 - 4s - loss: 0.0065 - 4s/epoch - 17ms/step
# Epoch 95/100
# 259/259 - 3s - loss: 0.0042 - 3s/epoch - 12ms/step
# Epoch 96/100
# 259/259 - 3s - loss: 0.0043 - 3s/epoch - 12ms/step
# Epoch 97/100
# 259/259 - 3s - loss: 0.0044 - 3s/epoch - 11ms/step
# Epoch 98/100
# 259/259 - 4s - loss: 0.0057 - 4s/epoch - 15ms/step
# Epoch 99/100
# 259/259 - 3s - loss: 0.0049 - 3s/epoch - 13ms/step
# Epoch 100/100
# 259/259 - 3s - loss: 0.0053 - 3s/epoch - 11ms/step
# 9/9 [==============================] - 0s 8ms/step

# %%
for result in results:
    print(f"n_steps: {result[0]}, RMSE: {result[1]}, MAPE: {result[2]}")
# Out:
# n_steps: 2, RMSE: 0.10442471790430925, MAPE: 0.24296561633188388
# n_steps: 6, RMSE: 0.04111875910887252, MAPE: 0.09307569467380553
# n_steps: 13, RMSE: 0.03753053073636534, MAPE: 0.07999777670471966
# n_steps: 20, RMSE: 0.06262254974447287, MAPE: 0.10569636020605234

# %%
plt.figure(figsize=(10, 5))
plt.plot([result[0] for result in results], [result[1] for result in results], marker='o', label='RMSE')
plt.plot([result[0] for result in results], [result[2] for result in results], marker='o', label='MAPE')
plt.xlabel('n_steps')
plt.ylabel('Error')
plt.title('Error vs. n_steps')
plt.legend()
plt.show()

# %% [markdown]
# The result shows that n_steps = n will reach the most accurate prediction, means that predicting the n+1th days is the best choice

# %% [markdown]
# #### 3.2.5 Cross Validation

# %%
# n_steps = 6
# X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

# %%
# tscv = TimeSeriesSplit(n_splits=5)
# rmse_scores = []
# mape_scores = []

# for train_index, test_index in tscv.split(X1):
#     X_train, X_test = X1[train_index], X1[test_index]
#     y_train, y_test = y1[train_index], y1[test_index]

#     # Define the model
#     model = Sequential()
#     model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
#     model.add(LSTM(50, activation='relu'))
#     model.add(Dense(1))
#     model.compile(loss='mean_squared_error', optimizer='adam')

#     # Train the model
#     model.fit(X_train, y_train, epochs=100, batch_size=4, verbose=0, shuffle=False)

#     # Predict
#     y_pred = model.predict(X_test)
#     y_pred = y_pred[:, 0]

#     # Calculate RMSE and MAPE
#     rmse = mean_squared_error(y_test, y_pred, squared=False)
#     mape = mean_absolute_percentage_error(y_test, y_pred)

#     rmse_scores.append(rmse)
#     mape_scores.append(mape)

# print(f"Average RMSE: {np.mean(rmse_scores)}, Average MAPE: {np.mean(mape_scores)}")

# %% [markdown]
# ###3.3 Run Saved Model

# %%
# Load the SavedModel
model = load_model('predict_near.h5')
sc = joblib.load('standard_scaler.pkl')

# %%
def prepare_input_data(ticker, end_date, n_steps):
    stock_data = yf.download(ticker, end=end_date)
    X_feat = stock_data[['Open', 'High', 'Low']]
    target_y = stock_data['Close']

    X_ft = sc.fit_transform(X_feat.values)
    stock_data_ft = pd.DataFrame(columns=X_feat.columns, data=X_ft, index=X_feat.index)
    stock_data_ft['Close'] = target_y.values

    input_data = stock_data_ft.values[-n_steps:, :-1]
    input_data = np.expand_dims(input_data, axis=0)

    return input_data, stock_data_ft.index[-1]

# %%
# Parameter prediksi
ticker = 'NEAR-USD'
end_date = '2024-03-01'
n_steps = 13

# Menyiapkan data input
input_data, last_date = prepare_input_data(ticker, end_date, n_steps)

# Melakukan prediksi
predicted_price_scaled = model.predict(input_data).flatten()[0]

# Mengembalikan hasil prediksi ke skala semula
predicted_price = sc.inverse_transform([[np.nan, predicted_price_scaled, np.nan]])[0][1]

# Menampilkan hasil prediksi
print(f"Harga saham {ticker} yang diprediksi untuk tanggal {end_date} adalah: {predicted_price:.2f}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 29ms/step
# Harga saham NEAR-USD yang diprediksi untuk tanggal 2024-03-01 adalah: 4.17
