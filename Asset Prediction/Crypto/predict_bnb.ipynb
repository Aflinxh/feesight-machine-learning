# %% [markdown]
# #Try Stock Prediction - NETFLIX

# %%
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import datetime as dt
import joblib
import yfinance as yf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 1. Read Data

# %%
# stock_data = pd.read_csv('/content/NFLX.csv', index_col='Date')
# stock_data

ticker = 'BNB-USD'
# start_date = '2020-05-20'
# end_date = pd.Timestamp.now().strftime('%Y-%m-%d')
start_date = '2020-05-21'
end_date = '2024-05-21'
stock_data = yf.download(ticker, start=start_date, end=end_date)
stock_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-05-21   16.887243   17.037516   15.791041   16.122381   16.122381
# 2020-05-22   16.126387   16.848112   15.980751   16.639593   16.639593
# 2020-05-23   16.631491   16.831505   16.358562   16.588194   16.588194
# 2020-05-24   16.579742   16.793018   16.081476   16.083439   16.083439
# 2020-05-25   16.074583   16.419571   15.958841   16.400908   16.400908
# ...                ...         ...         ...         ...         ...
# 2024-05-16  582.100159  586.436340  565.762329  569.190247  569.190247
# 2024-05-17  569.190247  584.666016  568.836731  581.178345  581.178345
# 2024-05-18  581.178345  581.987183  575.018555  580.481140  580.481140
# 2024-05-19  580.481567  581.876709  572.369629  574.631653  574.631653
# 2024-05-20  574.631653  601.563843  569.523560  600.616333  600.616333
#
#                 Volume
# Date
# 2020-05-21   283593221
# 2020-05-22   308017283
# 2020-05-23   281071630
# 2020-05-24   250849075
# 2020-05-25   295250983
# ...                ...
# 2024-05-16  1911862000
# 2024-05-17  1557134929
# 2024-05-18  1358737176
# 2024-05-19  1298887094
# 2024-05-20  2145457267
#
# [1461 rows x 6 columns]

# %% [markdown]
# ## 2. Plotting Data

# %% [markdown]
# ### 2.1 Plot High & Low

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
# x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]
x_dates = stock_data.index

plt.plot(x_dates, stock_data['High'], label='High')
plt.plot(x_dates, stock_data['Low'], label='Low')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ### 2.2 Plot Open & Close

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
# x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]
x_dates = stock_data.index

plt.plot(x_dates, stock_data['Open'], label='Open')
plt.plot(x_dates, stock_data['Close'], label='Close')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ## 3. Stock Prediction

# %% [markdown]
# ### 3.1 Normalize or Rescale

# %%
features = stock_data.iloc[:, 0:4]
sc = StandardScaler()
features_scaled = sc.fit_transform(features.values)
stock_data_ft = pd.DataFrame(columns=features.columns, data=features_scaled, index=features.index)

# Simpan objek StandardScaler
joblib.dump(sc, 'standard_scaler.pkl')
# Out:
# ['standard_scaler.pkl']

# %% [markdown]
# ### 3.2 Train & Test

# %% [markdown]
# #### 3.2.1 Splitting

# %%
def lstm_split(data, n_steps):
  X, y = [], []
  for i in range(len(data) - n_steps):
    X.append(data[i:i + n_steps, :-1])
    y.append(data[i + n_steps-1, -1])

  return np.array(X), np.array(y)

# %%
n_steps = 6
X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

train_split = 0.8
split_idx = int(np.ceil(len(X1)*train_split))
date_index = stock_data_ft.index

X_train, X_test = X1[:split_idx], X1[split_idx:]
y_train, y_test = y1[:split_idx], y1[split_idx:]
X_train_date, X_test_date = date_index[n_steps-1:split_idx + n_steps-1], date_index[split_idx + n_steps-1:len(X1) + n_steps-1]

print(X1.shape, X_train.shape, X_test.shape, y_test.shape)
# Out:
# (1455, 6, 3) (1164, 6, 3) (291, 6, 3) (291,)

# %% [markdown]
# #### 3.2.2 Training

# %%
lstm = Sequential()
lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
lstm.add(LSTM(50, activation="relu"))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error', optimizer='adam')
lstm.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 6, 50)             10800
#
#  lstm_11 (LSTM)              (None, 50)                20200
#
#  dense_5 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 31051 (121.29 KB)
# Trainable params: 31051 (121.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = lstm.fit(X_train, y_train, epochs=205, batch_size=4, verbose=2, shuffle=False)
# Out:
# Epoch 1/205
# 291/291 - 4s - loss: 0.2570 - 4s/epoch - 12ms/step
# Epoch 2/205
# 291/291 - 1s - loss: 0.0458 - 1s/epoch - 5ms/step
# Epoch 3/205
# 291/291 - 1s - loss: 0.0274 - 1s/epoch - 5ms/step
# Epoch 4/205
# 291/291 - 1s - loss: 0.0241 - 1s/epoch - 5ms/step
# Epoch 5/205
# 291/291 - 1s - loss: 0.0272 - 1s/epoch - 5ms/step
# Epoch 6/205
# 291/291 - 2s - loss: 0.0199 - 2s/epoch - 6ms/step
# Epoch 7/205
# 291/291 - 2s - loss: 0.0169 - 2s/epoch - 8ms/step
# Epoch 8/205
# 291/291 - 2s - loss: 0.0156 - 2s/epoch - 5ms/step
# Epoch 9/205
# 291/291 - 1s - loss: 0.0142 - 1s/epoch - 5ms/step
# Epoch 10/205
# 291/291 - 1s - loss: 0.0126 - 1s/epoch - 5ms/step
# Epoch 11/205
# 291/291 - 1s - loss: 0.0110 - 1s/epoch - 5ms/step
# Epoch 12/205
# 291/291 - 1s - loss: 0.0102 - 1s/epoch - 5ms/step
# Epoch 13/205
# 291/291 - 1s - loss: 0.0097 - 1s/epoch - 5ms/step
# Epoch 14/205
# 291/291 - 1s - loss: 0.0095 - 1s/epoch - 5ms/step
# Epoch 15/205
# 291/291 - 2s - loss: 0.0092 - 2s/epoch - 7ms/step
# Epoch 16/205
# 291/291 - 2s - loss: 0.0095 - 2s/epoch - 6ms/step
# Epoch 17/205
# 291/291 - 1s - loss: 0.0099 - 1s/epoch - 5ms/step
# Epoch 18/205
# 291/291 - 1s - loss: 0.0091 - 1s/epoch - 5ms/step
# Epoch 19/205
# 291/291 - 1s - loss: 0.0089 - 1s/epoch - 5ms/step
# Epoch 20/205
# 291/291 - 1s - loss: 0.0090 - 1s/epoch - 5ms/step
# Epoch 21/205
# 291/291 - 1s - loss: 0.0081 - 1s/epoch - 5ms/step
# Epoch 22/205
# 291/291 - 1s - loss: 0.0083 - 1s/epoch - 5ms/step
# Epoch 23/205
# 291/291 - 2s - loss: 0.0075 - 2s/epoch - 5ms/step
# Epoch 24/205
# 291/291 - 2s - loss: 0.0075 - 2s/epoch - 7ms/step
# Epoch 25/205
# 291/291 - 2s - loss: 0.0063 - 2s/epoch - 6ms/step
# Epoch 26/205
# 291/291 - 1s - loss: 0.0061 - 1s/epoch - 5ms/step
# Epoch 27/205
# 291/291 - 1s - loss: 0.0072 - 1s/epoch - 5ms/step
# Epoch 28/205
# 291/291 - 1s - loss: 0.0083 - 1s/epoch - 5ms/step
# Epoch 29/205
# 291/291 - 1s - loss: 0.0095 - 1s/epoch - 5ms/step
# Epoch 30/205
# 291/291 - 1s - loss: 0.0076 - 1s/epoch - 5ms/step
# Epoch 31/205
# 291/291 - 1s - loss: 0.0072 - 1s/epoch - 5ms/step
# Epoch 32/205
# 291/291 - 2s - loss: 0.0085 - 2s/epoch - 6ms/step
# Epoch 33/205
# 291/291 - 2s - loss: 0.0056 - 2s/epoch - 7ms/step
# Epoch 34/205
# 291/291 - 3s - loss: 0.0055 - 3s/epoch - 10ms/step
# Epoch 35/205
# 291/291 - 2s - loss: 0.0050 - 2s/epoch - 7ms/step
# Epoch 36/205
# 291/291 - 1s - loss: 0.0052 - 1s/epoch - 5ms/step
# Epoch 37/205
# 291/291 - 1s - loss: 0.0049 - 1s/epoch - 5ms/step
# Epoch 38/205
# 291/291 - 1s - loss: 0.0056 - 1s/epoch - 5ms/step
# Epoch 39/205
# 291/291 - 2s - loss: 0.0069 - 2s/epoch - 6ms/step
# Epoch 40/205
# 291/291 - 2s - loss: 0.0056 - 2s/epoch - 7ms/step
# Epoch 41/205
# 291/291 - 2s - loss: 0.0055 - 2s/epoch - 6ms/step
# Epoch 42/205
# 291/291 - 1s - loss: 0.0060 - 1s/epoch - 5ms/step
# Epoch 43/205
# 291/291 - 1s - loss: 0.0085 - 1s/epoch - 5ms/step
# Epoch 44/205
# 291/291 - 1s - loss: 0.0067 - 1s/epoch - 5ms/step
# Epoch 45/205
# 291/291 - 1s - loss: 0.0055 - 1s/epoch - 5ms/step
# Epoch 46/205
# 291/291 - 1s - loss: 0.0046 - 1s/epoch - 5ms/step
# Epoch 47/205
# 291/291 - 1s - loss: 0.0047 - 1s/epoch - 5ms/step
# Epoch 48/205
# 291/291 - 2s - loss: 0.0042 - 2s/epoch - 7ms/step
# Epoch 49/205
# 291/291 - 2s - loss: 0.0043 - 2s/epoch - 7ms/step
# Epoch 50/205
# 291/291 - 2s - loss: 0.0042 - 2s/epoch - 5ms/step
# Epoch 51/205
# 291/291 - 1s - loss: 0.0043 - 1s/epoch - 5ms/step
# Epoch 52/205
# 291/291 - 1s - loss: 0.0047 - 1s/epoch - 5ms/step
# Epoch 53/205
# 291/291 - 1s - loss: 0.0042 - 1s/epoch - 5ms/step
# Epoch 54/205
# 291/291 - 1s - loss: 0.0045 - 1s/epoch - 5ms/step
# Epoch 55/205
# 291/291 - 1s - loss: 0.0095 - 1s/epoch - 5ms/step
# Epoch 56/205
# 291/291 - 2s - loss: 0.0039 - 2s/epoch - 6ms/step
# Epoch 57/205
# 291/291 - 2s - loss: 0.0035 - 2s/epoch - 8ms/step
# Epoch 58/205
# 291/291 - 2s - loss: 0.0034 - 2s/epoch - 6ms/step
# Epoch 59/205
# 291/291 - 1s - loss: 0.0032 - 1s/epoch - 5ms/step
# Epoch 60/205
# 291/291 - 1s - loss: 0.0029 - 1s/epoch - 5ms/step
# Epoch 61/205
# 291/291 - 1s - loss: 0.0032 - 1s/epoch - 5ms/step
# Epoch 62/205
# 291/291 - 1s - loss: 0.0028 - 1s/epoch - 5ms/step
# Epoch 63/205
# 291/291 - 1s - loss: 0.0032 - 1s/epoch - 5ms/step
# Epoch 64/205
# 291/291 - 1s - loss: 0.0033 - 1s/epoch - 5ms/step
# Epoch 65/205
# 291/291 - 2s - loss: 0.0033 - 2s/epoch - 6ms/step
# Epoch 66/205
# 291/291 - 2s - loss: 0.0035 - 2s/epoch - 8ms/step
# Epoch 67/205
# 291/291 - 1s - loss: 0.0042 - 1s/epoch - 5ms/step
# Epoch 68/205
# 291/291 - 1s - loss: 0.0038 - 1s/epoch - 5ms/step
# Epoch 69/205
# 291/291 - 1s - loss: 0.0033 - 1s/epoch - 5ms/step
# Epoch 70/205
# 291/291 - 1s - loss: 0.0037 - 1s/epoch - 5ms/step
# Epoch 71/205
# 291/291 - 1s - loss: 0.0036 - 1s/epoch - 5ms/step
# Epoch 72/205
# 291/291 - 1s - loss: 0.0049 - 1s/epoch - 5ms/step
# Epoch 73/205
# 291/291 - 1s - loss: 0.0054 - 1s/epoch - 5ms/step
# Epoch 74/205
# 291/291 - 2s - loss: 0.0027 - 2s/epoch - 7ms/step
# Epoch 75/205
# 291/291 - 2s - loss: 0.0028 - 2s/epoch - 7ms/step
# Epoch 76/205
# 291/291 - 1s - loss: 0.0027 - 1s/epoch - 5ms/step
# Epoch 77/205
# 291/291 - 1s - loss: 0.0032 - 1s/epoch - 5ms/step
# Epoch 78/205
# 291/291 - 1s - loss: 0.0035 - 1s/epoch - 5ms/step
# Epoch 79/205
# 291/291 - 1s - loss: 0.0038 - 1s/epoch - 5ms/step
# Epoch 80/205
# 291/291 - 1s - loss: 0.0055 - 1s/epoch - 5ms/step
# Epoch 81/205
# 291/291 - 1s - loss: 0.0038 - 1s/epoch - 5ms/step
# Epoch 82/205
# 291/291 - 2s - loss: 0.0048 - 2s/epoch - 6ms/step
# Epoch 83/205
# 291/291 - 3s - loss: 0.0052 - 3s/epoch - 9ms/step
# Epoch 84/205
# 291/291 - 1s - loss: 0.0053 - 1s/epoch - 5ms/step
# Epoch 85/205
# 291/291 - 1s - loss: 0.0026 - 1s/epoch - 5ms/step
# Epoch 86/205
# 291/291 - 1s - loss: 0.0043 - 1s/epoch - 5ms/step
# Epoch 87/205
# 291/291 - 1s - loss: 0.0047 - 1s/epoch - 4ms/step
# Epoch 88/205
# 291/291 - 1s - loss: 0.0027 - 1s/epoch - 5ms/step
# Epoch 89/205
# 291/291 - 1s - loss: 0.0047 - 1s/epoch - 5ms/step
# Epoch 90/205
# 291/291 - 1s - loss: 0.0087 - 1s/epoch - 5ms/step
# Epoch 91/205
# 291/291 - 2s - loss: 0.0046 - 2s/epoch - 6ms/step
# Epoch 92/205
# 291/291 - 2s - loss: 0.0022 - 2s/epoch - 7ms/step
# Epoch 93/205
# 291/291 - 1s - loss: 0.0022 - 1s/epoch - 5ms/step
# Epoch 94/205
# 291/291 - 1s - loss: 0.0021 - 1s/epoch - 5ms/step
# Epoch 95/205
# 291/291 - 1s - loss: 0.0021 - 1s/epoch - 4ms/step
# Epoch 96/205
# 291/291 - 1s - loss: 0.0021 - 1s/epoch - 5ms/step
# Epoch 97/205
# 291/291 - 1s - loss: 0.0021 - 1s/epoch - 5ms/step
# Epoch 98/205
# 291/291 - 1s - loss: 0.0020 - 1s/epoch - 5ms/step
# Epoch 99/205
# 291/291 - 1s - loss: 0.0020 - 1s/epoch - 5ms/step
# Epoch 100/205
# 291/291 - 2s - loss: 0.0019 - 2s/epoch - 6ms/step
# Epoch 101/205
# 291/291 - 2s - loss: 0.0020 - 2s/epoch - 7ms/step
# Epoch 102/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 103/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 104/205
# 291/291 - 2s - loss: 0.0020 - 2s/epoch - 5ms/step
# Epoch 105/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 106/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 107/205
# 291/291 - 1s - loss: 0.0020 - 1s/epoch - 5ms/step
# Epoch 108/205
# 291/291 - 1s - loss: 0.0018 - 1s/epoch - 5ms/step
# Epoch 109/205
# 291/291 - 2s - loss: 0.0020 - 2s/epoch - 7ms/step
# Epoch 110/205
# 291/291 - 2s - loss: 0.0021 - 2s/epoch - 7ms/step
# Epoch 111/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 112/205
# 291/291 - 1s - loss: 0.0020 - 1s/epoch - 5ms/step
# Epoch 113/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 114/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 115/205
# 291/291 - 1s - loss: 0.0020 - 1s/epoch - 5ms/step
# Epoch 116/205
# 291/291 - 1s - loss: 0.0021 - 1s/epoch - 5ms/step
# Epoch 117/205
# 291/291 - 2s - loss: 0.0023 - 2s/epoch - 6ms/step
# Epoch 118/205
# 291/291 - 2s - loss: 0.0022 - 2s/epoch - 8ms/step
# Epoch 119/205
# 291/291 - 2s - loss: 0.0025 - 2s/epoch - 5ms/step
# Epoch 120/205
# 291/291 - 1s - loss: 0.0039 - 1s/epoch - 5ms/step
# Epoch 121/205
# 291/291 - 1s - loss: 0.0056 - 1s/epoch - 5ms/step
# Epoch 122/205
# 291/291 - 1s - loss: 0.0017 - 1s/epoch - 5ms/step
# Epoch 123/205
# 291/291 - 1s - loss: 0.0018 - 1s/epoch - 5ms/step
# Epoch 124/205
# 291/291 - 2s - loss: 0.0017 - 2s/epoch - 5ms/step
# Epoch 125/205
# 291/291 - 1s - loss: 0.0017 - 1s/epoch - 5ms/step
# Epoch 126/205
# 291/291 - 2s - loss: 0.0018 - 2s/epoch - 7ms/step
# Epoch 127/205
# 291/291 - 2s - loss: 0.0017 - 2s/epoch - 7ms/step
# Epoch 128/205
# 291/291 - 1s - loss: 0.0017 - 1s/epoch - 5ms/step
# Epoch 129/205
# 291/291 - 1s - loss: 0.0016 - 1s/epoch - 5ms/step
# Epoch 130/205
# 291/291 - 1s - loss: 0.0018 - 1s/epoch - 5ms/step
# Epoch 131/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 132/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 133/205
# 291/291 - 2s - loss: 0.0018 - 2s/epoch - 5ms/step
# Epoch 134/205
# 291/291 - 2s - loss: 0.0019 - 2s/epoch - 5ms/step
# Epoch 135/205
# 291/291 - 2s - loss: 0.0019 - 2s/epoch - 7ms/step
# Epoch 136/205
# 291/291 - 2s - loss: 0.0020 - 2s/epoch - 6ms/step
# Epoch 137/205
# 291/291 - 1s - loss: 0.0023 - 1s/epoch - 5ms/step
# Epoch 138/205
# 291/291 - 1s - loss: 0.0028 - 1s/epoch - 5ms/step
# Epoch 139/205
# 291/291 - 1s - loss: 0.0041 - 1s/epoch - 5ms/step
# Epoch 140/205
# 291/291 - 1s - loss: 0.0054 - 1s/epoch - 5ms/step
# Epoch 141/205
# 291/291 - 1s - loss: 0.0015 - 1s/epoch - 5ms/step
# Epoch 142/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 143/205
# 291/291 - 2s - loss: 0.0019 - 2s/epoch - 6ms/step
# Epoch 144/205
# 291/291 - 2s - loss: 0.0018 - 2s/epoch - 7ms/step
# Epoch 145/205
# 291/291 - 2s - loss: 0.0017 - 2s/epoch - 5ms/step
# Epoch 146/205
# 291/291 - 1s - loss: 0.0018 - 1s/epoch - 5ms/step
# Epoch 147/205
# 291/291 - 1s - loss: 0.0017 - 1s/epoch - 5ms/step
# Epoch 148/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 149/205
# 291/291 - 1s - loss: 0.0018 - 1s/epoch - 5ms/step
# Epoch 150/205
# 291/291 - 1s - loss: 0.0017 - 1s/epoch - 5ms/step
# Epoch 151/205
# 291/291 - 1s - loss: 0.0021 - 1s/epoch - 5ms/step
# Epoch 152/205
# 291/291 - 2s - loss: 0.0018 - 2s/epoch - 6ms/step
# Epoch 153/205
# 291/291 - 2s - loss: 0.0022 - 2s/epoch - 7ms/step
# Epoch 154/205
# 291/291 - 1s - loss: 0.0022 - 1s/epoch - 5ms/step
# Epoch 155/205
# 291/291 - 1s - loss: 0.0040 - 1s/epoch - 5ms/step
# Epoch 156/205
# 291/291 - 1s - loss: 0.0021 - 1s/epoch - 5ms/step
# Epoch 157/205
# 291/291 - 1s - loss: 0.0058 - 1s/epoch - 5ms/step
# Epoch 158/205
# 291/291 - 1s - loss: 0.0050 - 1s/epoch - 5ms/step
# Epoch 159/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 160/205
# 291/291 - 1s - loss: 0.0020 - 1s/epoch - 5ms/step
# Epoch 161/205
# 291/291 - 2s - loss: 0.0019 - 2s/epoch - 6ms/step
# Epoch 162/205
# 291/291 - 2s - loss: 0.0022 - 2s/epoch - 7ms/step
# Epoch 163/205
# 291/291 - 1s - loss: 0.0022 - 1s/epoch - 5ms/step
# Epoch 164/205
# 291/291 - 1s - loss: 0.0025 - 1s/epoch - 5ms/step
# Epoch 165/205
# 291/291 - 1s - loss: 0.0027 - 1s/epoch - 5ms/step
# Epoch 166/205
# 291/291 - 1s - loss: 0.0037 - 1s/epoch - 5ms/step
# Epoch 167/205
# 291/291 - 1s - loss: 0.0024 - 1s/epoch - 5ms/step
# Epoch 168/205
# 291/291 - 1s - loss: 0.0054 - 1s/epoch - 5ms/step
# Epoch 169/205
# 291/291 - 1s - loss: 0.0016 - 1s/epoch - 5ms/step
# Epoch 170/205
# 291/291 - 2s - loss: 0.0016 - 2s/epoch - 7ms/step
# Epoch 171/205
# 291/291 - 2s - loss: 0.0018 - 2s/epoch - 7ms/step
# Epoch 172/205
# 291/291 - 1s - loss: 0.0027 - 1s/epoch - 5ms/step
# Epoch 173/205
# 291/291 - 1s - loss: 0.0023 - 1s/epoch - 5ms/step
# Epoch 174/205
# 291/291 - 1s - loss: 0.0045 - 1s/epoch - 5ms/step
# Epoch 175/205
# 291/291 - 1s - loss: 0.0018 - 1s/epoch - 5ms/step
# Epoch 176/205
# 291/291 - 1s - loss: 0.0018 - 1s/epoch - 5ms/step
# Epoch 177/205
# 291/291 - 1s - loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 178/205
# 291/291 - 2s - loss: 0.0028 - 2s/epoch - 6ms/step
# Epoch 179/205
# 291/291 - 2s - loss: 0.0037 - 2s/epoch - 7ms/step
# Epoch 180/205
# 291/291 - 2s - loss: 0.0016 - 2s/epoch - 6ms/step
# Epoch 181/205
# 291/291 - 1s - loss: 0.0016 - 1s/epoch - 5ms/step
# Epoch 182/205
# 291/291 - 1s - loss: 0.0016 - 1s/epoch - 5ms/step
# Epoch 183/205
# 291/291 - 1s - loss: 0.0015 - 1s/epoch - 5ms/step
# Epoch 184/205
# 291/291 - 1s - loss: 0.0018 - 1s/epoch - 5ms/step
# Epoch 185/205
# 291/291 - 1s - loss: 0.0018 - 1s/epoch - 5ms/step
# Epoch 186/205
# 291/291 - 1s - loss: 0.0022 - 1s/epoch - 5ms/step
# Epoch 187/205
# 291/291 - 2s - loss: 0.0032 - 2s/epoch - 6ms/step
# Epoch 188/205
# 291/291 - 2s - loss: 0.0032 - 2s/epoch - 7ms/step
# Epoch 189/205
# 291/291 - 2s - loss: 0.0040 - 2s/epoch - 6ms/step
# Epoch 190/205
# 291/291 - 1s - loss: 0.0020 - 1s/epoch - 5ms/step
# Epoch 191/205
# 291/291 - 1s - loss: 0.0015 - 1s/epoch - 5ms/step
# Epoch 192/205
# 291/291 - 1s - loss: 0.0015 - 1s/epoch - 5ms/step
# Epoch 193/205
# 291/291 - 1s - loss: 0.0013 - 1s/epoch - 5ms/step
# Epoch 194/205
# 291/291 - 1s - loss: 0.0013 - 1s/epoch - 5ms/step
# Epoch 195/205
# 291/291 - 1s - loss: 0.0013 - 1s/epoch - 5ms/step
# Epoch 196/205
# 291/291 - 2s - loss: 0.0012 - 2s/epoch - 6ms/step
# Epoch 197/205
# 291/291 - 2s - loss: 0.0013 - 2s/epoch - 8ms/step
# Epoch 198/205
# 291/291 - 1s - loss: 0.0014 - 1s/epoch - 5ms/step
# Epoch 199/205
# 291/291 - 1s - loss: 0.0015 - 1s/epoch - 5ms/step
# Epoch 200/205
# 291/291 - 1s - loss: 0.0029 - 1s/epoch - 5ms/step
# Epoch 201/205
# 291/291 - 1s - loss: 0.0048 - 1s/epoch - 5ms/step
# Epoch 202/205
# 291/291 - 1s - loss: 0.0020 - 1s/epoch - 5ms/step
# Epoch 203/205
# 291/291 - 1s - loss: 0.0030 - 1s/epoch - 5ms/step
# Epoch 204/205
# 291/291 - 1s - loss: 0.0043 - 1s/epoch - 5ms/step
# Epoch 205/205
# 291/291 - 2s - loss: 0.0034 - 2s/epoch - 7ms/step

# %%
plt.plot(history.history['loss'])
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# #### 3.2.3 Evaluation

# %%
# Make predictions
y_pred = lstm.predict(X_test)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(X_test_date, y_test, label='True Values', color='blue')
plt.plot(X_test_date, y_pred, label='Predicted Values', color='red')
plt.title('True Values vs Predicted Values')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 10/10 [==============================] - 0s 3ms/step

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
mape = mean_absolute_percentage_error(y_test, y_pred)
print("RMSE: ", rmse)
print("MAPE: ", mape)
# Out:
# RMSE:  0.07061941297651128
# MAPE:  0.07482495898367715

# %%
# Save Model
lstm.save("predict_nflx.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# #### 3.2.4 Compare Performance

# %%
n_steps_list = [2, 6, 13, 20]
results = []
models = []

for n_steps in n_steps_list:
    X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

    split_idx = int(np.ceil(len(X1) * 0.8))
    X_train, X_test = X1[:split_idx], X1[split_idx:]
    y_train, y_test = y1[:split_idx], y1[split_idx:]

    lstm = Sequential()
    lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
    lstm.add(LSTM(50, activation='relu'))
    lstm.add(Dense(1))
    lstm.compile(loss='mean_squared_error', optimizer='adam')

    lstm.fit(X_train, y_train, epochs=100, batch_size=4, verbose=2, shuffle=False)

    y_pred = lstm.predict(X_test)
    y_pred = y_pred.flatten()  # Ensure y_pred is a 1D array

    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mape = mean_absolute_percentage_error(y_test, y_pred)

    results.append((n_steps, rmse, mape))
    models.append(lstm)
# Out:
# Epoch 1/100
# 292/292 - 4s - loss: 0.4418 - 4s/epoch - 13ms/step
# Epoch 2/100
# 292/292 - 1s - loss: 0.0162 - 853ms/epoch - 3ms/step
# Epoch 3/100
# 292/292 - 1s - loss: 0.0135 - 919ms/epoch - 3ms/step
# Epoch 4/100
# 292/292 - 1s - loss: 0.0106 - 882ms/epoch - 3ms/step
# Epoch 5/100
# 292/292 - 1s - loss: 0.0094 - 902ms/epoch - 3ms/step
# Epoch 6/100
# 292/292 - 1s - loss: 0.0082 - 887ms/epoch - 3ms/step
# Epoch 7/100
# 292/292 - 1s - loss: 0.0069 - 821ms/epoch - 3ms/step
# Epoch 8/100
# 292/292 - 1s - loss: 0.0068 - 865ms/epoch - 3ms/step
# Epoch 9/100
# 292/292 - 1s - loss: 0.0068 - 861ms/epoch - 3ms/step
# Epoch 10/100
# 292/292 - 1s - loss: 0.0068 - 866ms/epoch - 3ms/step
# Epoch 11/100
# 292/292 - 1s - loss: 0.0065 - 862ms/epoch - 3ms/step
# Epoch 12/100
# 292/292 - 1s - loss: 0.0064 - 1s/epoch - 5ms/step
# Epoch 13/100
# 292/292 - 1s - loss: 0.0056 - 1s/epoch - 5ms/step
# Epoch 14/100
# 292/292 - 1s - loss: 0.0055 - 1s/epoch - 4ms/step
# Epoch 15/100
# 292/292 - 1s - loss: 0.0056 - 952ms/epoch - 3ms/step
# Epoch 16/100
# 292/292 - 1s - loss: 0.0064 - 908ms/epoch - 3ms/step
# Epoch 17/100
# 292/292 - 1s - loss: 0.0055 - 895ms/epoch - 3ms/step
# Epoch 18/100
# 292/292 - 1s - loss: 0.0052 - 923ms/epoch - 3ms/step
# Epoch 19/100
# 292/292 - 1s - loss: 0.0049 - 900ms/epoch - 3ms/step
# Epoch 20/100
# 292/292 - 1s - loss: 0.0051 - 911ms/epoch - 3ms/step
# Epoch 21/100
# 292/292 - 1s - loss: 0.0047 - 857ms/epoch - 3ms/step
# Epoch 22/100
# 292/292 - 1s - loss: 0.0045 - 887ms/epoch - 3ms/step
# Epoch 23/100
# 292/292 - 1s - loss: 0.0048 - 866ms/epoch - 3ms/step
# Epoch 24/100
# 292/292 - 1s - loss: 0.0047 - 826ms/epoch - 3ms/step
# Epoch 25/100
# 292/292 - 1s - loss: 0.0047 - 1s/epoch - 4ms/step
# Epoch 26/100
# 292/292 - 1s - loss: 0.0072 - 1s/epoch - 5ms/step
# Epoch 27/100
# 292/292 - 1s - loss: 0.0064 - 1s/epoch - 5ms/step
# Epoch 28/100
# 292/292 - 1s - loss: 0.0041 - 867ms/epoch - 3ms/step
# Epoch 29/100
# 292/292 - 1s - loss: 0.0057 - 872ms/epoch - 3ms/step
# Epoch 30/100
# 292/292 - 1s - loss: 0.0046 - 827ms/epoch - 3ms/step
# Epoch 31/100
# 292/292 - 1s - loss: 0.0033 - 844ms/epoch - 3ms/step
# Epoch 32/100
# 292/292 - 1s - loss: 0.0035 - 877ms/epoch - 3ms/step
# Epoch 33/100
# 292/292 - 1s - loss: 0.0040 - 922ms/epoch - 3ms/step
# Epoch 34/100
# 292/292 - 1s - loss: 0.0039 - 966ms/epoch - 3ms/step
# Epoch 35/100
# 292/292 - 1s - loss: 0.0037 - 951ms/epoch - 3ms/step
# Epoch 36/100
# 292/292 - 1s - loss: 0.0037 - 876ms/epoch - 3ms/step
# Epoch 37/100
# 292/292 - 1s - loss: 0.0040 - 889ms/epoch - 3ms/step
# Epoch 38/100
# 292/292 - 1s - loss: 0.0039 - 833ms/epoch - 3ms/step
# Epoch 39/100
# 292/292 - 1s - loss: 0.0034 - 1s/epoch - 5ms/step
# Epoch 40/100
# 292/292 - 2s - loss: 0.0035 - 2s/epoch - 5ms/step
# Epoch 41/100
# 292/292 - 1s - loss: 0.0039 - 1s/epoch - 4ms/step
# Epoch 42/100
# 292/292 - 1s - loss: 0.0037 - 888ms/epoch - 3ms/step
# Epoch 43/100
# 292/292 - 1s - loss: 0.0036 - 859ms/epoch - 3ms/step
# Epoch 44/100
# 292/292 - 1s - loss: 0.0032 - 886ms/epoch - 3ms/step
# Epoch 45/100
# 292/292 - 1s - loss: 0.0034 - 917ms/epoch - 3ms/step
# Epoch 46/100
# 292/292 - 1s - loss: 0.0036 - 908ms/epoch - 3ms/step
# Epoch 47/100
# 292/292 - 1s - loss: 0.0036 - 905ms/epoch - 3ms/step
# Epoch 48/100
# 292/292 - 1s - loss: 0.0035 - 942ms/epoch - 3ms/step
# Epoch 49/100
# 292/292 - 1s - loss: 0.0029 - 969ms/epoch - 3ms/step
# Epoch 50/100
# 292/292 - 1s - loss: 0.0032 - 932ms/epoch - 3ms/step
# Epoch 51/100
# 292/292 - 1s - loss: 0.0031 - 1s/epoch - 4ms/step
# Epoch 52/100
# 292/292 - 1s - loss: 0.0034 - 1s/epoch - 5ms/step
# Epoch 53/100
# 292/292 - 2s - loss: 0.0036 - 2s/epoch - 5ms/step
# Epoch 54/100
# 292/292 - 1s - loss: 0.0030 - 975ms/epoch - 3ms/step
# Epoch 55/100
# 292/292 - 1s - loss: 0.0028 - 996ms/epoch - 3ms/step
# Epoch 56/100
# 292/292 - 1s - loss: 0.0034 - 870ms/epoch - 3ms/step
# Epoch 57/100
# 292/292 - 1s - loss: 0.0029 - 876ms/epoch - 3ms/step
# Epoch 58/100
# 292/292 - 1s - loss: 0.0034 - 889ms/epoch - 3ms/step
# Epoch 59/100
# 292/292 - 1s - loss: 0.0035 - 929ms/epoch - 3ms/step
# Epoch 60/100
# 292/292 - 1s - loss: 0.0032 - 918ms/epoch - 3ms/step
# Epoch 61/100
# 292/292 - 1s - loss: 0.0028 - 937ms/epoch - 3ms/step
# Epoch 62/100
# 292/292 - 1s - loss: 0.0029 - 944ms/epoch - 3ms/step
# Epoch 63/100
# 292/292 - 1s - loss: 0.0031 - 936ms/epoch - 3ms/step
# Epoch 64/100
# 292/292 - 1s - loss: 0.0034 - 950ms/epoch - 3ms/step
# Epoch 65/100
# 292/292 - 1s - loss: 0.0035 - 1s/epoch - 5ms/step
# Epoch 66/100
# 292/292 - 2s - loss: 0.0031 - 2s/epoch - 5ms/step
# Epoch 67/100
# 292/292 - 1s - loss: 0.0026 - 1s/epoch - 4ms/step
# Epoch 68/100
# 292/292 - 1s - loss: 0.0030 - 921ms/epoch - 3ms/step
# Epoch 69/100
# 292/292 - 1s - loss: 0.0031 - 882ms/epoch - 3ms/step
# Epoch 70/100
# 292/292 - 1s - loss: 0.0035 - 920ms/epoch - 3ms/step
# Epoch 71/100
# 292/292 - 1s - loss: 0.0032 - 878ms/epoch - 3ms/step
# Epoch 72/100
# 292/292 - 1s - loss: 0.0029 - 865ms/epoch - 3ms/step
# Epoch 73/100
# 292/292 - 1s - loss: 0.0029 - 886ms/epoch - 3ms/step
# Epoch 74/100
# 292/292 - 1s - loss: 0.0029 - 925ms/epoch - 3ms/step
# Epoch 75/100
# 292/292 - 1s - loss: 0.0032 - 865ms/epoch - 3ms/step
# Epoch 76/100
# 292/292 - 1s - loss: 0.0033 - 883ms/epoch - 3ms/step
# Epoch 77/100
# 292/292 - 1s - loss: 0.0031 - 874ms/epoch - 3ms/step
# Epoch 78/100
# 292/292 - 1s - loss: 0.0030 - 1s/epoch - 4ms/step
# Epoch 79/100
# 292/292 - 1s - loss: 0.0029 - 1s/epoch - 5ms/step
# Epoch 80/100
# 292/292 - 1s - loss: 0.0029 - 1s/epoch - 5ms/step
# Epoch 81/100
# 292/292 - 1s - loss: 0.0030 - 902ms/epoch - 3ms/step
# Epoch 82/100
# 292/292 - 1s - loss: 0.0028 - 920ms/epoch - 3ms/step
# Epoch 83/100
# 292/292 - 1s - loss: 0.0028 - 910ms/epoch - 3ms/step
# Epoch 84/100
# 292/292 - 1s - loss: 0.0031 - 915ms/epoch - 3ms/step
# Epoch 85/100
# 292/292 - 1s - loss: 0.0032 - 936ms/epoch - 3ms/step
# Epoch 86/100
# 292/292 - 1s - loss: 0.0030 - 993ms/epoch - 3ms/step
# Epoch 87/100
# 292/292 - 1s - loss: 0.0030 - 984ms/epoch - 3ms/step
# Epoch 88/100
# 292/292 - 1s - loss: 0.0029 - 913ms/epoch - 3ms/step
# Epoch 89/100
# 292/292 - 1s - loss: 0.0030 - 949ms/epoch - 3ms/step
# Epoch 90/100
# 292/292 - 1s - loss: 0.0032 - 971ms/epoch - 3ms/step
# Epoch 91/100
# 292/292 - 1s - loss: 0.0030 - 1s/epoch - 5ms/step
# Epoch 92/100
# 292/292 - 2s - loss: 0.0030 - 2s/epoch - 5ms/step
# Epoch 93/100
# 292/292 - 1s - loss: 0.0030 - 1s/epoch - 4ms/step
# Epoch 94/100
# 292/292 - 1s - loss: 0.0030 - 877ms/epoch - 3ms/step
# Epoch 95/100
# 292/292 - 1s - loss: 0.0032 - 898ms/epoch - 3ms/step
# Epoch 96/100
# 292/292 - 1s - loss: 0.0032 - 927ms/epoch - 3ms/step
# Epoch 97/100
# 292/292 - 1s - loss: 0.0031 - 880ms/epoch - 3ms/step
# Epoch 98/100
# 292/292 - 1s - loss: 0.0032 - 906ms/epoch - 3ms/step
# Epoch 99/100
# 292/292 - 1s - loss: 0.0032 - 975ms/epoch - 3ms/step
# Epoch 100/100
# 292/292 - 1s - loss: 0.0032 - 907ms/epoch - 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# Epoch 1/100
# 291/291 - 3s - loss: 0.2733 - 3s/epoch - 12ms/step
# Epoch 2/100
# 291/291 - 1s - loss: 0.0870 - 1s/epoch - 5ms/step
# Epoch 3/100
# 291/291 - 1s - loss: 0.0302 - 1s/epoch - 5ms/step
# Epoch 4/100
# 291/291 - 1s - loss: 0.0233 - 1s/epoch - 5ms/step
# Epoch 5/100
# 291/291 - 2s - loss: 0.0253 - 2s/epoch - 7ms/step
# Epoch 6/100
# 291/291 - 2s - loss: 0.0234 - 2s/epoch - 7ms/step
# Epoch 7/100
# 291/291 - 1s - loss: 0.0292 - 1s/epoch - 5ms/step
# Epoch 8/100
# 291/291 - 1s - loss: 0.0324 - 1s/epoch - 5ms/step
# Epoch 9/100
# 291/291 - 1s - loss: 0.0229 - 1s/epoch - 5ms/step
# Epoch 10/100
# 291/291 - 1s - loss: 0.0185 - 1s/epoch - 5ms/step
# Epoch 11/100
# 291/291 - 1s - loss: 0.0211 - 1s/epoch - 5ms/step
# Epoch 12/100
# 291/291 - 1s - loss: 0.0154 - 1s/epoch - 5ms/step
# Epoch 13/100
# 291/291 - 1s - loss: 0.0125 - 1s/epoch - 5ms/step
# Epoch 14/100
# 291/291 - 2s - loss: 0.0132 - 2s/epoch - 7ms/step
# Epoch 15/100
# 291/291 - 2s - loss: 0.0131 - 2s/epoch - 6ms/step
# Epoch 16/100
# 291/291 - 1s - loss: 0.0111 - 1s/epoch - 5ms/step
# Epoch 17/100
# 291/291 - 1s - loss: 0.0103 - 1s/epoch - 5ms/step
# Epoch 18/100
# 291/291 - 1s - loss: 0.0105 - 1s/epoch - 5ms/step
# Epoch 19/100
# 291/291 - 1s - loss: 0.0094 - 1s/epoch - 5ms/step
# Epoch 20/100
# 291/291 - 1s - loss: 0.0085 - 1s/epoch - 5ms/step
# Epoch 21/100
# 291/291 - 1s - loss: 0.0077 - 1s/epoch - 5ms/step
# Epoch 22/100
# 291/291 - 1s - loss: 0.0078 - 1s/epoch - 5ms/step
# Epoch 23/100
# 291/291 - 2s - loss: 0.0073 - 2s/epoch - 7ms/step
# Epoch 24/100
# 291/291 - 2s - loss: 0.0068 - 2s/epoch - 6ms/step
# Epoch 25/100
# 291/291 - 1s - loss: 0.0058 - 1s/epoch - 5ms/step
# Epoch 26/100
# 291/291 - 1s - loss: 0.0059 - 1s/epoch - 5ms/step
# Epoch 27/100
# 291/291 - 1s - loss: 0.0067 - 1s/epoch - 5ms/step
# Epoch 28/100
# 291/291 - 1s - loss: 0.0060 - 1s/epoch - 5ms/step
# Epoch 29/100
# 291/291 - 1s - loss: 0.0058 - 1s/epoch - 5ms/step
# Epoch 30/100
# 291/291 - 1s - loss: 0.0049 - 1s/epoch - 5ms/step
# Epoch 31/100
# 291/291 - 2s - loss: 0.0054 - 2s/epoch - 6ms/step
# Epoch 32/100
# 291/291 - 2s - loss: 0.0052 - 2s/epoch - 7ms/step
# Epoch 33/100
# 291/291 - 2s - loss: 0.0049 - 2s/epoch - 5ms/step
# Epoch 34/100
# 291/291 - 1s - loss: 0.0042 - 1s/epoch - 5ms/step
# Epoch 35/100
# 291/291 - 1s - loss: 0.0041 - 1s/epoch - 5ms/step
# Epoch 36/100
# 291/291 - 1s - loss: 0.0042 - 1s/epoch - 5ms/step
# Epoch 37/100
# 291/291 - 1s - loss: 0.0043 - 1s/epoch - 5ms/step
# Epoch 38/100
# 291/291 - 1s - loss: 0.0052 - 1s/epoch - 5ms/step
# Epoch 39/100
# 291/291 - 1s - loss: 0.0062 - 1s/epoch - 5ms/step
# Epoch 40/100
# 291/291 - 2s - loss: 0.0044 - 2s/epoch - 6ms/step
# Epoch 41/100
# 291/291 - 2s - loss: 0.0044 - 2s/epoch - 7ms/step
# Epoch 42/100
# 291/291 - 1s - loss: 0.0035 - 1s/epoch - 5ms/step
# Epoch 43/100
# 291/291 - 1s - loss: 0.0040 - 1s/epoch - 5ms/step
# Epoch 44/100
# 291/291 - 1s - loss: 0.0034 - 1s/epoch - 5ms/step
# Epoch 45/100
# 291/291 - 1s - loss: 0.0035 - 1s/epoch - 5ms/step
# Epoch 46/100
# 291/291 - 1s - loss: 0.0033 - 1s/epoch - 5ms/step
# Epoch 47/100
# 291/291 - 1s - loss: 0.0042 - 1s/epoch - 5ms/step
# Epoch 48/100
# 291/291 - 1s - loss: 0.0033 - 1s/epoch - 5ms/step
# Epoch 49/100
# 291/291 - 2s - loss: 0.0034 - 2s/epoch - 7ms/step
# Epoch 50/100
# 291/291 - 2s - loss: 0.0034 - 2s/epoch - 7ms/step
# Epoch 51/100
# 291/291 - 1s - loss: 0.0035 - 1s/epoch - 5ms/step
# Epoch 52/100
# 291/291 - 1s - loss: 0.0040 - 1s/epoch - 5ms/step
# Epoch 53/100
# 291/291 - 1s - loss: 0.0032 - 1s/epoch - 5ms/step
# Epoch 54/100
# 291/291 - 1s - loss: 0.0033 - 1s/epoch - 5ms/step
# Epoch 55/100
# 291/291 - 1s - loss: 0.0032 - 1s/epoch - 5ms/step
# Epoch 56/100
# 291/291 - 1s - loss: 0.0036 - 1s/epoch - 5ms/step
# Epoch 57/100
# 291/291 - 1s - loss: 0.0031 - 1s/epoch - 5ms/step
# Epoch 58/100
# 291/291 - 2s - loss: 0.0028 - 2s/epoch - 7ms/step
# Epoch 59/100
# 291/291 - 2s - loss: 0.0027 - 2s/epoch - 6ms/step
# Epoch 60/100
# 291/291 - 1s - loss: 0.0028 - 1s/epoch - 5ms/step
# Epoch 61/100
# 291/291 - 1s - loss: 0.0026 - 1s/epoch - 5ms/step
# Epoch 62/100
# 291/291 - 1s - loss: 0.0028 - 1s/epoch - 5ms/step
# Epoch 63/100
# 291/291 - 1s - loss: 0.0028 - 1s/epoch - 5ms/step
# Epoch 64/100
# 291/291 - 1s - loss: 0.0030 - 1s/epoch - 5ms/step
# Epoch 65/100
# 291/291 - 1s - loss: 0.0026 - 1s/epoch - 5ms/step
# Epoch 66/100
# 291/291 - 2s - loss: 0.0027 - 2s/epoch - 5ms/step
# Epoch 67/100
# 291/291 - 2s - loss: 0.0029 - 2s/epoch - 7ms/step
# Epoch 68/100
# 291/291 - 2s - loss: 0.0026 - 2s/epoch - 6ms/step
# Epoch 69/100
# 291/291 - 1s - loss: 0.0028 - 1s/epoch - 5ms/step
# Epoch 70/100
# 291/291 - 1s - loss: 0.0028 - 1s/epoch - 5ms/step
# Epoch 71/100
# 291/291 - 1s - loss: 0.0022 - 1s/epoch - 5ms/step
# Epoch 72/100
# 291/291 - 1s - loss: 0.0024 - 1s/epoch - 5ms/step
# Epoch 73/100
# 291/291 - 1s - loss: 0.0025 - 1s/epoch - 5ms/step
# Epoch 74/100
# 291/291 - 1s - loss: 0.0025 - 1s/epoch - 5ms/step
# Epoch 75/100
# 291/291 - 2s - loss: 0.0027 - 2s/epoch - 6ms/step
# Epoch 76/100
# 291/291 - 2s - loss: 0.0026 - 2s/epoch - 8ms/step
# Epoch 77/100
# 291/291 - 2s - loss: 0.0027 - 2s/epoch - 5ms/step
# Epoch 78/100
# 291/291 - 1s - loss: 0.0036 - 1s/epoch - 5ms/step
# Epoch 79/100
# 291/291 - 1s - loss: 0.0023 - 1s/epoch - 5ms/step
# Epoch 80/100
# 291/291 - 1s - loss: 0.0025 - 1s/epoch - 5ms/step
# Epoch 81/100
# 291/291 - 1s - loss: 0.0024 - 1s/epoch - 5ms/step
# Epoch 82/100
# 291/291 - 1s - loss: 0.0021 - 1s/epoch - 5ms/step
# Epoch 83/100
# 291/291 - 1s - loss: 0.0021 - 1s/epoch - 5ms/step
# Epoch 84/100
# 291/291 - 2s - loss: 0.0023 - 2s/epoch - 7ms/step
# Epoch 85/100
# 291/291 - 2s - loss: 0.0025 - 2s/epoch - 7ms/step
# Epoch 86/100
# 291/291 - 1s - loss: 0.0024 - 1s/epoch - 5ms/step
# Epoch 87/100
# 291/291 - 1s - loss: 0.0026 - 1s/epoch - 5ms/step
# Epoch 88/100
# 291/291 - 1s - loss: 0.0021 - 1s/epoch - 5ms/step
# Epoch 89/100
# 291/291 - 1s - loss: 0.0022 - 1s/epoch - 5ms/step
# Epoch 90/100
# 291/291 - 1s - loss: 0.0020 - 1s/epoch - 5ms/step
# Epoch 91/100
# 291/291 - 1s - loss: 0.0020 - 1s/epoch - 5ms/step
# Epoch 92/100
# 291/291 - 2s - loss: 0.0020 - 2s/epoch - 5ms/step
# Epoch 93/100
# 291/291 - 2s - loss: 0.0018 - 2s/epoch - 7ms/step
# Epoch 94/100
# 291/291 - 2s - loss: 0.0021 - 2s/epoch - 6ms/step
# Epoch 95/100
# 291/291 - 1s - loss: 0.0025 - 1s/epoch - 5ms/step
# Epoch 96/100
# 291/291 - 1s - loss: 0.0020 - 1s/epoch - 5ms/step
# Epoch 97/100
# 291/291 - 1s - loss: 0.0029 - 1s/epoch - 5ms/step
# Epoch 98/100
# 291/291 - 1s - loss: 0.0025 - 1s/epoch - 5ms/step
# Epoch 99/100
# 291/291 - 1s - loss: 0.0023 - 1s/epoch - 5ms/step
# Epoch 100/100
# 291/291 - 1s - loss: 0.0022 - 1s/epoch - 5ms/step
# 10/10 [==============================] - 0s 3ms/step
# Epoch 1/100
# 290/290 - 6s - loss: 0.2266 - 6s/epoch - 22ms/step
# Epoch 2/100
# 290/290 - 3s - loss: 0.0708 - 3s/epoch - 10ms/step
# Epoch 3/100
# 290/290 - 3s - loss: 0.0428 - 3s/epoch - 9ms/step
# Epoch 4/100
# 290/290 - 3s - loss: 0.0370 - 3s/epoch - 12ms/step
# Epoch 5/100
# 290/290 - 3s - loss: 0.0379 - 3s/epoch - 12ms/step
# Epoch 6/100
# 290/290 - 3s - loss: 0.0276 - 3s/epoch - 10ms/step
# Epoch 7/100
# 290/290 - 3s - loss: 0.0211 - 3s/epoch - 10ms/step
# Epoch 8/100
# 290/290 - 3s - loss: 0.0176 - 3s/epoch - 10ms/step
# Epoch 9/100
# 290/290 - 4s - loss: 0.0159 - 4s/epoch - 13ms/step
# Epoch 10/100
# 290/290 - 3s - loss: 0.0143 - 3s/epoch - 9ms/step
# Epoch 11/100
# 290/290 - 3s - loss: 0.0137 - 3s/epoch - 10ms/step
# Epoch 12/100
# 290/290 - 3s - loss: 0.0127 - 3s/epoch - 10ms/step
# Epoch 13/100
# 290/290 - 4s - loss: 0.0142 - 4s/epoch - 14ms/step
# Epoch 14/100
# 290/290 - 3s - loss: 0.0123 - 3s/epoch - 10ms/step
# Epoch 15/100
# 290/290 - 3s - loss: 0.0110 - 3s/epoch - 9ms/step
# Epoch 16/100
# 290/290 - 3s - loss: 0.0109 - 3s/epoch - 9ms/step
# Epoch 17/100
# 290/290 - 3s - loss: 0.0093 - 3s/epoch - 11ms/step
# Epoch 18/100
# 290/290 - 4s - loss: 0.0093 - 4s/epoch - 12ms/step
# Epoch 19/100
# 290/290 - 3s - loss: 0.0092 - 3s/epoch - 9ms/step
# Epoch 20/100
# 290/290 - 3s - loss: 0.0094 - 3s/epoch - 9ms/step
# Epoch 21/100
# 290/290 - 3s - loss: 0.0079 - 3s/epoch - 9ms/step
# Epoch 22/100
# 290/290 - 4s - loss: 0.0090 - 4s/epoch - 14ms/step
# Epoch 23/100
# 290/290 - 3s - loss: 0.0087 - 3s/epoch - 10ms/step
# Epoch 24/100
# 290/290 - 3s - loss: 0.0067 - 3s/epoch - 9ms/step
# Epoch 25/100
# 290/290 - 3s - loss: 0.0070 - 3s/epoch - 9ms/step
# Epoch 26/100
# 290/290 - 3s - loss: 0.0061 - 3s/epoch - 11ms/step
# Epoch 27/100
# 290/290 - 4s - loss: 0.0063 - 4s/epoch - 13ms/step
# Epoch 28/100
# 290/290 - 3s - loss: 0.0062 - 3s/epoch - 10ms/step
# Epoch 29/100
# 290/290 - 3s - loss: 0.0065 - 3s/epoch - 10ms/step
# Epoch 30/100
# 290/290 - 3s - loss: 0.0058 - 3s/epoch - 10ms/step
# Epoch 31/100
# 290/290 - 4s - loss: 0.0050 - 4s/epoch - 13ms/step
# Epoch 32/100
# 290/290 - 3s - loss: 0.0048 - 3s/epoch - 9ms/step
# Epoch 33/100
# 290/290 - 3s - loss: 0.0047 - 3s/epoch - 10ms/step
# Epoch 34/100
# 290/290 - 3s - loss: 0.0055 - 3s/epoch - 9ms/step
# Epoch 35/100
# 290/290 - 3s - loss: 0.0059 - 3s/epoch - 12ms/step
# Epoch 36/100
# 290/290 - 3s - loss: 0.0069 - 3s/epoch - 12ms/step
# Epoch 37/100
# 290/290 - 3s - loss: 0.0069 - 3s/epoch - 9ms/step
# Epoch 38/100
# 290/290 - 3s - loss: 0.0049 - 3s/epoch - 9ms/step
# Epoch 39/100
# 290/290 - 3s - loss: 0.0050 - 3s/epoch - 9ms/step
# Epoch 40/100
# 290/290 - 4s - loss: 0.0041 - 4s/epoch - 14ms/step
# Epoch 41/100
# 290/290 - 3s - loss: 0.0048 - 3s/epoch - 9ms/step
# Epoch 42/100
# 290/290 - 3s - loss: 0.0045 - 3s/epoch - 9ms/step
# Epoch 43/100
# 290/290 - 3s - loss: 0.0049 - 3s/epoch - 9ms/step
# Epoch 44/100
# 290/290 - 3s - loss: 0.0044 - 3s/epoch - 11ms/step
# Epoch 45/100
# 290/290 - 3s - loss: 0.0042 - 3s/epoch - 12ms/step
# Epoch 46/100
# 290/290 - 3s - loss: 0.0048 - 3s/epoch - 9ms/step
# Epoch 47/100
# 290/290 - 3s - loss: 0.0047 - 3s/epoch - 9ms/step
# Epoch 48/100
# 290/290 - 3s - loss: 0.0039 - 3s/epoch - 9ms/step
# Epoch 49/100
# 290/290 - 4s - loss: 0.0035 - 4s/epoch - 14ms/step
# Epoch 50/100
# 290/290 - 3s - loss: 0.0038 - 3s/epoch - 9ms/step
# Epoch 51/100
# 290/290 - 3s - loss: 0.0048 - 3s/epoch - 10ms/step
# Epoch 52/100
# 290/290 - 3s - loss: 0.0046 - 3s/epoch - 9ms/step
# Epoch 53/100
# 290/290 - 3s - loss: 0.0047 - 3s/epoch - 12ms/step
# Epoch 54/100
# 290/290 - 3s - loss: 0.0049 - 3s/epoch - 11ms/step
# Epoch 55/100
# 290/290 - 3s - loss: 0.0046 - 3s/epoch - 9ms/step
# Epoch 56/100
# 290/290 - 3s - loss: 0.0037 - 3s/epoch - 9ms/step
# Epoch 57/100
# 290/290 - 3s - loss: 0.0032 - 3s/epoch - 9ms/step
# Epoch 58/100
# 290/290 - 4s - loss: 0.0038 - 4s/epoch - 14ms/step
# Epoch 59/100
# 290/290 - 3s - loss: 0.0033 - 3s/epoch - 9ms/step
# Epoch 60/100
# 290/290 - 3s - loss: 0.0039 - 3s/epoch - 9ms/step
# Epoch 61/100
# 290/290 - 3s - loss: 0.0034 - 3s/epoch - 9ms/step
# Epoch 62/100
# 290/290 - 3s - loss: 0.0026 - 3s/epoch - 12ms/step
# Epoch 63/100
# 290/290 - 3s - loss: 0.0032 - 3s/epoch - 11ms/step
# Epoch 64/100
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 9ms/step
# Epoch 65/100
# 290/290 - 3s - loss: 0.0027 - 3s/epoch - 10ms/step
# Epoch 66/100
# 290/290 - 3s - loss: 0.0034 - 3s/epoch - 10ms/step
# Epoch 67/100
# 290/290 - 4s - loss: 0.0045 - 4s/epoch - 14ms/step
# Epoch 68/100
# 290/290 - 3s - loss: 0.0042 - 3s/epoch - 10ms/step
# Epoch 69/100
# 290/290 - 3s - loss: 0.0052 - 3s/epoch - 9ms/step
# Epoch 70/100
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 10ms/step
# Epoch 71/100
# 290/290 - 4s - loss: 0.0036 - 4s/epoch - 12ms/step
# Epoch 72/100
# 290/290 - 3s - loss: 0.0032 - 3s/epoch - 11ms/step
# Epoch 73/100
# 290/290 - 3s - loss: 0.0048 - 3s/epoch - 9ms/step
# Epoch 74/100
# 290/290 - 3s - loss: 0.0033 - 3s/epoch - 9ms/step
# Epoch 75/100
# 290/290 - 3s - loss: 0.0030 - 3s/epoch - 10ms/step
# Epoch 76/100
# 290/290 - 4s - loss: 0.0027 - 4s/epoch - 14ms/step
# Epoch 77/100
# 290/290 - 3s - loss: 0.0031 - 3s/epoch - 9ms/step
# Epoch 78/100
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 9ms/step
# Epoch 79/100
# 290/290 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 80/100
# 290/290 - 4s - loss: 0.0022 - 4s/epoch - 13ms/step
# Epoch 81/100
# 290/290 - 3s - loss: 0.0022 - 3s/epoch - 11ms/step
# Epoch 82/100
# 290/290 - 3s - loss: 0.0032 - 3s/epoch - 10ms/step
# Epoch 83/100
# 290/290 - 3s - loss: 0.0024 - 3s/epoch - 9ms/step
# Epoch 84/100
# 290/290 - 3s - loss: 0.0019 - 3s/epoch - 9ms/step
# Epoch 85/100
# 290/290 - 4s - loss: 0.0020 - 4s/epoch - 14ms/step
# Epoch 86/100
# 290/290 - 3s - loss: 0.0025 - 3s/epoch - 9ms/step
# Epoch 87/100
# 290/290 - 3s - loss: 0.0034 - 3s/epoch - 9ms/step
# Epoch 88/100
# 290/290 - 3s - loss: 0.0029 - 3s/epoch - 10ms/step
# Epoch 89/100
# 290/290 - 4s - loss: 0.0039 - 4s/epoch - 14ms/step
# Epoch 90/100
# 290/290 - 3s - loss: 0.0027 - 3s/epoch - 11ms/step
# Epoch 91/100
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 10ms/step
# Epoch 92/100
# 290/290 - 3s - loss: 0.0038 - 3s/epoch - 10ms/step
# Epoch 93/100
# 290/290 - 4s - loss: 0.0021 - 4s/epoch - 12ms/step
# Epoch 94/100
# 290/290 - 3s - loss: 0.0036 - 3s/epoch - 12ms/step
# Epoch 95/100
# 290/290 - 3s - loss: 0.0028 - 3s/epoch - 10ms/step
# Epoch 96/100
# 290/290 - 3s - loss: 0.0018 - 3s/epoch - 10ms/step
# Epoch 97/100
# 290/290 - 3s - loss: 0.0035 - 3s/epoch - 10ms/step
# Epoch 98/100
# 290/290 - 4s - loss: 0.0026 - 4s/epoch - 13ms/step
# Epoch 99/100
# 290/290 - 3s - loss: 0.0030 - 3s/epoch - 9ms/step
# Epoch 100/100
# 290/290 - 3s - loss: 0.0017 - 3s/epoch - 10ms/step
# 10/10 [==============================] - 0s 5ms/step
# Epoch 1/100
# 289/289 - 6s - loss: 0.1790 - 6s/epoch - 22ms/step
# Epoch 2/100
# 289/289 - 5s - loss: 0.0743 - 5s/epoch - 17ms/step
# Epoch 3/100
# 289/289 - 4s - loss: 0.0769 - 4s/epoch - 13ms/step
# Epoch 4/100
# 289/289 - 4s - loss: 0.0254 - 4s/epoch - 13ms/step
# Epoch 5/100
# 289/289 - 4s - loss: 0.0308 - 4s/epoch - 14ms/step
# Epoch 6/100
# 289/289 - 5s - loss: 0.0280 - 5s/epoch - 16ms/step
# Epoch 7/100
# 289/289 - 4s - loss: 0.0235 - 4s/epoch - 12ms/step
# Epoch 8/100
# 289/289 - 4s - loss: 0.0199 - 4s/epoch - 12ms/step
# Epoch 9/100
# 289/289 - 5s - loss: 0.0186 - 5s/epoch - 17ms/step
# Epoch 10/100
# 289/289 - 4s - loss: 0.0160 - 4s/epoch - 13ms/step
# Epoch 11/100
# 289/289 - 4s - loss: 0.0159 - 4s/epoch - 13ms/step
# Epoch 12/100
# 289/289 - 5s - loss: 0.0165 - 5s/epoch - 17ms/step
# Epoch 13/100
# 289/289 - 4s - loss: 0.0122 - 4s/epoch - 13ms/step
# Epoch 14/100
# 289/289 - 4s - loss: 0.0131 - 4s/epoch - 13ms/step
# Epoch 15/100
# 289/289 - 4s - loss: 0.0114 - 4s/epoch - 15ms/step
# Epoch 16/100
# 289/289 - 5s - loss: 0.0112 - 5s/epoch - 16ms/step
# Epoch 17/100
# 289/289 - 4s - loss: 0.0092 - 4s/epoch - 13ms/step
# Epoch 18/100
# 289/289 - 4s - loss: 0.0098 - 4s/epoch - 13ms/step
# Epoch 19/100
# 289/289 - 5s - loss: 0.0077 - 5s/epoch - 17ms/step
# Epoch 20/100
# 289/289 - 4s - loss: 0.0089 - 4s/epoch - 12ms/step
# Epoch 21/100
# 289/289 - 4s - loss: 0.0063 - 4s/epoch - 12ms/step
# Epoch 22/100
# 289/289 - 5s - loss: 0.0069 - 5s/epoch - 17ms/step
# Epoch 23/100
# 289/289 - 4s - loss: 0.0064 - 4s/epoch - 13ms/step
# Epoch 24/100
# 289/289 - 4s - loss: 0.0067 - 4s/epoch - 13ms/step
# Epoch 25/100
# 289/289 - 4s - loss: 0.0080 - 4s/epoch - 15ms/step
# Epoch 26/100
# 289/289 - 4s - loss: 0.0058 - 4s/epoch - 15ms/step
# Epoch 27/100
# 289/289 - 4s - loss: 0.0060 - 4s/epoch - 13ms/step
# Epoch 28/100
# 289/289 - 4s - loss: 0.0094 - 4s/epoch - 13ms/step
# Epoch 29/100
# 289/289 - 5s - loss: 0.0066 - 5s/epoch - 17ms/step
# Epoch 30/100
# 289/289 - 4s - loss: 0.0058 - 4s/epoch - 13ms/step
# Epoch 31/100
# 289/289 - 4s - loss: 0.0047 - 4s/epoch - 13ms/step
# Epoch 32/100
# 289/289 - 5s - loss: 0.0057 - 5s/epoch - 18ms/step
# Epoch 33/100
# 289/289 - 4s - loss: 0.0046 - 4s/epoch - 13ms/step
# Epoch 34/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 12ms/step
# Epoch 35/100
# 289/289 - 4s - loss: 0.0036 - 4s/epoch - 15ms/step
# Epoch 36/100
# 289/289 - 4s - loss: 0.0039 - 4s/epoch - 14ms/step
# Epoch 37/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 13ms/step
# Epoch 38/100
# 289/289 - 4s - loss: 0.0033 - 4s/epoch - 13ms/step
# Epoch 39/100
# 289/289 - 5s - loss: 0.0036 - 5s/epoch - 17ms/step
# Epoch 40/100
# 289/289 - 4s - loss: 0.0039 - 4s/epoch - 13ms/step
# Epoch 41/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 12ms/step
# Epoch 42/100
# 289/289 - 5s - loss: 0.0036 - 5s/epoch - 17ms/step
# Epoch 43/100
# 289/289 - 4s - loss: 0.0038 - 4s/epoch - 12ms/step
# Epoch 44/100
# 289/289 - 4s - loss: 0.0045 - 4s/epoch - 13ms/step
# Epoch 45/100
# 289/289 - 4s - loss: 0.0047 - 4s/epoch - 15ms/step
# Epoch 46/100
# 289/289 - 4s - loss: 0.0043 - 4s/epoch - 15ms/step
# Epoch 47/100
# 289/289 - 4s - loss: 0.0036 - 4s/epoch - 13ms/step
# Epoch 48/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 13ms/step
# Epoch 49/100
# 289/289 - 5s - loss: 0.0035 - 5s/epoch - 17ms/step
# Epoch 50/100
# 289/289 - 4s - loss: 0.0039 - 4s/epoch - 12ms/step
# Epoch 51/100
# 289/289 - 4s - loss: 0.0032 - 4s/epoch - 12ms/step
# Epoch 52/100
# 289/289 - 5s - loss: 0.0030 - 5s/epoch - 17ms/step
# Epoch 53/100
# 289/289 - 4s - loss: 0.0029 - 4s/epoch - 12ms/step
# Epoch 54/100
# 289/289 - 4s - loss: 0.0033 - 4s/epoch - 12ms/step
# Epoch 55/100
# 289/289 - 4s - loss: 0.0034 - 4s/epoch - 14ms/step
# Epoch 56/100
# 289/289 - 5s - loss: 0.0040 - 5s/epoch - 16ms/step
# Epoch 57/100
# 289/289 - 4s - loss: 0.0045 - 4s/epoch - 12ms/step
# Epoch 58/100
# 289/289 - 4s - loss: 0.0055 - 4s/epoch - 13ms/step
# Epoch 59/100
# 289/289 - 5s - loss: 0.0036 - 5s/epoch - 17ms/step
# Epoch 60/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 12ms/step
# Epoch 61/100
# 289/289 - 4s - loss: 0.0031 - 4s/epoch - 12ms/step
# Epoch 62/100
# 289/289 - 5s - loss: 0.0033 - 5s/epoch - 16ms/step
# Epoch 63/100
# 289/289 - 4s - loss: 0.0031 - 4s/epoch - 13ms/step
# Epoch 64/100
# 289/289 - 4s - loss: 0.0032 - 4s/epoch - 12ms/step
# Epoch 65/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 13ms/step
# Epoch 66/100
# 289/289 - 5s - loss: 0.0034 - 5s/epoch - 16ms/step
# Epoch 67/100
# 289/289 - 4s - loss: 0.0035 - 4s/epoch - 13ms/step
# Epoch 68/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 13ms/step
# Epoch 69/100
# 289/289 - 5s - loss: 0.0041 - 5s/epoch - 17ms/step
# Epoch 70/100
# 289/289 - 4s - loss: 0.0026 - 4s/epoch - 13ms/step
# Epoch 71/100
# 289/289 - 4s - loss: 0.0038 - 4s/epoch - 13ms/step
# Epoch 72/100
# 289/289 - 5s - loss: 0.0036 - 5s/epoch - 16ms/step
# Epoch 73/100
# 289/289 - 4s - loss: 0.0042 - 4s/epoch - 14ms/step
# Epoch 74/100
# 289/289 - 4s - loss: 0.0059 - 4s/epoch - 13ms/step
# Epoch 75/100
# 289/289 - 4s - loss: 0.0039 - 4s/epoch - 14ms/step
# Epoch 76/100
# 289/289 - 5s - loss: 0.0042 - 5s/epoch - 17ms/step
# Epoch 77/100
# 289/289 - 4s - loss: 0.0031 - 4s/epoch - 13ms/step
# Epoch 78/100
# 289/289 - 4s - loss: 0.0034 - 4s/epoch - 13ms/step
# Epoch 79/100
# 289/289 - 5s - loss: 0.0033 - 5s/epoch - 17ms/step
# Epoch 80/100
# 289/289 - 4s - loss: 0.0032 - 4s/epoch - 12ms/step
# Epoch 81/100
# 289/289 - 4s - loss: 0.0034 - 4s/epoch - 12ms/step
# Epoch 82/100
# 289/289 - 5s - loss: 0.0037 - 5s/epoch - 16ms/step
# Epoch 83/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 14ms/step
# Epoch 84/100
# 289/289 - 4s - loss: 0.0029 - 4s/epoch - 13ms/step
# Epoch 85/100
# 289/289 - 4s - loss: 0.0031 - 4s/epoch - 13ms/step
# Epoch 86/100
# 289/289 - 5s - loss: 0.0028 - 5s/epoch - 17ms/step
# Epoch 87/100
# 289/289 - 4s - loss: 0.0029 - 4s/epoch - 12ms/step
# Epoch 88/100
# 289/289 - 4s - loss: 0.0036 - 4s/epoch - 12ms/step
# Epoch 89/100
# 289/289 - 5s - loss: 0.0029 - 5s/epoch - 17ms/step
# Epoch 90/100
# 289/289 - 4s - loss: 0.0029 - 4s/epoch - 13ms/step
# Epoch 91/100
# 289/289 - 4s - loss: 0.0027 - 4s/epoch - 12ms/step
# Epoch 92/100
# 289/289 - 4s - loss: 0.0033 - 4s/epoch - 15ms/step
# Epoch 93/100
# 289/289 - 4s - loss: 0.0027 - 4s/epoch - 14ms/step
# Epoch 94/100
# 289/289 - 4s - loss: 0.0027 - 4s/epoch - 12ms/step
# Epoch 95/100
# 289/289 - 4s - loss: 0.0035 - 4s/epoch - 12ms/step
# Epoch 96/100
# 289/289 - 5s - loss: 0.0028 - 5s/epoch - 17ms/step
# Epoch 97/100
# 289/289 - 4s - loss: 0.0024 - 4s/epoch - 13ms/step
# Epoch 98/100
# 289/289 - 4s - loss: 0.0032 - 4s/epoch - 12ms/step
# Epoch 99/100
# 289/289 - 5s - loss: 0.0029 - 5s/epoch - 17ms/step
# Epoch 100/100
# 289/289 - 4s - loss: 0.0037 - 4s/epoch - 13ms/step
# 9/9 [==============================] - 0s 7ms/step

# %%
for result in results:
    print(f"n_steps: {result[0]}, RMSE: {result[1]}, MAPE: {result[2]}")
# Out:
# n_steps: 2, RMSE: 0.12215869036804144, MAPE: 0.10010175977418173
# n_steps: 6, RMSE: 0.05372582201861379, MAPE: 0.06487787154507212
# n_steps: 13, RMSE: 0.08267918089227824, MAPE: 0.09383307205931878
# n_steps: 20, RMSE: 0.09018409385449735, MAPE: 0.08497624467102646

# %%
plt.figure(figsize=(10, 5))
plt.plot([result[0] for result in results], [result[1] for result in results], marker='o', label='RMSE')
plt.plot([result[0] for result in results], [result[2] for result in results], marker='o', label='MAPE')
plt.xlabel('n_steps')
plt.ylabel('Error')
plt.title('Error vs. n_steps')
plt.legend()
plt.show()

# %% [markdown]
# The result shows that n_steps = n will reach the most accurate prediction, means that predicting the n+1th days is the best choice

# %% [markdown]
# #### 3.2.5 Cross Validation

# %%
# n_steps = 6
# X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

# %%
# tscv = TimeSeriesSplit(n_splits=5)
# rmse_scores = []
# mape_scores = []

# for train_index, test_index in tscv.split(X1):
#     X_train, X_test = X1[train_index], X1[test_index]
#     y_train, y_test = y1[train_index], y1[test_index]

#     # Define the model
#     model = Sequential()
#     model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
#     model.add(LSTM(50, activation='relu'))
#     model.add(Dense(1))
#     model.compile(loss='mean_squared_error', optimizer='adam')

#     # Train the model
#     model.fit(X_train, y_train, epochs=100, batch_size=4, verbose=0, shuffle=False)

#     # Predict
#     y_pred = model.predict(X_test)
#     y_pred = y_pred[:, 0]

#     # Calculate RMSE and MAPE
#     rmse = mean_squared_error(y_test, y_pred, squared=False)
#     mape = mean_absolute_percentage_error(y_test, y_pred)

#     rmse_scores.append(rmse)
#     mape_scores.append(mape)

# print(f"Average RMSE: {np.mean(rmse_scores)}, Average MAPE: {np.mean(mape_scores)}")

# %% [markdown]
# ###3.3 Run Saved Model

# %%
# Load the SavedModel
model = load_model('predict_nflx.h5')
sc = joblib.load('standard_scaler.pkl')

# %%
def prepare_input_data(ticker, end_date, n_steps):
    stock_data = yf.download(ticker, end=end_date)
    X_feat = stock_data[['Open', 'High', 'Low']]
    target_y = stock_data['Close']

    X_ft = sc.fit_transform(X_feat.values)
    stock_data_ft = pd.DataFrame(columns=X_feat.columns, data=X_ft, index=X_feat.index)
    stock_data_ft['Close'] = target_y.values

    input_data = stock_data_ft.values[-n_steps:, :-1]
    input_data = np.expand_dims(input_data, axis=0)

    return input_data, stock_data_ft.index[-1]

# %%
# Parameter prediksi
ticker = 'BNB-USD'
end_date = '2024-04-05'
n_steps = 6

# Menyiapkan data input
input_data, last_date = prepare_input_data(ticker, end_date, n_steps)

# Melakukan prediksi
predicted_price_scaled = model.predict(input_data).flatten()[0]

# Mengembalikan hasil prediksi ke skala semula
predicted_price = sc.inverse_transform([[np.nan, predicted_price_scaled, np.nan]])[0][1]

# Menampilkan hasil prediksi
print(f"Harga saham {ticker} yang diprediksi untuk tanggal {end_date} adalah: {predicted_price:.2f}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 403ms/step
# Harga saham BNB-USD yang diprediksi untuk tanggal 2024-04-05 adalah: 584.73
