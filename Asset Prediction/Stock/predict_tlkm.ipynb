# %% [markdown]
# #Try Stock Prediction - Telkom

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import joblib
import yfinance as yf
import matplotlib.dates as mdates

import tensorflow as tf
from tensorflow import keras
from keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %% [markdown]
# ## 1. Read Data

# %%
# stock_data = pd.read_csv('/content/NFLX.csv', index_col='Date')
# stock_data

ticker = 'TLKM.JK'
# start_date = '2020-05-20'
# end_date = pd.Timestamp.now().strftime('%Y-%m-%d')
start_date = '2020-05-21'
end_date = '2024-05-21'
stock_data = yf.download(ticker, start=start_date, end=end_date)
stock_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#               Open    High     Low   Close    Adj Close     Volume
# Date
# 2020-05-26  3150.0  3280.0  3130.0  3250.0  2568.562256  105792900
# 2020-05-27  3250.0  3270.0  3150.0  3170.0  2505.336182  128693900
# 2020-05-28  3180.0  3210.0  3130.0  3130.0  2473.723145  177385100
# 2020-05-29  3100.0  3150.0  3080.0  3150.0  2489.529541  276092100
# 2020-06-02  3160.0  3270.0  3120.0  3250.0  2568.562256  174790600
# ...            ...     ...     ...     ...          ...        ...
# 2024-05-14  3100.0  3120.0  3080.0  3120.0  2940.343994  104126800
# 2024-05-15  3120.0  3130.0  3070.0  3100.0  2921.495850  149143600
# 2024-05-16  2960.0  3050.0  2960.0  3010.0  3010.000000  196239200
# 2024-05-17  3050.0  3050.0  2980.0  2990.0  2990.000000  120345300
# 2024-05-20  2950.0  3000.0  2950.0  2990.0  2990.000000  215877500
#
# [963 rows x 6 columns]

# %% [markdown]
# ## 2. Plotting Data

# %% [markdown]
# ### 2.1 Plot High & Low

# %%
# Define function to create input and output sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length, :-1])
        y.append(data[i + seq_length, -1])
    return np.array(X), np.array(y)

# Hyperparameters
seq_length = 7
n_features = stock_data.shape[1]
n_units = 64
dropout_rate = 0.2
learning_rate = 0.001
batch_size = 32
epochs = 50

# %% [markdown]
# ### 2.2 Plot Open & Close

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
# x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]
x_dates = stock_data.index

plt.plot(x_dates, stock_data['Open'], label='Open')
plt.plot(x_dates, stock_data['Close'], label='Close')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ## 3. Stock Prediction

# %% [markdown]
# ### 3.1 Normalize or Rescale

# %%
features = stock_data.iloc[:, 0:4]
sc = StandardScaler()
features_scaled = sc.fit_transform(features.values)
stock_data_ft = pd.DataFrame(columns=features.columns, data=features_scaled, index=features.index)

# Simpan objek StandardScaler
joblib.dump(sc, 'standard_scaler.pkl')
# Out:
# ['standard_scaler.pkl']

# %% [markdown]
# ### 3.2 Train & Test

# %% [markdown]
# #### 3.2.1 Splitting

# %%
def lstm_split(data, n_steps):
  X, y = [], []
  for i in range(len(data) - n_steps):
    X.append(data[i:i + n_steps, :-1])
    y.append(data[i + n_steps-1, -1])

  return np.array(X), np.array(y)

# %%
n_steps = 6
X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

train_split = 0.8
split_idx = int(np.ceil(len(X1)*train_split))
date_index = stock_data_ft.index

X_train, X_test = X1[:split_idx], X1[split_idx:]
y_train, y_test = y1[:split_idx], y1[split_idx:]
X_train_date, X_test_date = date_index[n_steps-1:split_idx + n_steps-1], date_index[split_idx + n_steps-1:len(X1) + n_steps-1]

print(X1.shape, X_train.shape, X_test.shape, y_test.shape)
# Out:
# (957, 6, 3) (766, 6, 3) (191, 6, 3) (191,)

# %% [markdown]
# #### 3.2.2 Training

# %%
lstm = Sequential()
lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='tanh', return_sequences=True))
lstm.add(Dropout(0.4))
lstm.add(LSTM(50, activation='tanh'))
lstm.add(Dropout(0.2))
lstm.add(Dense(80, activation = 'relu'))
lstm.add(Dense(80, activation = 'relu'))
lstm.add(Dense(1, activation = 'linear'))
lstm.compile(loss='mean_squared_error', optimizer='adam')
lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 6, 50)             10800
#
#  dropout (Dropout)           (None, 6, 50)             0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 80)                4080
#
#  dense_1 (Dense)             (None, 80)                6480
#
#  dense_2 (Dense)             (None, 1)                 81
#
# =================================================================
# Total params: 41641 (162.66 KB)
# Trainable params: 41641 (162.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

# %%
history = lstm.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=2, verbose = 1, shuffle=True, callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 306/306 [==============================] - 7s 10ms/step - loss: 0.1260 - val_loss: 0.0257
# Epoch 2/100
#  26/306 [=>............................] - ETA: 1s - loss: 0.0830
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0663 - val_loss: 0.0277
# Epoch 3/100
# 306/306 [==============================] - 3s 8ms/step - loss: 0.0600 - val_loss: 0.0207
# Epoch 4/100
# 306/306 [==============================] - 3s 11ms/step - loss: 0.0529 - val_loss: 0.0263
# Epoch 5/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0478 - val_loss: 0.0174
# Epoch 6/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0428 - val_loss: 0.0303
# Epoch 7/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0425 - val_loss: 0.0245
# Epoch 8/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0433 - val_loss: 0.0252
# Epoch 9/100
# 306/306 [==============================] - 3s 10ms/step - loss: 0.0363 - val_loss: 0.0099
# Epoch 10/100
# 306/306 [==============================] - 3s 11ms/step - loss: 0.0349 - val_loss: 0.0092
# Epoch 11/100
# 306/306 [==============================] - 3s 9ms/step - loss: 0.0330 - val_loss: 0.0108
# Epoch 12/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0342 - val_loss: 0.0079
# Epoch 13/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0371 - val_loss: 0.0082
# Epoch 14/100
# 306/306 [==============================] - 3s 9ms/step - loss: 0.0328 - val_loss: 0.0074
# Epoch 15/100
# 306/306 [==============================] - 3s 10ms/step - loss: 0.0301 - val_loss: 0.0083
# Epoch 16/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0290 - val_loss: 0.0075
# Epoch 17/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0291 - val_loss: 0.0125
# Epoch 18/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0296 - val_loss: 0.0055
# Epoch 19/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0281 - val_loss: 0.0117
# Epoch 20/100
# 306/306 [==============================] - 3s 9ms/step - loss: 0.0253 - val_loss: 0.0079
# Epoch 21/100
# 306/306 [==============================] - 4s 13ms/step - loss: 0.0235 - val_loss: 0.0206
# Epoch 22/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0286 - val_loss: 0.0073
# Epoch 23/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0251 - val_loss: 0.0058
# Epoch 24/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0222 - val_loss: 0.0133
# Epoch 25/100
# 306/306 [==============================] - 3s 8ms/step - loss: 0.0252 - val_loss: 0.0049
# Epoch 26/100
# 306/306 [==============================] - 3s 10ms/step - loss: 0.0241 - val_loss: 0.0049
# Epoch 27/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0251 - val_loss: 0.0081
# Epoch 28/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0210 - val_loss: 0.0119
# Epoch 29/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0291 - val_loss: 0.0044
# Epoch 30/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0246 - val_loss: 0.0049
# Epoch 31/100
# 306/306 [==============================] - 3s 9ms/step - loss: 0.0206 - val_loss: 0.0044
# Epoch 32/100
# 306/306 [==============================] - 3s 9ms/step - loss: 0.0244 - val_loss: 0.0072
# Epoch 33/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0228 - val_loss: 0.0285
# Epoch 34/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0178 - val_loss: 0.0052
# Epoch 35/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0219 - val_loss: 0.0047
# Epoch 36/100
# 306/306 [==============================] - 2s 8ms/step - loss: 0.0181 - val_loss: 0.0100
# Epoch 37/100
# 306/306 [==============================] - 3s 10ms/step - loss: 0.0187 - val_loss: 0.0076
# Epoch 38/100
# 306/306 [==============================] - 2s 8ms/step - loss: 0.0181 - val_loss: 0.0080
# Epoch 39/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0222 - val_loss: 0.0207
# Epoch 40/100
# 306/306 [==============================] - 2s 8ms/step - loss: 0.0194 - val_loss: 0.0050
# Epoch 41/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0214 - val_loss: 0.0175

# %%
plt.plot(history.history['loss'])
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# #### 3.2.3 Evaluation

# %%
# Make predictions
y_pred = lstm.predict(X_test)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(X_test_date, y_test, label='True Values', color='blue')
plt.plot(X_test_date, y_pred, label='Predicted Values', color='red')
plt.title('True Values vs Predicted Values')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 6/6 [==============================] - 1s 6ms/step

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
mape = mean_absolute_percentage_error(y_test, y_pred)
print("RMSE: ", rmse)
print("MAPE: ", mape)
# Out:
# RMSE:  0.0640486577441328
# MAPE:  0.5761713540569293

# %%
# Save Model
lstm.save("predict_tlkm.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# #### 3.2.4 Compare Performance

# %%
n_steps_list = [2, 6, 13, 20]
results = []
models = []

for n_steps in n_steps_list:
    X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

    split_idx = int(np.ceil(len(X1) * 0.8))
    X_train, X_test = X1[:split_idx], X1[split_idx:]
    y_train, y_test = y1[:split_idx], y1[split_idx:]

    lstm = Sequential()
    lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='tanh', return_sequences=True))
    lstm.add(Dropout(0.2))
    lstm.add(LSTM(50, activation='tanh'))
    lstm.add(Dropout(0.2))
    lstm.add(Dense(1))
    lstm.compile(loss='mean_squared_error', optimizer='adam')

    lstm.fit(X_train, y_train, epochs=100, batch_size=4, verbose=2, shuffle=False)

    y_pred = lstm.predict(X_test)
    y_pred = y_pred.flatten()  # Ensure y_pred is a 1D array

    #sc_y.fit(y_train.reshape(-1, 1))  # Fit scaler on training target data
    #y_pred = sc_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
    #y_test = sc_y.inverse_transform(y_test.reshape(-1, 1)).flatten()

    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mape = mean_absolute_percentage_error(y_test, y_pred)

    results.append((n_steps, rmse, mape))
    models.append(lstm)
# Out:
# Epoch 1/100
# 193/193 - 6s - loss: 0.2556 - 6s/epoch - 30ms/step
# Epoch 2/100
# 193/193 - 1s - loss: 0.0365 - 818ms/epoch - 4ms/step
# Epoch 3/100
# 193/193 - 1s - loss: 0.0334 - 813ms/epoch - 4ms/step
# Epoch 4/100
# 193/193 - 1s - loss: 0.0331 - 850ms/epoch - 4ms/step
# Epoch 5/100
# 193/193 - 1s - loss: 0.0362 - 852ms/epoch - 4ms/step
# Epoch 6/100
# 193/193 - 1s - loss: 0.0299 - 817ms/epoch - 4ms/step
# Epoch 7/100
# 193/193 - 1s - loss: 0.0309 - 863ms/epoch - 4ms/step
# Epoch 8/100
# 193/193 - 1s - loss: 0.0350 - 842ms/epoch - 4ms/step
# Epoch 9/100
# 193/193 - 1s - loss: 0.0371 - 832ms/epoch - 4ms/step
# Epoch 10/100
# 193/193 - 1s - loss: 0.0339 - 840ms/epoch - 4ms/step
# Epoch 11/100
# 193/193 - 1s - loss: 0.0301 - 1s/epoch - 5ms/step
# Epoch 12/100
# 193/193 - 1s - loss: 0.0274 - 1s/epoch - 6ms/step
# Epoch 13/100
# 193/193 - 1s - loss: 0.0275 - 1s/epoch - 6ms/step
# Epoch 14/100
# 193/193 - 1s - loss: 0.0260 - 1s/epoch - 6ms/step
# Epoch 15/100
# 193/193 - 1s - loss: 0.0283 - 821ms/epoch - 4ms/step
# Epoch 16/100
# 193/193 - 1s - loss: 0.0250 - 842ms/epoch - 4ms/step
# Epoch 17/100
# 193/193 - 1s - loss: 0.0274 - 853ms/epoch - 4ms/step
# Epoch 18/100
# 193/193 - 1s - loss: 0.0260 - 822ms/epoch - 4ms/step
# Epoch 19/100
# 193/193 - 1s - loss: 0.0263 - 867ms/epoch - 4ms/step
# Epoch 20/100
# 193/193 - 1s - loss: 0.0287 - 879ms/epoch - 5ms/step
# Epoch 21/100
# 193/193 - 1s - loss: 0.0284 - 847ms/epoch - 4ms/step
# Epoch 22/100
# 193/193 - 1s - loss: 0.0280 - 802ms/epoch - 4ms/step
# Epoch 23/100
# 193/193 - 1s - loss: 0.0223 - 841ms/epoch - 4ms/step
# Epoch 24/100
# 193/193 - 1s - loss: 0.0235 - 852ms/epoch - 4ms/step
# Epoch 25/100
# 193/193 - 1s - loss: 0.0218 - 848ms/epoch - 4ms/step
# Epoch 26/100
# 193/193 - 1s - loss: 0.0290 - 988ms/epoch - 5ms/step
# Epoch 27/100
# 193/193 - 1s - loss: 0.0240 - 1s/epoch - 6ms/step
# Epoch 28/100
# 193/193 - 1s - loss: 0.0242 - 1s/epoch - 6ms/step
# Epoch 29/100
# 193/193 - 1s - loss: 0.0194 - 1s/epoch - 6ms/step
# Epoch 30/100
# 193/193 - 1s - loss: 0.0204 - 838ms/epoch - 4ms/step
# Epoch 31/100
# 193/193 - 1s - loss: 0.0209 - 813ms/epoch - 4ms/step
# Epoch 32/100
# 193/193 - 1s - loss: 0.0250 - 850ms/epoch - 4ms/step
# Epoch 33/100
# 193/193 - 1s - loss: 0.0222 - 860ms/epoch - 4ms/step
# Epoch 34/100
# 193/193 - 1s - loss: 0.0243 - 859ms/epoch - 4ms/step
# Epoch 35/100
# 193/193 - 1s - loss: 0.0243 - 815ms/epoch - 4ms/step
# Epoch 36/100
# 193/193 - 1s - loss: 0.0207 - 807ms/epoch - 4ms/step
# Epoch 37/100
# 193/193 - 1s - loss: 0.0249 - 879ms/epoch - 5ms/step
# Epoch 38/100
# 193/193 - 1s - loss: 0.0224 - 857ms/epoch - 4ms/step
# Epoch 39/100
# 193/193 - 1s - loss: 0.0222 - 823ms/epoch - 4ms/step
# Epoch 40/100
# 193/193 - 1s - loss: 0.0239 - 881ms/epoch - 5ms/step
# Epoch 41/100
# 193/193 - 1s - loss: 0.0204 - 1s/epoch - 5ms/step
# Epoch 42/100
# 193/193 - 1s - loss: 0.0205 - 1s/epoch - 6ms/step
# Epoch 43/100
# 193/193 - 1s - loss: 0.0197 - 1s/epoch - 6ms/step
# Epoch 44/100
# 193/193 - 1s - loss: 0.0227 - 1s/epoch - 6ms/step
# Epoch 45/100
# 193/193 - 1s - loss: 0.0197 - 828ms/epoch - 4ms/step
# Epoch 46/100
# 193/193 - 1s - loss: 0.0226 - 874ms/epoch - 5ms/step
# Epoch 47/100
# 193/193 - 1s - loss: 0.0195 - 846ms/epoch - 4ms/step
# Epoch 48/100
# 193/193 - 1s - loss: 0.0209 - 868ms/epoch - 4ms/step
# Epoch 49/100
# 193/193 - 1s - loss: 0.0191 - 847ms/epoch - 4ms/step
# Epoch 50/100
# 193/193 - 1s - loss: 0.0217 - 872ms/epoch - 5ms/step
# Epoch 51/100
# 193/193 - 1s - loss: 0.0225 - 803ms/epoch - 4ms/step
# Epoch 52/100
# 193/193 - 1s - loss: 0.0195 - 846ms/epoch - 4ms/step
# Epoch 53/100
# 193/193 - 1s - loss: 0.0184 - 847ms/epoch - 4ms/step
# Epoch 54/100
# 193/193 - 1s - loss: 0.0213 - 822ms/epoch - 4ms/step
# Epoch 55/100
# 193/193 - 1s - loss: 0.0177 - 821ms/epoch - 4ms/step
# Epoch 56/100
# 193/193 - 1s - loss: 0.0200 - 1s/epoch - 5ms/step
# Epoch 57/100
# 193/193 - 1s - loss: 0.0239 - 1s/epoch - 6ms/step
# Epoch 58/100
# 193/193 - 1s - loss: 0.0232 - 1s/epoch - 6ms/step
# Epoch 59/100
# 193/193 - 1s - loss: 0.0196 - 1s/epoch - 6ms/step
# Epoch 60/100
# 193/193 - 1s - loss: 0.0189 - 866ms/epoch - 4ms/step
# Epoch 61/100
# 193/193 - 1s - loss: 0.0245 - 866ms/epoch - 4ms/step
# Epoch 62/100
# 193/193 - 1s - loss: 0.0200 - 837ms/epoch - 4ms/step
# Epoch 63/100
# 193/193 - 1s - loss: 0.0213 - 845ms/epoch - 4ms/step
# Epoch 64/100
# 193/193 - 1s - loss: 0.0167 - 840ms/epoch - 4ms/step
# Epoch 65/100
# 193/193 - 1s - loss: 0.0202 - 845ms/epoch - 4ms/step
# Epoch 66/100
# 193/193 - 1s - loss: 0.0214 - 868ms/epoch - 4ms/step
# Epoch 67/100
# 193/193 - 1s - loss: 0.0204 - 851ms/epoch - 4ms/step
# Epoch 68/100
# 193/193 - 1s - loss: 0.0204 - 816ms/epoch - 4ms/step
# Epoch 69/100
# 193/193 - 1s - loss: 0.0177 - 819ms/epoch - 4ms/step
# Epoch 70/100
# 193/193 - 1s - loss: 0.0183 - 833ms/epoch - 4ms/step
# Epoch 71/100
# 193/193 - 1s - loss: 0.0188 - 995ms/epoch - 5ms/step
# Epoch 72/100
# 193/193 - 1s - loss: 0.0191 - 1s/epoch - 6ms/step
# Epoch 73/100
# 193/193 - 1s - loss: 0.0211 - 1s/epoch - 6ms/step
# Epoch 74/100
# 193/193 - 1s - loss: 0.0196 - 1s/epoch - 6ms/step
# Epoch 75/100
# 193/193 - 1s - loss: 0.0203 - 835ms/epoch - 4ms/step
# Epoch 76/100
# 193/193 - 1s - loss: 0.0173 - 840ms/epoch - 4ms/step
# Epoch 77/100
# 193/193 - 1s - loss: 0.0200 - 866ms/epoch - 4ms/step
# Epoch 78/100
# 193/193 - 1s - loss: 0.0197 - 860ms/epoch - 4ms/step
# Epoch 79/100
# 193/193 - 1s - loss: 0.0195 - 866ms/epoch - 4ms/step
# Epoch 80/100
# 193/193 - 1s - loss: 0.0180 - 851ms/epoch - 4ms/step
# Epoch 81/100
# 193/193 - 1s - loss: 0.0160 - 831ms/epoch - 4ms/step
# Epoch 82/100
# 193/193 - 1s - loss: 0.0179 - 857ms/epoch - 4ms/step
# Epoch 83/100
# 193/193 - 1s - loss: 0.0171 - 860ms/epoch - 4ms/step
# Epoch 84/100
# 193/193 - 1s - loss: 0.0172 - 820ms/epoch - 4ms/step
# Epoch 85/100
# 193/193 - 1s - loss: 0.0205 - 843ms/epoch - 4ms/step
# Epoch 86/100
# 193/193 - 1s - loss: 0.0218 - 998ms/epoch - 5ms/step
# Epoch 87/100
# 193/193 - 1s - loss: 0.0155 - 1s/epoch - 6ms/step
# Epoch 88/100
# 193/193 - 1s - loss: 0.0191 - 1s/epoch - 6ms/step
# Epoch 89/100
# 193/193 - 1s - loss: 0.0194 - 1s/epoch - 6ms/step
# Epoch 90/100
# 193/193 - 1s - loss: 0.0175 - 804ms/epoch - 4ms/step
# Epoch 91/100
# 193/193 - 1s - loss: 0.0196 - 846ms/epoch - 4ms/step
# Epoch 92/100
# 193/193 - 1s - loss: 0.0169 - 833ms/epoch - 4ms/step
# Epoch 93/100
# 193/193 - 1s - loss: 0.0194 - 862ms/epoch - 4ms/step
# Epoch 94/100
# 193/193 - 1s - loss: 0.0181 - 819ms/epoch - 4ms/step
# Epoch 95/100
# 193/193 - 1s - loss: 0.0180 - 843ms/epoch - 4ms/step
# Epoch 96/100
# 193/193 - 1s - loss: 0.0208 - 819ms/epoch - 4ms/step
# Epoch 97/100
# 193/193 - 1s - loss: 0.0165 - 819ms/epoch - 4ms/step
# Epoch 98/100
# 193/193 - 1s - loss: 0.0179 - 817ms/epoch - 4ms/step
# Epoch 99/100
# 193/193 - 1s - loss: 0.0182 - 875ms/epoch - 5ms/step
# Epoch 100/100
# 193/193 - 1s - loss: 0.0187 - 869ms/epoch - 5ms/step
# 6/6 [==============================] - 1s 4ms/step
# Epoch 1/100
# 192/192 - 6s - loss: 0.1256 - 6s/epoch - 29ms/step
# Epoch 2/100
# 192/192 - 1s - loss: 0.0802 - 1s/epoch - 6ms/step
# Epoch 3/100
# 192/192 - 1s - loss: 0.0812 - 1s/epoch - 7ms/step
# Epoch 4/100
# 192/192 - 1s - loss: 0.0710 - 1s/epoch - 7ms/step
# Epoch 5/100
# 192/192 - 1s - loss: 0.0775 - 1s/epoch - 7ms/step
# Epoch 6/100
# 192/192 - 1s - loss: 0.0703 - 1s/epoch - 7ms/step
# Epoch 7/100
# 192/192 - 2s - loss: 0.0792 - 2s/epoch - 10ms/step
# Epoch 8/100
# 192/192 - 2s - loss: 0.0725 - 2s/epoch - 11ms/step
# Epoch 9/100
# 192/192 - 1s - loss: 0.0690 - 1s/epoch - 7ms/step
# Epoch 10/100
# 192/192 - 1s - loss: 0.0577 - 1s/epoch - 7ms/step
# Epoch 11/100
# 192/192 - 1s - loss: 0.0445 - 1s/epoch - 7ms/step
# Epoch 12/100
# 192/192 - 1s - loss: 0.0383 - 1s/epoch - 7ms/step
# Epoch 13/100
# 192/192 - 1s - loss: 0.0351 - 1s/epoch - 7ms/step
# Epoch 14/100
# 192/192 - 1s - loss: 0.0370 - 1s/epoch - 7ms/step
# Epoch 15/100
# 192/192 - 1s - loss: 0.0310 - 1s/epoch - 7ms/step
# Epoch 16/100
# 192/192 - 1s - loss: 0.0361 - 1s/epoch - 8ms/step
# Epoch 17/100
# 192/192 - 2s - loss: 0.0280 - 2s/epoch - 10ms/step
# Epoch 18/100
# 192/192 - 2s - loss: 0.0252 - 2s/epoch - 9ms/step
# Epoch 19/100
# 192/192 - 1s - loss: 0.0252 - 1s/epoch - 7ms/step
# Epoch 20/100
# 192/192 - 1s - loss: 0.0223 - 1s/epoch - 7ms/step
# Epoch 21/100
# 192/192 - 1s - loss: 0.0254 - 1s/epoch - 7ms/step
# Epoch 22/100
# 192/192 - 1s - loss: 0.0228 - 1s/epoch - 7ms/step
# Epoch 23/100
# 192/192 - 1s - loss: 0.0241 - 1s/epoch - 7ms/step
# Epoch 24/100
# 192/192 - 1s - loss: 0.0268 - 1s/epoch - 7ms/step
# Epoch 25/100
# 192/192 - 1s - loss: 0.0198 - 1s/epoch - 7ms/step
# Epoch 26/100
# 192/192 - 2s - loss: 0.0195 - 2s/epoch - 9ms/step
# Epoch 27/100
# 192/192 - 2s - loss: 0.0187 - 2s/epoch - 10ms/step
# Epoch 28/100
# 192/192 - 2s - loss: 0.0247 - 2s/epoch - 8ms/step
# Epoch 29/100
# 192/192 - 1s - loss: 0.0193 - 1s/epoch - 7ms/step
# Epoch 30/100
# 192/192 - 1s - loss: 0.0194 - 1s/epoch - 7ms/step
# Epoch 31/100
# 192/192 - 1s - loss: 0.0195 - 1s/epoch - 7ms/step
# Epoch 32/100
# 192/192 - 1s - loss: 0.0219 - 1s/epoch - 7ms/step
# Epoch 33/100
# 192/192 - 1s - loss: 0.0181 - 1s/epoch - 7ms/step
# Epoch 34/100
# 192/192 - 1s - loss: 0.0224 - 1s/epoch - 7ms/step
# Epoch 35/100
# 192/192 - 1s - loss: 0.0185 - 1s/epoch - 7ms/step
# Epoch 36/100
# 192/192 - 2s - loss: 0.0185 - 2s/epoch - 10ms/step
# Epoch 37/100
# 192/192 - 2s - loss: 0.0173 - 2s/epoch - 10ms/step
# Epoch 38/100
# 192/192 - 1s - loss: 0.0194 - 1s/epoch - 7ms/step
# Epoch 39/100
# 192/192 - 1s - loss: 0.0180 - 1s/epoch - 7ms/step
# Epoch 40/100
# 192/192 - 1s - loss: 0.0202 - 1s/epoch - 7ms/step
# Epoch 41/100
# 192/192 - 1s - loss: 0.0206 - 1s/epoch - 7ms/step
# Epoch 42/100
# 192/192 - 1s - loss: 0.0179 - 1s/epoch - 7ms/step
# Epoch 43/100
# 192/192 - 1s - loss: 0.0208 - 1s/epoch - 7ms/step
# Epoch 44/100
# 192/192 - 1s - loss: 0.0209 - 1s/epoch - 7ms/step
# Epoch 45/100
# 192/192 - 1s - loss: 0.0206 - 1s/epoch - 7ms/step
# Epoch 46/100
# 192/192 - 2s - loss: 0.0196 - 2s/epoch - 10ms/step
# Epoch 47/100
# 192/192 - 2s - loss: 0.0176 - 2s/epoch - 9ms/step
# Epoch 48/100
# 192/192 - 1s - loss: 0.0203 - 1s/epoch - 7ms/step
# Epoch 49/100
# 192/192 - 1s - loss: 0.0214 - 1s/epoch - 7ms/step
# Epoch 50/100
# 192/192 - 1s - loss: 0.0193 - 1s/epoch - 7ms/step
# Epoch 51/100
# 192/192 - 1s - loss: 0.0185 - 1s/epoch - 7ms/step
# Epoch 52/100
# 192/192 - 1s - loss: 0.0209 - 1s/epoch - 7ms/step
# Epoch 53/100
# 192/192 - 1s - loss: 0.0199 - 1s/epoch - 7ms/step
# Epoch 54/100
# 192/192 - 1s - loss: 0.0216 - 1s/epoch - 7ms/step
# Epoch 55/100
# 192/192 - 2s - loss: 0.0198 - 2s/epoch - 9ms/step
# Epoch 56/100
# 192/192 - 2s - loss: 0.0212 - 2s/epoch - 10ms/step
# Epoch 57/100
# 192/192 - 2s - loss: 0.0240 - 2s/epoch - 8ms/step
# Epoch 58/100
# 192/192 - 1s - loss: 0.0210 - 1s/epoch - 7ms/step
# Epoch 59/100
# 192/192 - 1s - loss: 0.0194 - 1s/epoch - 7ms/step
# Epoch 60/100
# 192/192 - 1s - loss: 0.0195 - 1s/epoch - 7ms/step
# Epoch 61/100
# 192/192 - 1s - loss: 0.0201 - 1s/epoch - 7ms/step
# Epoch 62/100
# 192/192 - 1s - loss: 0.0208 - 1s/epoch - 7ms/step
# Epoch 63/100
# 192/192 - 1s - loss: 0.0183 - 1s/epoch - 7ms/step
# Epoch 64/100
# 192/192 - 1s - loss: 0.0184 - 1s/epoch - 7ms/step
# Epoch 65/100
# 192/192 - 2s - loss: 0.0180 - 2s/epoch - 9ms/step
# Epoch 66/100
# 192/192 - 2s - loss: 0.0175 - 2s/epoch - 10ms/step
# Epoch 67/100
# 192/192 - 1s - loss: 0.0195 - 1s/epoch - 8ms/step
# Epoch 68/100
# 192/192 - 1s - loss: 0.0167 - 1s/epoch - 7ms/step
# Epoch 69/100
# 192/192 - 1s - loss: 0.0157 - 1s/epoch - 7ms/step
# Epoch 70/100
# 192/192 - 1s - loss: 0.0169 - 1s/epoch - 7ms/step
# Epoch 71/100
# 192/192 - 1s - loss: 0.0183 - 1s/epoch - 7ms/step
# Epoch 72/100
# 192/192 - 1s - loss: 0.0184 - 1s/epoch - 7ms/step
# Epoch 73/100
# 192/192 - 1s - loss: 0.0190 - 1s/epoch - 7ms/step
# Epoch 74/100
# 192/192 - 1s - loss: 0.0150 - 1s/epoch - 7ms/step
# Epoch 75/100
# 192/192 - 2s - loss: 0.0164 - 2s/epoch - 9ms/step
# Epoch 76/100
# 192/192 - 2s - loss: 0.0152 - 2s/epoch - 10ms/step
# Epoch 77/100
# 192/192 - 1s - loss: 0.0164 - 1s/epoch - 7ms/step
# Epoch 78/100
# 192/192 - 1s - loss: 0.0167 - 1s/epoch - 7ms/step
# Epoch 79/100
# 192/192 - 1s - loss: 0.0194 - 1s/epoch - 7ms/step
# Epoch 80/100
# 192/192 - 1s - loss: 0.0169 - 1s/epoch - 7ms/step
# Epoch 81/100
# 192/192 - 1s - loss: 0.0178 - 1s/epoch - 7ms/step
# Epoch 82/100
# 192/192 - 1s - loss: 0.0203 - 1s/epoch - 7ms/step
# Epoch 83/100
# 192/192 - 1s - loss: 0.0164 - 1s/epoch - 7ms/step
# Epoch 84/100
# 192/192 - 1s - loss: 0.0158 - 1s/epoch - 7ms/step
# Epoch 85/100
# 192/192 - 2s - loss: 0.0162 - 2s/epoch - 10ms/step
# Epoch 86/100
# 192/192 - 2s - loss: 0.0174 - 2s/epoch - 10ms/step
# Epoch 87/100
# 192/192 - 1s - loss: 0.0157 - 1s/epoch - 7ms/step
# Epoch 88/100
# 192/192 - 1s - loss: 0.0153 - 1s/epoch - 7ms/step
# Epoch 89/100
# 192/192 - 1s - loss: 0.0163 - 1s/epoch - 7ms/step
# Epoch 90/100
# 192/192 - 1s - loss: 0.0149 - 1s/epoch - 7ms/step
# Epoch 91/100
# 192/192 - 1s - loss: 0.0143 - 1s/epoch - 7ms/step
# Epoch 92/100
# 192/192 - 1s - loss: 0.0160 - 1s/epoch - 7ms/step
# Epoch 93/100
# 192/192 - 1s - loss: 0.0162 - 1s/epoch - 7ms/step
# Epoch 94/100
# 192/192 - 1s - loss: 0.0153 - 1s/epoch - 7ms/step
# Epoch 95/100
# 192/192 - 2s - loss: 0.0180 - 2s/epoch - 10ms/step
# Epoch 96/100
# 192/192 - 2s - loss: 0.0172 - 2s/epoch - 10ms/step
# Epoch 97/100
# 192/192 - 1s - loss: 0.0137 - 1s/epoch - 7ms/step
# Epoch 98/100
# 192/192 - 1s - loss: 0.0166 - 1s/epoch - 7ms/step
# Epoch 99/100
# 192/192 - 1s - loss: 0.0154 - 1s/epoch - 7ms/step
# Epoch 100/100
# 192/192 - 1s - loss: 0.0182 - 1s/epoch - 7ms/step
# 6/6 [==============================] - 1s 4ms/step
# Epoch 1/100
# 190/190 - 6s - loss: 0.1670 - 6s/epoch - 29ms/step
# Epoch 2/100
# 190/190 - 2s - loss: 0.1146 - 2s/epoch - 12ms/step
# Epoch 3/100
# 190/190 - 2s - loss: 0.1119 - 2s/epoch - 8ms/step
# Epoch 4/100
# 190/190 - 2s - loss: 0.1018 - 2s/epoch - 9ms/step
# Epoch 5/100
# 190/190 - 2s - loss: 0.1047 - 2s/epoch - 9ms/step
# Epoch 6/100
# 190/190 - 2s - loss: 0.0811 - 2s/epoch - 9ms/step
# Epoch 7/100
# 190/190 - 2s - loss: 0.0620 - 2s/epoch - 8ms/step
# Epoch 8/100
# 190/190 - 2s - loss: 0.0520 - 2s/epoch - 9ms/step
# Epoch 9/100
# 190/190 - 2s - loss: 0.0384 - 2s/epoch - 13ms/step
# Epoch 10/100
# 190/190 - 2s - loss: 0.0410 - 2s/epoch - 11ms/step
# Epoch 11/100
# 190/190 - 2s - loss: 0.0411 - 2s/epoch - 9ms/step
# Epoch 12/100
# 190/190 - 2s - loss: 0.0305 - 2s/epoch - 9ms/step
# Epoch 13/100
# 190/190 - 2s - loss: 0.0391 - 2s/epoch - 8ms/step
# Epoch 14/100
# 190/190 - 2s - loss: 0.0316 - 2s/epoch - 9ms/step
# Epoch 15/100
# 190/190 - 2s - loss: 0.0295 - 2s/epoch - 8ms/step
# Epoch 16/100
# 190/190 - 2s - loss: 0.0336 - 2s/epoch - 10ms/step
# Epoch 17/100
# 190/190 - 2s - loss: 0.0311 - 2s/epoch - 13ms/step
# Epoch 18/100
# 190/190 - 2s - loss: 0.0277 - 2s/epoch - 10ms/step
# Epoch 19/100
# 190/190 - 2s - loss: 0.0268 - 2s/epoch - 8ms/step
# Epoch 20/100
# 190/190 - 2s - loss: 0.0271 - 2s/epoch - 8ms/step
# Epoch 21/100
# 190/190 - 2s - loss: 0.0241 - 2s/epoch - 9ms/step
# Epoch 22/100
# 190/190 - 2s - loss: 0.0245 - 2s/epoch - 8ms/step
# Epoch 23/100
# 190/190 - 2s - loss: 0.0216 - 2s/epoch - 9ms/step
# Epoch 24/100
# 190/190 - 2s - loss: 0.0213 - 2s/epoch - 11ms/step
# Epoch 25/100
# 190/190 - 2s - loss: 0.0224 - 2s/epoch - 13ms/step
# Epoch 26/100
# 190/190 - 2s - loss: 0.0231 - 2s/epoch - 9ms/step
# Epoch 27/100
# 190/190 - 2s - loss: 0.0243 - 2s/epoch - 8ms/step
# Epoch 28/100
# 190/190 - 2s - loss: 0.0231 - 2s/epoch - 8ms/step
# Epoch 29/100
# 190/190 - 2s - loss: 0.0277 - 2s/epoch - 9ms/step
# Epoch 30/100
# 190/190 - 2s - loss: 0.0198 - 2s/epoch - 8ms/step
# Epoch 31/100
# 190/190 - 2s - loss: 0.0222 - 2s/epoch - 9ms/step
# Epoch 32/100
# 190/190 - 2s - loss: 0.0213 - 2s/epoch - 12ms/step
# Epoch 33/100
# 190/190 - 2s - loss: 0.0207 - 2s/epoch - 13ms/step
# Epoch 34/100
# 190/190 - 2s - loss: 0.0223 - 2s/epoch - 8ms/step
# Epoch 35/100
# 190/190 - 2s - loss: 0.0178 - 2s/epoch - 9ms/step
# Epoch 36/100
# 190/190 - 2s - loss: 0.0170 - 2s/epoch - 8ms/step
# Epoch 37/100
# 190/190 - 2s - loss: 0.0192 - 2s/epoch - 9ms/step
# Epoch 38/100
# 190/190 - 2s - loss: 0.0170 - 2s/epoch - 9ms/step
# Epoch 39/100
# 190/190 - 2s - loss: 0.0216 - 2s/epoch - 8ms/step
# Epoch 40/100
# 190/190 - 2s - loss: 0.0185 - 2s/epoch - 12ms/step
# Epoch 41/100
# 190/190 - 2s - loss: 0.0210 - 2s/epoch - 11ms/step
# Epoch 42/100
# 190/190 - 2s - loss: 0.0185 - 2s/epoch - 9ms/step
# Epoch 43/100
# 190/190 - 2s - loss: 0.0199 - 2s/epoch - 9ms/step
# Epoch 44/100
# 190/190 - 2s - loss: 0.0173 - 2s/epoch - 8ms/step
# Epoch 45/100
# 190/190 - 2s - loss: 0.0174 - 2s/epoch - 8ms/step
# Epoch 46/100
# 190/190 - 2s - loss: 0.0172 - 2s/epoch - 9ms/step
# Epoch 47/100
# 190/190 - 2s - loss: 0.0179 - 2s/epoch - 10ms/step
# Epoch 48/100
# 190/190 - 2s - loss: 0.0168 - 2s/epoch - 13ms/step
# Epoch 49/100
# 190/190 - 2s - loss: 0.0193 - 2s/epoch - 10ms/step
# Epoch 50/100
# 190/190 - 2s - loss: 0.0186 - 2s/epoch - 9ms/step
# Epoch 51/100
# 190/190 - 2s - loss: 0.0180 - 2s/epoch - 9ms/step
# Epoch 52/100
# 190/190 - 2s - loss: 0.0208 - 2s/epoch - 9ms/step
# Epoch 53/100
# 190/190 - 2s - loss: 0.0170 - 2s/epoch - 8ms/step
# Epoch 54/100
# 190/190 - 2s - loss: 0.0193 - 2s/epoch - 9ms/step
# Epoch 55/100
# 190/190 - 2s - loss: 0.0184 - 2s/epoch - 11ms/step
# Epoch 56/100
# 190/190 - 2s - loss: 0.0173 - 2s/epoch - 13ms/step
# Epoch 57/100
# 190/190 - 2s - loss: 0.0189 - 2s/epoch - 8ms/step
# Epoch 58/100
# 190/190 - 2s - loss: 0.0164 - 2s/epoch - 9ms/step
# Epoch 59/100
# 190/190 - 2s - loss: 0.0206 - 2s/epoch - 9ms/step
# Epoch 60/100
# 190/190 - 2s - loss: 0.0179 - 2s/epoch - 8ms/step
# Epoch 61/100
# 190/190 - 2s - loss: 0.0164 - 2s/epoch - 9ms/step
# Epoch 62/100
# 190/190 - 2s - loss: 0.0162 - 2s/epoch - 9ms/step
# Epoch 63/100
# 190/190 - 2s - loss: 0.0166 - 2s/epoch - 13ms/step
# Epoch 64/100
# 190/190 - 2s - loss: 0.0195 - 2s/epoch - 12ms/step
# Epoch 65/100
# 190/190 - 2s - loss: 0.0174 - 2s/epoch - 9ms/step
# Epoch 66/100
# 190/190 - 2s - loss: 0.0200 - 2s/epoch - 9ms/step
# Epoch 67/100
# 190/190 - 2s - loss: 0.0156 - 2s/epoch - 9ms/step
# Epoch 68/100
# 190/190 - 2s - loss: 0.0153 - 2s/epoch - 9ms/step
# Epoch 69/100
# 190/190 - 2s - loss: 0.0153 - 2s/epoch - 9ms/step
# Epoch 70/100
# 190/190 - 2s - loss: 0.0166 - 2s/epoch - 9ms/step
# Epoch 71/100
# 190/190 - 2s - loss: 0.0148 - 2s/epoch - 13ms/step
# Epoch 72/100
# 190/190 - 2s - loss: 0.0150 - 2s/epoch - 11ms/step
# Epoch 73/100
# 190/190 - 2s - loss: 0.0144 - 2s/epoch - 8ms/step
# Epoch 74/100
# 190/190 - 2s - loss: 0.0147 - 2s/epoch - 9ms/step
# Epoch 75/100
# 190/190 - 2s - loss: 0.0164 - 2s/epoch - 9ms/step
# Epoch 76/100
# 190/190 - 2s - loss: 0.0162 - 2s/epoch - 9ms/step
# Epoch 77/100
# 190/190 - 2s - loss: 0.0160 - 2s/epoch - 9ms/step
# Epoch 78/100
# 190/190 - 2s - loss: 0.0184 - 2s/epoch - 10ms/step
# Epoch 79/100
# 190/190 - 2s - loss: 0.0166 - 2s/epoch - 13ms/step
# Epoch 80/100
# 190/190 - 2s - loss: 0.0165 - 2s/epoch - 10ms/step
# Epoch 81/100
# 190/190 - 2s - loss: 0.0151 - 2s/epoch - 9ms/step
# Epoch 82/100
# 190/190 - 2s - loss: 0.0171 - 2s/epoch - 9ms/step
# Epoch 83/100
# 190/190 - 2s - loss: 0.0170 - 2s/epoch - 9ms/step
# Epoch 84/100
# 190/190 - 2s - loss: 0.0149 - 2s/epoch - 9ms/step
# Epoch 85/100
# 190/190 - 2s - loss: 0.0167 - 2s/epoch - 9ms/step
# Epoch 86/100
# 190/190 - 2s - loss: 0.0174 - 2s/epoch - 12ms/step
# Epoch 87/100
# 190/190 - 2s - loss: 0.0167 - 2s/epoch - 13ms/step
# Epoch 88/100
# 190/190 - 2s - loss: 0.0168 - 2s/epoch - 9ms/step
# Epoch 89/100
# 190/190 - 2s - loss: 0.0167 - 2s/epoch - 9ms/step
# Epoch 90/100
# 190/190 - 2s - loss: 0.0143 - 2s/epoch - 9ms/step
# Epoch 91/100
# 190/190 - 2s - loss: 0.0155 - 2s/epoch - 9ms/step
# Epoch 92/100
# 190/190 - 2s - loss: 0.0150 - 2s/epoch - 9ms/step
# Epoch 93/100
# 190/190 - 2s - loss: 0.0154 - 2s/epoch - 9ms/step
# Epoch 94/100
# 190/190 - 2s - loss: 0.0165 - 2s/epoch - 13ms/step
# Epoch 95/100
# 190/190 - 2s - loss: 0.0151 - 2s/epoch - 11ms/step
# Epoch 96/100
# 190/190 - 2s - loss: 0.0142 - 2s/epoch - 9ms/step
# Epoch 97/100
# 190/190 - 2s - loss: 0.0128 - 2s/epoch - 9ms/step
# Epoch 98/100
# 190/190 - 2s - loss: 0.0133 - 2s/epoch - 9ms/step
# Epoch 99/100
# 190/190 - 2s - loss: 0.0156 - 2s/epoch - 9ms/step
# Epoch 100/100
# 190/190 - 2s - loss: 0.0155 - 2s/epoch - 9ms/step
# 6/6 [==============================] - 1s 6ms/step
# Epoch 1/100
# 189/189 - 8s - loss: 0.1668 - 8s/epoch - 40ms/step
# Epoch 2/100
# 189/189 - 3s - loss: 0.1470 - 3s/epoch - 15ms/step
# Epoch 3/100
# 189/189 - 3s - loss: 0.1183 - 3s/epoch - 16ms/step
# Epoch 4/100
# 189/189 - 4s - loss: 0.1253 - 4s/epoch - 21ms/step
# Epoch 5/100
# 189/189 - 3s - loss: 0.1015 - 3s/epoch - 15ms/step
# Epoch 6/100
# 189/189 - 3s - loss: 0.0779 - 3s/epoch - 15ms/step
# Epoch 7/100
# 189/189 - 3s - loss: 0.0503 - 3s/epoch - 15ms/step
# Epoch 8/100
# 189/189 - 4s - loss: 0.0431 - 4s/epoch - 19ms/step
# Epoch 9/100
# 189/189 - 3s - loss: 0.0411 - 3s/epoch - 18ms/step
# Epoch 10/100
# 189/189 - 3s - loss: 0.0386 - 3s/epoch - 15ms/step
# Epoch 11/100
# 189/189 - 3s - loss: 0.0350 - 3s/epoch - 14ms/step
# Epoch 12/100
# 189/189 - 3s - loss: 0.0342 - 3s/epoch - 15ms/step
# Epoch 13/100
# 189/189 - 4s - loss: 0.0320 - 4s/epoch - 22ms/step
# Epoch 14/100
# 189/189 - 3s - loss: 0.0288 - 3s/epoch - 15ms/step
# Epoch 15/100
# 189/189 - 3s - loss: 0.0293 - 3s/epoch - 14ms/step
# Epoch 16/100
# 189/189 - 3s - loss: 0.0289 - 3s/epoch - 14ms/step
# Epoch 17/100
# 189/189 - 3s - loss: 0.0247 - 3s/epoch - 18ms/step
# Epoch 18/100
# 189/189 - 4s - loss: 0.0240 - 4s/epoch - 19ms/step
# Epoch 19/100
# 189/189 - 3s - loss: 0.0268 - 3s/epoch - 15ms/step
# Epoch 20/100
# 189/189 - 3s - loss: 0.0234 - 3s/epoch - 15ms/step
# Epoch 21/100
# 189/189 - 3s - loss: 0.0210 - 3s/epoch - 15ms/step
# Epoch 22/100
# 189/189 - 4s - loss: 0.0229 - 4s/epoch - 21ms/step
# Epoch 23/100
# 189/189 - 3s - loss: 0.0242 - 3s/epoch - 16ms/step
# Epoch 24/100
# 189/189 - 3s - loss: 0.0233 - 3s/epoch - 15ms/step
# Epoch 25/100
# 189/189 - 3s - loss: 0.0240 - 3s/epoch - 15ms/step
# Epoch 26/100
# 189/189 - 3s - loss: 0.0259 - 3s/epoch - 17ms/step
# Epoch 27/100
# 189/189 - 4s - loss: 0.0294 - 4s/epoch - 20ms/step
# Epoch 28/100
# 189/189 - 3s - loss: 0.0266 - 3s/epoch - 15ms/step
# Epoch 29/100
# 189/189 - 3s - loss: 0.0235 - 3s/epoch - 15ms/step
# Epoch 30/100
# 189/189 - 3s - loss: 0.0225 - 3s/epoch - 15ms/step
# Epoch 31/100
# 189/189 - 4s - loss: 0.0219 - 4s/epoch - 21ms/step
# Epoch 32/100
# 189/189 - 3s - loss: 0.0230 - 3s/epoch - 16ms/step
# Epoch 33/100
# 189/189 - 3s - loss: 0.0209 - 3s/epoch - 15ms/step
# Epoch 34/100
# 189/189 - 3s - loss: 0.0194 - 3s/epoch - 15ms/step
# Epoch 35/100
# 189/189 - 3s - loss: 0.0228 - 3s/epoch - 16ms/step
# Epoch 36/100
# 189/189 - 4s - loss: 0.0241 - 4s/epoch - 20ms/step
# Epoch 37/100
# 189/189 - 3s - loss: 0.0210 - 3s/epoch - 15ms/step
# Epoch 38/100
# 189/189 - 3s - loss: 0.0205 - 3s/epoch - 15ms/step
# Epoch 39/100
# 189/189 - 3s - loss: 0.0214 - 3s/epoch - 15ms/step
# Epoch 40/100
# 189/189 - 4s - loss: 0.0198 - 4s/epoch - 20ms/step
# Epoch 41/100
# 189/189 - 3s - loss: 0.0174 - 3s/epoch - 17ms/step
# Epoch 42/100
# 189/189 - 3s - loss: 0.0194 - 3s/epoch - 15ms/step
# Epoch 43/100
# 189/189 - 3s - loss: 0.0177 - 3s/epoch - 15ms/step
# Epoch 44/100
# 189/189 - 3s - loss: 0.0173 - 3s/epoch - 16ms/step
# Epoch 45/100
# 189/189 - 4s - loss: 0.0203 - 4s/epoch - 21ms/step
# Epoch 46/100
# 189/189 - 3s - loss: 0.0200 - 3s/epoch - 15ms/step
# Epoch 47/100
# 189/189 - 3s - loss: 0.0215 - 3s/epoch - 15ms/step
# Epoch 48/100
# 189/189 - 3s - loss: 0.0182 - 3s/epoch - 15ms/step
# Epoch 49/100
# 189/189 - 4s - loss: 0.0204 - 4s/epoch - 19ms/step
# Epoch 50/100
# 189/189 - 3s - loss: 0.0165 - 3s/epoch - 18ms/step
# Epoch 51/100
# 189/189 - 3s - loss: 0.0187 - 3s/epoch - 15ms/step
# Epoch 52/100
# 189/189 - 3s - loss: 0.0211 - 3s/epoch - 15ms/step
# Epoch 53/100
# 189/189 - 3s - loss: 0.0196 - 3s/epoch - 15ms/step
# Epoch 54/100
# 189/189 - 4s - loss: 0.0184 - 4s/epoch - 22ms/step
# Epoch 55/100
# 189/189 - 3s - loss: 0.0161 - 3s/epoch - 15ms/step
# Epoch 56/100
# 189/189 - 3s - loss: 0.0193 - 3s/epoch - 15ms/step
# Epoch 57/100
# 189/189 - 3s - loss: 0.0173 - 3s/epoch - 15ms/step
# Epoch 58/100
# 189/189 - 3s - loss: 0.0166 - 3s/epoch - 18ms/step
# Epoch 59/100
# 189/189 - 3s - loss: 0.0168 - 3s/epoch - 18ms/step
# Epoch 60/100
# 189/189 - 3s - loss: 0.0149 - 3s/epoch - 15ms/step
# Epoch 61/100
# 189/189 - 3s - loss: 0.0176 - 3s/epoch - 14ms/step
# Epoch 62/100
# 189/189 - 3s - loss: 0.0211 - 3s/epoch - 15ms/step
# Epoch 63/100
# 189/189 - 4s - loss: 0.0169 - 4s/epoch - 22ms/step
# Epoch 64/100
# 189/189 - 3s - loss: 0.0165 - 3s/epoch - 15ms/step
# Epoch 65/100
# 189/189 - 3s - loss: 0.0160 - 3s/epoch - 15ms/step
# Epoch 66/100
# 189/189 - 3s - loss: 0.0180 - 3s/epoch - 15ms/step
# Epoch 67/100
# 189/189 - 3s - loss: 0.0168 - 3s/epoch - 17ms/step
# Epoch 68/100
# 189/189 - 4s - loss: 0.0194 - 4s/epoch - 19ms/step
# Epoch 69/100
# 189/189 - 3s - loss: 0.0167 - 3s/epoch - 15ms/step
# Epoch 70/100
# 189/189 - 3s - loss: 0.0153 - 3s/epoch - 15ms/step
# Epoch 71/100
# 189/189 - 3s - loss: 0.0146 - 3s/epoch - 14ms/step
# Epoch 72/100
# 189/189 - 4s - loss: 0.0133 - 4s/epoch - 20ms/step
# Epoch 73/100
# 189/189 - 3s - loss: 0.0147 - 3s/epoch - 16ms/step
# Epoch 74/100
# 189/189 - 3s - loss: 0.0146 - 3s/epoch - 14ms/step
# Epoch 75/100
# 189/189 - 3s - loss: 0.0162 - 3s/epoch - 15ms/step
# Epoch 76/100
# 189/189 - 3s - loss: 0.0131 - 3s/epoch - 16ms/step
# Epoch 77/100
# 189/189 - 4s - loss: 0.0165 - 4s/epoch - 21ms/step
# Epoch 78/100
# 189/189 - 3s - loss: 0.0157 - 3s/epoch - 15ms/step
# Epoch 79/100
# 189/189 - 3s - loss: 0.0130 - 3s/epoch - 15ms/step
# Epoch 80/100
# 189/189 - 3s - loss: 0.0149 - 3s/epoch - 15ms/step
# Epoch 81/100
# 189/189 - 4s - loss: 0.0156 - 4s/epoch - 19ms/step
# Epoch 82/100
# 189/189 - 3s - loss: 0.0155 - 3s/epoch - 18ms/step
# Epoch 83/100
# 189/189 - 3s - loss: 0.0169 - 3s/epoch - 15ms/step
# Epoch 84/100
# 189/189 - 3s - loss: 0.0162 - 3s/epoch - 15ms/step
# Epoch 85/100
# 189/189 - 3s - loss: 0.0142 - 3s/epoch - 15ms/step
# Epoch 86/100
# 189/189 - 4s - loss: 0.0151 - 4s/epoch - 22ms/step
# Epoch 87/100
# 189/189 - 3s - loss: 0.0171 - 3s/epoch - 15ms/step
# Epoch 88/100
# 189/189 - 3s - loss: 0.0125 - 3s/epoch - 14ms/step
# Epoch 89/100
# 189/189 - 3s - loss: 0.0132 - 3s/epoch - 14ms/step
# Epoch 90/100
# 189/189 - 3s - loss: 0.0130 - 3s/epoch - 18ms/step
# Epoch 91/100
# 189/189 - 4s - loss: 0.0149 - 4s/epoch - 19ms/step
# Epoch 92/100
# 189/189 - 3s - loss: 0.0131 - 3s/epoch - 15ms/step
# Epoch 93/100
# 189/189 - 3s - loss: 0.0143 - 3s/epoch - 15ms/step
# Epoch 94/100
# 189/189 - 3s - loss: 0.0138 - 3s/epoch - 15ms/step
# Epoch 95/100
# 189/189 - 4s - loss: 0.0128 - 4s/epoch - 21ms/step
# Epoch 96/100
# 189/189 - 3s - loss: 0.0155 - 3s/epoch - 15ms/step
# Epoch 97/100
# 189/189 - 3s - loss: 0.0154 - 3s/epoch - 15ms/step
# Epoch 98/100
# 189/189 - 3s - loss: 0.0145 - 3s/epoch - 14ms/step
# Epoch 99/100
# 189/189 - 3s - loss: 0.0143 - 3s/epoch - 16ms/step
# Epoch 100/100
# 189/189 - 4s - loss: 0.0138 - 4s/epoch - 20ms/step
# 6/6 [==============================] - 1s 7ms/step

# %%
for result in results:
    print(f"n_steps: {result[0]}, RMSE: {result[1]}, MAPE: {result[2]}")
# Out:
# n_steps: 2, RMSE: 0.08974450383379405, MAPE: 0.6043746257119192
# n_steps: 6, RMSE: 0.06984382254810274, MAPE: 0.39138833658776756
# n_steps: 13, RMSE: 0.06602552520469841, MAPE: 0.5582976914392004
# n_steps: 20, RMSE: 0.06199001564911812, MAPE: 0.5244136264768702

# %%
plt.figure(figsize=(10, 5))
plt.plot([result[0] for result in results], [result[1] for result in results], marker='o', label='RMSE')
plt.plot([result[0] for result in results], [result[2] for result in results], marker='o', label='MAPE')
plt.xlabel('n_steps')
plt.ylabel('Error')
plt.title('Error vs. n_steps')
plt.legend()
plt.show()

# %% [markdown]
# The result shows that n_steps = n will reach the most accurate prediction, means that predicting the n+1th days is the best choice

# %% [markdown]
# #### 3.2.5 Cross Validation

# %%
# n_steps = 6
# X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

# %%
# tscv = TimeSeriesSplit(n_splits=5)
# rmse_scores = []
# mape_scores = []

# for train_index, test_index in tscv.split(X1):
#     X_train, X_test = X1[train_index], X1[test_index]
#     y_train, y_test = y1[train_index], y1[test_index]

#     # Define the model
#     model = Sequential()
#     model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
#     model.add(LSTM(50, activation='relu'))
#     model.add(Dense(1))
#     model.compile(loss='mean_squared_error', optimizer='adam')

#     # Train the model
#     model.fit(X_train, y_train, epochs=100, batch_size=4, verbose=0, shuffle=False)

#     # Predict
#     y_pred = model.predict(X_test)
#     y_pred = y_pred[:, 0]

#     # Calculate RMSE and MAPE
#     rmse = mean_squared_error(y_test, y_pred, squared=False)
#     mape = mean_absolute_percentage_error(y_test, y_pred)

#     rmse_scores.append(rmse)
#     mape_scores.append(mape)

# print(f"Average RMSE: {np.mean(rmse_scores)}, Average MAPE: {np.mean(mape_scores)}")

# %% [markdown]
# ###3.3 Run Saved Model

# %%
# Load the SavedModel
model = models.load_model('predict_tlkm.h5')
sc = joblib.load('standard_scaler.pkl')

# %%
def prepare_input_data(ticker, end_date, n_steps):
    stock_data = yf.download(ticker, end=end_date)
    X_feat = stock_data[['Open', 'High', 'Low']]
    target_y = stock_data['Close']

    X_ft = sc.fit_transform(X_feat.values)
    stock_data_ft = pd.DataFrame(columns=X_feat.columns, data=X_ft, index=X_feat.index)
    stock_data_ft['Close'] = target_y.values

    input_data = stock_data_ft.values[-n_steps:, :-1]
    input_data = np.expand_dims(input_data, axis=0)

    return input_data, stock_data_ft.index[-1]

# %%
# Parameter prediksi
ticker = 'TLKM.JK'
end_date = '2024-05-15'
n_steps = 6

# Menyiapkan data input
input_data, last_date = prepare_input_data(ticker, end_date, n_steps)

# Melakukan prediksi
predicted_price_scaled = model.predict(input_data).flatten()[0]

# Mengembalikan hasil prediksi ke skala semula
predicted_price = sc.inverse_transform([[np.nan, predicted_price_scaled, np.nan]])[0][1]

# Menampilkan hasil prediksi
print(f"Harga saham {ticker} yang diprediksi untuk tanggal {end_date} adalah: {predicted_price:.2f}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 1s 831ms/step
# Harga saham TLKM.JK yang diprediksi untuk tanggal 2024-05-15 adalah: 3083.36
