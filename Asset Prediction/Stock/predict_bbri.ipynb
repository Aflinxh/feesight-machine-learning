# %% [markdown]
# #Try Stock Prediction - BBRI

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import joblib
import yfinance as yf
import matplotlib.dates as mdates

import tensorflow as tf
from tensorflow import keras
from keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %% [markdown]
# ## 1. Read Data

# %%
# stock_data = pd.read_csv('/content/NFLX.csv', index_col='Date')
# stock_data

ticker = 'BBRI.JK'
# start_date = '2020-05-20'
# end_date = pd.Timestamp.now().strftime('%Y-%m-%d')
start_date = '2020-05-21'
end_date = '2024-05-21'
stock_data = yf.download(ticker, start=start_date, end=end_date)
stock_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-05-26  2318.141846  2318.141846  2245.415771  2290.869629  1921.681641
# 2020-05-27  2309.051025  2390.867676  2290.869629  2390.867676  2005.564453
# 2020-05-28  2399.958496  2527.229004  2399.958496  2481.775391  2081.821533
# 2020-05-29  2454.503174  2681.771973  2454.503174  2681.771973  2249.587646
# 2020-06-02  2681.771973  2990.857422  2681.771973  2890.859131  2424.979004
# ...                 ...          ...          ...          ...          ...
# 2024-05-14  4720.000000  4810.000000  4700.000000  4730.000000  4730.000000
# 2024-05-15  4780.000000  4870.000000  4760.000000  4820.000000  4820.000000
# 2024-05-16  4930.000000  4960.000000  4840.000000  4840.000000  4840.000000
# 2024-05-17  4840.000000  4960.000000  4820.000000  4920.000000  4920.000000
# 2024-05-20  4990.000000  5050.000000  4820.000000  4820.000000  4820.000000
#
#                Volume
# Date
# 2020-05-26  444514707
# 2020-05-27  476102523
# 2020-05-28  498739044
# 2020-05-29  959884609
# 2020-06-02  514215761
# ...               ...
# 2024-05-14  341458900
# 2024-05-15  298990300
# 2024-05-16  371295000
# 2024-05-17  208991800
# 2024-05-20  335150700
#
# [963 rows x 6 columns]

# %% [markdown]
# ## 2. Plotting Data

# %% [markdown]
# ### 2.1 Plot High & Low

# %%
# Define function to create input and output sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length, :-1])
        y.append(data[i + seq_length, -1])
    return np.array(X), np.array(y)

# Hyperparameters
seq_length = 7
n_features = stock_data.shape[1]
n_units = 64
dropout_rate = 0.2
learning_rate = 0.001
batch_size = 32
epochs = 50

# %% [markdown]
# ### 2.2 Plot Open & Close

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
# x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]
x_dates = stock_data.index

plt.plot(x_dates, stock_data['Open'], label='Open')
plt.plot(x_dates, stock_data['Close'], label='Close')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ## 3. Stock Prediction

# %% [markdown]
# ### 3.1 Normalize or Rescale

# %%
features = stock_data.iloc[:, 0:4]
sc = StandardScaler()
features_scaled = sc.fit_transform(features.values)
stock_data_ft = pd.DataFrame(columns=features.columns, data=features_scaled, index=features.index)

# Simpan objek StandardScaler
joblib.dump(sc, 'standard_scaler.pkl')
# Out:
# ['standard_scaler.pkl']

# %% [markdown]
# ### 3.2 Train & Test

# %% [markdown]
# #### 3.2.1 Splitting

# %%
def lstm_split(data, n_steps):
  X, y = [], []
  for i in range(len(data) - n_steps):
    X.append(data[i:i + n_steps, :-1])
    y.append(data[i + n_steps-1, -1])

  return np.array(X), np.array(y)

# %%
n_steps = 6
X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

train_split = 0.8
split_idx = int(np.ceil(len(X1)*train_split))
date_index = stock_data_ft.index

X_train, X_test = X1[:split_idx], X1[split_idx:]
y_train, y_test = y1[:split_idx], y1[split_idx:]
X_train_date, X_test_date = date_index[n_steps-1:split_idx + n_steps-1], date_index[split_idx + n_steps-1:len(X1) + n_steps-1]

print(X1.shape, X_train.shape, X_test.shape, y_test.shape)
# Out:
# (957, 6, 3) (766, 6, 3) (191, 6, 3) (191,)

# %% [markdown]
# #### 3.2.2 Training

# %%
lstm = Sequential()
lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='tanh', return_sequences=True))
lstm.add(Dropout(0.4))
lstm.add(LSTM(50, activation='tanh'))
lstm.add(Dropout(0.2))
lstm.add(Dense(70, activation = 'relu'))
lstm.add(Dense(70, activation = 'relu'))
lstm.add(Dense(1, activation = 'linear'))
lstm.compile(loss='mean_squared_error', optimizer='adam')
lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 6, 50)             10800
#
#  dropout (Dropout)           (None, 6, 50)             0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 70)                3570
#
#  dense_1 (Dense)             (None, 70)                4970
#
#  dense_2 (Dense)             (None, 1)                 71
#
# =================================================================
# Total params: 39611 (154.73 KB)
# Trainable params: 39611 (154.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

# %%
history = lstm.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=2, verbose = 1, shuffle=True, callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 306/306 [==============================] - 12s 10ms/step - loss: 0.0539 - val_loss: 0.1600
# Epoch 2/100
#  12/306 [>.............................] - ETA: 2s - loss: 0.0205
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 306/306 [==============================] - 3s 9ms/step - loss: 0.0294 - val_loss: 0.1693
# Epoch 3/100
# 306/306 [==============================] - 3s 11ms/step - loss: 0.0267 - val_loss: 0.1759
# Epoch 4/100
# 306/306 [==============================] - 2s 6ms/step - loss: 0.0275 - val_loss: 0.0820
# Epoch 5/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0238 - val_loss: 0.1361
# Epoch 6/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0207 - val_loss: 0.0380
# Epoch 7/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0178 - val_loss: 0.0072
# Epoch 8/100
# 306/306 [==============================] - 3s 9ms/step - loss: 0.0169 - val_loss: 0.0201
# Epoch 9/100
# 306/306 [==============================] - 2s 8ms/step - loss: 0.0136 - val_loss: 0.0469
# Epoch 10/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0179 - val_loss: 0.0505
# Epoch 11/100
# 306/306 [==============================] - 3s 9ms/step - loss: 0.0181 - val_loss: 0.0581
# Epoch 12/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0162 - val_loss: 0.0265
# Epoch 13/100
# 306/306 [==============================] - 3s 9ms/step - loss: 0.0128 - val_loss: 0.0221
# Epoch 14/100
# 306/306 [==============================] - 3s 10ms/step - loss: 0.0139 - val_loss: 0.0374
# Epoch 15/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0139 - val_loss: 0.0462
# Epoch 16/100
# 306/306 [==============================] - 2s 7ms/step - loss: 0.0140 - val_loss: 0.0714
# Epoch 17/100
# 306/306 [==============================] - 3s 8ms/step - loss: 0.0146 - val_loss: 0.0179

# %%
plt.plot(history.history['loss'])
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# #### 3.2.3 Evaluation

# %%
# Make predictions
y_pred = lstm.predict(X_test)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(X_test_date, y_test, label='True Values', color='blue')
plt.plot(X_test_date, y_pred, label='Predicted Values', color='red')
plt.title('True Values vs Predicted Values')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 6/6 [==============================] - 2s 8ms/step

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
mape = mean_absolute_percentage_error(y_test, y_pred)
print("RMSE: ", rmse)
print("MAPE: ", mape)
# Out:
# RMSE:  0.12381468337236654
# MAPE:  0.09026697232032482

# %%
# Save Model
lstm.save("predict_bbri.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# #### 3.2.4 Compare Performance

# %%
n_steps_list = [2, 6, 13, 20]
results = []
models = []

for n_steps in n_steps_list:
    X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

    split_idx = int(np.ceil(len(X1) * 0.8))
    X_train, X_test = X1[:split_idx], X1[split_idx:]
    y_train, y_test = y1[:split_idx], y1[split_idx:]

    lstm = Sequential()
    lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='tanh', return_sequences=True))
    lstm.add(Dropout(0.2))
    lstm.add(LSTM(50, activation='tanh'))
    lstm.add(Dropout(0.2))
    lstm.add(Dense(1))
    lstm.compile(loss='mean_squared_error', optimizer='adam')

    lstm.fit(X_train, y_train, epochs=100, batch_size=4, verbose=2, shuffle=False)

    y_pred = lstm.predict(X_test)
    y_pred = y_pred.flatten()  # Ensure y_pred is a 1D array

    #sc_y.fit(y_train.reshape(-1, 1))  # Fit scaler on training target data
    #y_pred = sc_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
    #y_test = sc_y.inverse_transform(y_test.reshape(-1, 1)).flatten()

    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mape = mean_absolute_percentage_error(y_test, y_pred)

    results.append((n_steps, rmse, mape))
    models.append(lstm)
# Out:
# Epoch 1/100
# 193/193 - 5s - loss: 0.2644 - 5s/epoch - 25ms/step
# Epoch 2/100
# 193/193 - 1s - loss: 0.0230 - 945ms/epoch - 5ms/step
# Epoch 3/100
# 193/193 - 1s - loss: 0.0223 - 923ms/epoch - 5ms/step
# Epoch 4/100
# 193/193 - 1s - loss: 0.0191 - 937ms/epoch - 5ms/step
# Epoch 5/100
# 193/193 - 1s - loss: 0.0176 - 950ms/epoch - 5ms/step
# Epoch 6/100
# 193/193 - 1s - loss: 0.0166 - 945ms/epoch - 5ms/step
# Epoch 7/100
# 193/193 - 1s - loss: 0.0229 - 1s/epoch - 7ms/step
# Epoch 8/100
# 193/193 - 1s - loss: 0.0159 - 1s/epoch - 7ms/step
# Epoch 9/100
# 193/193 - 1s - loss: 0.0139 - 1s/epoch - 7ms/step
# Epoch 10/100
# 193/193 - 1s - loss: 0.0191 - 955ms/epoch - 5ms/step
# Epoch 11/100
# 193/193 - 1s - loss: 0.0117 - 933ms/epoch - 5ms/step
# Epoch 12/100
# 193/193 - 1s - loss: 0.0194 - 993ms/epoch - 5ms/step
# Epoch 13/100
# 193/193 - 1s - loss: 0.0161 - 1s/epoch - 5ms/step
# Epoch 14/100
# 193/193 - 1s - loss: 0.0198 - 950ms/epoch - 5ms/step
# Epoch 15/100
# 193/193 - 1s - loss: 0.0167 - 1s/epoch - 5ms/step
# Epoch 16/100
# 193/193 - 1s - loss: 0.0132 - 979ms/epoch - 5ms/step
# Epoch 17/100
# 193/193 - 1s - loss: 0.0131 - 970ms/epoch - 5ms/step
# Epoch 18/100
# 193/193 - 1s - loss: 0.0150 - 929ms/epoch - 5ms/step
# Epoch 19/100
# 193/193 - 1s - loss: 0.0161 - 949ms/epoch - 5ms/step
# Epoch 20/100
# 193/193 - 1s - loss: 0.0178 - 1s/epoch - 6ms/step
# Epoch 21/100
# 193/193 - 1s - loss: 0.0180 - 1s/epoch - 7ms/step
# Epoch 22/100
# 193/193 - 1s - loss: 0.0139 - 1s/epoch - 6ms/step
# Epoch 23/100
# 193/193 - 1s - loss: 0.0120 - 962ms/epoch - 5ms/step
# Epoch 24/100
# 193/193 - 1s - loss: 0.0139 - 963ms/epoch - 5ms/step
# Epoch 25/100
# 193/193 - 1s - loss: 0.0115 - 972ms/epoch - 5ms/step
# Epoch 26/100
# 193/193 - 1s - loss: 0.0115 - 947ms/epoch - 5ms/step
# Epoch 27/100
# 193/193 - 1s - loss: 0.0162 - 953ms/epoch - 5ms/step
# Epoch 28/100
# 193/193 - 1s - loss: 0.0161 - 949ms/epoch - 5ms/step
# Epoch 29/100
# 193/193 - 1s - loss: 0.0141 - 921ms/epoch - 5ms/step
# Epoch 30/100
# 193/193 - 1s - loss: 0.0126 - 976ms/epoch - 5ms/step
# Epoch 31/100
# 193/193 - 1s - loss: 0.0143 - 941ms/epoch - 5ms/step
# Epoch 32/100
# 193/193 - 1s - loss: 0.0115 - 966ms/epoch - 5ms/step
# Epoch 33/100
# 193/193 - 1s - loss: 0.0132 - 1s/epoch - 7ms/step
# Epoch 34/100
# 193/193 - 1s - loss: 0.0116 - 1s/epoch - 7ms/step
# Epoch 35/100
# 193/193 - 1s - loss: 0.0132 - 1s/epoch - 7ms/step
# Epoch 36/100
# 193/193 - 1s - loss: 0.0121 - 952ms/epoch - 5ms/step
# Epoch 37/100
# 193/193 - 1s - loss: 0.0110 - 974ms/epoch - 5ms/step
# Epoch 38/100
# 193/193 - 1s - loss: 0.0125 - 955ms/epoch - 5ms/step
# Epoch 39/100
# 193/193 - 1s - loss: 0.0129 - 941ms/epoch - 5ms/step
# Epoch 40/100
# 193/193 - 1s - loss: 0.0117 - 933ms/epoch - 5ms/step
# Epoch 41/100
# 193/193 - 1s - loss: 0.0150 - 930ms/epoch - 5ms/step
# Epoch 42/100
# 193/193 - 1s - loss: 0.0101 - 979ms/epoch - 5ms/step
# Epoch 43/100
# 193/193 - 1s - loss: 0.0092 - 964ms/epoch - 5ms/step
# Epoch 44/100
# 193/193 - 1s - loss: 0.0092 - 970ms/epoch - 5ms/step
# Epoch 45/100
# 193/193 - 1s - loss: 0.0115 - 946ms/epoch - 5ms/step
# Epoch 46/100
# 193/193 - 1s - loss: 0.0177 - 1s/epoch - 6ms/step
# Epoch 47/100
# 193/193 - 1s - loss: 0.0211 - 1s/epoch - 7ms/step
# Epoch 48/100
# 193/193 - 1s - loss: 0.0184 - 1s/epoch - 7ms/step
# Epoch 49/100
# 193/193 - 1s - loss: 0.0124 - 1s/epoch - 5ms/step
# Epoch 50/100
# 193/193 - 1s - loss: 0.0107 - 1s/epoch - 5ms/step
# Epoch 51/100
# 193/193 - 1s - loss: 0.0081 - 1s/epoch - 5ms/step
# Epoch 52/100
# 193/193 - 1s - loss: 0.0093 - 975ms/epoch - 5ms/step
# Epoch 53/100
# 193/193 - 1s - loss: 0.0073 - 953ms/epoch - 5ms/step
# Epoch 54/100
# 193/193 - 1s - loss: 0.0094 - 955ms/epoch - 5ms/step
# Epoch 55/100
# 193/193 - 1s - loss: 0.0083 - 1s/epoch - 5ms/step
# Epoch 56/100
# 193/193 - 1s - loss: 0.0135 - 987ms/epoch - 5ms/step
# Epoch 57/100
# 193/193 - 1s - loss: 0.0137 - 992ms/epoch - 5ms/step
# Epoch 58/100
# 193/193 - 1s - loss: 0.0087 - 996ms/epoch - 5ms/step
# Epoch 59/100
# 193/193 - 1s - loss: 0.0137 - 1s/epoch - 6ms/step
# Epoch 60/100
# 193/193 - 1s - loss: 0.0091 - 1s/epoch - 7ms/step
# Epoch 61/100
# 193/193 - 1s - loss: 0.0087 - 1s/epoch - 7ms/step
# Epoch 62/100
# 193/193 - 1s - loss: 0.0093 - 973ms/epoch - 5ms/step
# Epoch 63/100
# 193/193 - 1s - loss: 0.0079 - 952ms/epoch - 5ms/step
# Epoch 64/100
# 193/193 - 1s - loss: 0.0115 - 924ms/epoch - 5ms/step
# Epoch 65/100
# 193/193 - 1s - loss: 0.0089 - 941ms/epoch - 5ms/step
# Epoch 66/100
# 193/193 - 1s - loss: 0.0072 - 962ms/epoch - 5ms/step
# Epoch 67/100
# 193/193 - 1s - loss: 0.0063 - 934ms/epoch - 5ms/step
# Epoch 68/100
# 193/193 - 1s - loss: 0.0085 - 1s/epoch - 5ms/step
# Epoch 69/100
# 193/193 - 1s - loss: 0.0127 - 975ms/epoch - 5ms/step
# Epoch 70/100
# 193/193 - 1s - loss: 0.0111 - 1s/epoch - 5ms/step
# Epoch 71/100
# 193/193 - 1s - loss: 0.0087 - 1s/epoch - 5ms/step
# Epoch 72/100
# 193/193 - 1s - loss: 0.0108 - 1s/epoch - 6ms/step
# Epoch 73/100
# 193/193 - 1s - loss: 0.0097 - 1s/epoch - 7ms/step
# Epoch 74/100
# 193/193 - 1s - loss: 0.0142 - 1s/epoch - 7ms/step
# Epoch 75/100
# 193/193 - 1s - loss: 0.0083 - 1s/epoch - 5ms/step
# Epoch 76/100
# 193/193 - 1s - loss: 0.0100 - 956ms/epoch - 5ms/step
# Epoch 77/100
# 193/193 - 1s - loss: 0.0113 - 921ms/epoch - 5ms/step
# Epoch 78/100
# 193/193 - 1s - loss: 0.0116 - 942ms/epoch - 5ms/step
# Epoch 79/100
# 193/193 - 1s - loss: 0.0110 - 953ms/epoch - 5ms/step
# Epoch 80/100
# 193/193 - 1s - loss: 0.0085 - 937ms/epoch - 5ms/step
# Epoch 81/100
# 193/193 - 1s - loss: 0.0101 - 951ms/epoch - 5ms/step
# Epoch 82/100
# 193/193 - 1s - loss: 0.0090 - 929ms/epoch - 5ms/step
# Epoch 83/100
# 193/193 - 1s - loss: 0.0106 - 937ms/epoch - 5ms/step
# Epoch 84/100
# 193/193 - 1s - loss: 0.0141 - 904ms/epoch - 5ms/step
# Epoch 85/100
# 193/193 - 1s - loss: 0.0147 - 1s/epoch - 5ms/step
# Epoch 86/100
# 193/193 - 1s - loss: 0.0079 - 1s/epoch - 7ms/step
# Epoch 87/100
# 193/193 - 1s - loss: 0.0081 - 1s/epoch - 7ms/step
# Epoch 88/100
# 193/193 - 1s - loss: 0.0098 - 1s/epoch - 6ms/step
# Epoch 89/100
# 193/193 - 1s - loss: 0.0095 - 971ms/epoch - 5ms/step
# Epoch 90/100
# 193/193 - 1s - loss: 0.0092 - 951ms/epoch - 5ms/step
# Epoch 91/100
# 193/193 - 1s - loss: 0.0088 - 960ms/epoch - 5ms/step
# Epoch 92/100
# 193/193 - 1s - loss: 0.0089 - 976ms/epoch - 5ms/step
# Epoch 93/100
# 193/193 - 1s - loss: 0.0114 - 1s/epoch - 7ms/step
# Epoch 94/100
# 193/193 - 1s - loss: 0.0080 - 992ms/epoch - 5ms/step
# Epoch 95/100
# 193/193 - 1s - loss: 0.0105 - 942ms/epoch - 5ms/step
# Epoch 96/100
# 193/193 - 1s - loss: 0.0099 - 949ms/epoch - 5ms/step
# Epoch 97/100
# 193/193 - 1s - loss: 0.0075 - 942ms/epoch - 5ms/step
# Epoch 98/100
# 193/193 - 1s - loss: 0.0106 - 1s/epoch - 5ms/step
# Epoch 99/100
# 193/193 - 1s - loss: 0.0084 - 1s/epoch - 7ms/step
# Epoch 100/100
# 193/193 - 1s - loss: 0.0092 - 1s/epoch - 7ms/step
# 6/6 [==============================] - 1s 3ms/step
# Epoch 1/100
# 192/192 - 6s - loss: 0.1696 - 6s/epoch - 32ms/step
# Epoch 2/100
# 192/192 - 2s - loss: 0.0420 - 2s/epoch - 8ms/step
# Epoch 3/100
# 192/192 - 2s - loss: 0.0423 - 2s/epoch - 10ms/step
# Epoch 4/100
# 192/192 - 2s - loss: 0.0435 - 2s/epoch - 10ms/step
# Epoch 5/100
# 192/192 - 1s - loss: 0.0336 - 1s/epoch - 8ms/step
# Epoch 6/100
# 192/192 - 1s - loss: 0.0390 - 1s/epoch - 8ms/step
# Epoch 7/100
# 192/192 - 1s - loss: 0.0308 - 1s/epoch - 7ms/step
# Epoch 8/100
# 192/192 - 1s - loss: 0.0433 - 1s/epoch - 8ms/step
# Epoch 9/100
# 192/192 - 1s - loss: 0.0434 - 1s/epoch - 7ms/step
# Epoch 10/100
# 192/192 - 1s - loss: 0.0458 - 1s/epoch - 8ms/step
# Epoch 11/100
# 192/192 - 2s - loss: 0.0443 - 2s/epoch - 9ms/step
# Epoch 12/100
# 192/192 - 2s - loss: 0.0410 - 2s/epoch - 10ms/step
# Epoch 13/100
# 192/192 - 2s - loss: 0.0408 - 2s/epoch - 9ms/step
# Epoch 14/100
# 192/192 - 1s - loss: 0.0435 - 1s/epoch - 7ms/step
# Epoch 15/100
# 192/192 - 1s - loss: 0.0371 - 1s/epoch - 8ms/step
# Epoch 16/100
# 192/192 - 1s - loss: 0.0307 - 1s/epoch - 8ms/step
# Epoch 17/100
# 192/192 - 1s - loss: 0.0249 - 1s/epoch - 8ms/step
# Epoch 18/100
# 192/192 - 1s - loss: 0.0271 - 1s/epoch - 8ms/step
# Epoch 19/100
# 192/192 - 1s - loss: 0.0223 - 1s/epoch - 8ms/step
# Epoch 20/100
# 192/192 - 2s - loss: 0.0203 - 2s/epoch - 9ms/step
# Epoch 21/100
# 192/192 - 2s - loss: 0.0192 - 2s/epoch - 11ms/step
# Epoch 22/100
# 192/192 - 2s - loss: 0.0182 - 2s/epoch - 8ms/step
# Epoch 23/100
# 192/192 - 1s - loss: 0.0134 - 1s/epoch - 8ms/step
# Epoch 24/100
# 192/192 - 1s - loss: 0.0150 - 1s/epoch - 7ms/step
# Epoch 25/100
# 192/192 - 2s - loss: 0.0165 - 2s/epoch - 9ms/step
# Epoch 26/100
# 192/192 - 1s - loss: 0.0168 - 1s/epoch - 7ms/step
# Epoch 27/100
# 192/192 - 1s - loss: 0.0173 - 1s/epoch - 8ms/step
# Epoch 28/100
# 192/192 - 1s - loss: 0.0160 - 1s/epoch - 8ms/step
# Epoch 29/100
# 192/192 - 2s - loss: 0.0144 - 2s/epoch - 11ms/step
# Epoch 30/100
# 192/192 - 2s - loss: 0.0154 - 2s/epoch - 11ms/step
# Epoch 31/100
# 192/192 - 1s - loss: 0.0139 - 1s/epoch - 8ms/step
# Epoch 32/100
# 192/192 - 1s - loss: 0.0102 - 1s/epoch - 8ms/step
# Epoch 33/100
# 192/192 - 2s - loss: 0.0127 - 2s/epoch - 8ms/step
# Epoch 34/100
# 192/192 - 1s - loss: 0.0138 - 1s/epoch - 8ms/step
# Epoch 35/100
# 192/192 - 1s - loss: 0.0123 - 1s/epoch - 7ms/step
# Epoch 36/100
# 192/192 - 1s - loss: 0.0098 - 1s/epoch - 8ms/step
# Epoch 37/100
# 192/192 - 2s - loss: 0.0104 - 2s/epoch - 9ms/step
# Epoch 38/100
# 192/192 - 2s - loss: 0.0094 - 2s/epoch - 11ms/step
# Epoch 39/100
# 192/192 - 2s - loss: 0.0115 - 2s/epoch - 9ms/step
# Epoch 40/100
# 192/192 - 1s - loss: 0.0128 - 1s/epoch - 7ms/step
# Epoch 41/100
# 192/192 - 1s - loss: 0.0126 - 1s/epoch - 7ms/step
# Epoch 42/100
# 192/192 - 1s - loss: 0.0120 - 1s/epoch - 8ms/step
# Epoch 43/100
# 192/192 - 1s - loss: 0.0091 - 1s/epoch - 8ms/step
# Epoch 44/100
# 192/192 - 1s - loss: 0.0103 - 1s/epoch - 8ms/step
# Epoch 45/100
# 192/192 - 1s - loss: 0.0092 - 1s/epoch - 8ms/step
# Epoch 46/100
# 192/192 - 2s - loss: 0.0088 - 2s/epoch - 10ms/step
# Epoch 47/100
# 192/192 - 2s - loss: 0.0087 - 2s/epoch - 11ms/step
# Epoch 48/100
# 192/192 - 2s - loss: 0.0098 - 2s/epoch - 8ms/step
# Epoch 49/100
# 192/192 - 1s - loss: 0.0123 - 1s/epoch - 8ms/step
# Epoch 50/100
# 192/192 - 1s - loss: 0.0140 - 1s/epoch - 7ms/step
# Epoch 51/100
# 192/192 - 1s - loss: 0.0130 - 1s/epoch - 7ms/step
# Epoch 52/100
# 192/192 - 1s - loss: 0.0117 - 1s/epoch - 7ms/step
# Epoch 53/100
# 192/192 - 1s - loss: 0.0112 - 1s/epoch - 7ms/step
# Epoch 54/100
# 192/192 - 2s - loss: 0.0102 - 2s/epoch - 8ms/step
# Epoch 55/100
# 192/192 - 2s - loss: 0.0102 - 2s/epoch - 12ms/step
# Epoch 56/100
# 192/192 - 2s - loss: 0.0105 - 2s/epoch - 11ms/step
# Epoch 57/100
# 192/192 - 1s - loss: 0.0132 - 1s/epoch - 8ms/step
# Epoch 58/100
# 192/192 - 1s - loss: 0.0110 - 1s/epoch - 7ms/step
# Epoch 59/100
# 192/192 - 1s - loss: 0.0094 - 1s/epoch - 7ms/step
# Epoch 60/100
# 192/192 - 1s - loss: 0.0101 - 1s/epoch - 7ms/step
# Epoch 61/100
# 192/192 - 1s - loss: 0.0124 - 1s/epoch - 7ms/step
# Epoch 62/100
# 192/192 - 1s - loss: 0.0100 - 1s/epoch - 7ms/step
# Epoch 63/100
# 192/192 - 2s - loss: 0.0093 - 2s/epoch - 8ms/step
# Epoch 64/100
# 192/192 - 2s - loss: 0.0089 - 2s/epoch - 10ms/step
# Epoch 65/100
# 192/192 - 2s - loss: 0.0101 - 2s/epoch - 10ms/step
# Epoch 66/100
# 192/192 - 2s - loss: 0.0122 - 2s/epoch - 8ms/step
# Epoch 67/100
# 192/192 - 1s - loss: 0.0117 - 1s/epoch - 7ms/step
# Epoch 68/100
# 192/192 - 1s - loss: 0.0120 - 1s/epoch - 8ms/step
# Epoch 69/100
# 192/192 - 1s - loss: 0.0086 - 1s/epoch - 8ms/step
# Epoch 70/100
# 192/192 - 1s - loss: 0.0089 - 1s/epoch - 7ms/step
# Epoch 71/100
# 192/192 - 1s - loss: 0.0085 - 1s/epoch - 8ms/step
# Epoch 72/100
# 192/192 - 2s - loss: 0.0101 - 2s/epoch - 9ms/step
# Epoch 73/100
# 192/192 - 2s - loss: 0.0095 - 2s/epoch - 11ms/step
# Epoch 74/100
# 192/192 - 2s - loss: 0.0091 - 2s/epoch - 9ms/step
# Epoch 75/100
# 192/192 - 2s - loss: 0.0083 - 2s/epoch - 8ms/step
# Epoch 76/100
# 192/192 - 1s - loss: 0.0113 - 1s/epoch - 8ms/step
# Epoch 77/100
# 192/192 - 1s - loss: 0.0082 - 1s/epoch - 7ms/step
# Epoch 78/100
# 192/192 - 1s - loss: 0.0089 - 1s/epoch - 7ms/step
# Epoch 79/100
# 192/192 - 1s - loss: 0.0096 - 1s/epoch - 8ms/step
# Epoch 80/100
# 192/192 - 1s - loss: 0.0131 - 1s/epoch - 8ms/step
# Epoch 81/100
# 192/192 - 2s - loss: 0.0090 - 2s/epoch - 10ms/step
# Epoch 82/100
# 192/192 - 2s - loss: 0.0083 - 2s/epoch - 11ms/step
# Epoch 83/100
# 192/192 - 1s - loss: 0.0116 - 1s/epoch - 8ms/step
# Epoch 84/100
# 192/192 - 1s - loss: 0.0106 - 1s/epoch - 7ms/step
# Epoch 85/100
# 192/192 - 1s - loss: 0.0091 - 1s/epoch - 7ms/step
# Epoch 86/100
# 192/192 - 1s - loss: 0.0105 - 1s/epoch - 8ms/step
# Epoch 87/100
# 192/192 - 1s - loss: 0.0109 - 1s/epoch - 7ms/step
# Epoch 88/100
# 192/192 - 1s - loss: 0.0107 - 1s/epoch - 8ms/step
# Epoch 89/100
# 192/192 - 1s - loss: 0.0084 - 1s/epoch - 7ms/step
# Epoch 90/100
# 192/192 - 2s - loss: 0.0090 - 2s/epoch - 10ms/step
# Epoch 91/100
# 192/192 - 2s - loss: 0.0082 - 2s/epoch - 11ms/step
# Epoch 92/100
# 192/192 - 1s - loss: 0.0074 - 1s/epoch - 8ms/step
# Epoch 93/100
# 192/192 - 2s - loss: 0.0102 - 2s/epoch - 8ms/step
# Epoch 94/100
# 192/192 - 1s - loss: 0.0097 - 1s/epoch - 8ms/step
# Epoch 95/100
# 192/192 - 2s - loss: 0.0107 - 2s/epoch - 8ms/step
# Epoch 96/100
# 192/192 - 1s - loss: 0.0084 - 1s/epoch - 7ms/step
# Epoch 97/100
# 192/192 - 1s - loss: 0.0085 - 1s/epoch - 8ms/step
# Epoch 98/100
# 192/192 - 2s - loss: 0.0098 - 2s/epoch - 9ms/step
# Epoch 99/100
# 192/192 - 2s - loss: 0.0089 - 2s/epoch - 11ms/step
# Epoch 100/100
# 192/192 - 2s - loss: 0.0092 - 2s/epoch - 9ms/step
# 6/6 [==============================] - 1s 5ms/step
# Epoch 1/100
# 190/190 - 6s - loss: 0.2050 - 6s/epoch - 33ms/step
# Epoch 2/100
# 190/190 - 2s - loss: 0.0563 - 2s/epoch - 10ms/step
# Epoch 3/100
# 190/190 - 2s - loss: 0.0597 - 2s/epoch - 9ms/step
# Epoch 4/100
# 190/190 - 2s - loss: 0.0713 - 2s/epoch - 9ms/step
# Epoch 5/100
# 190/190 - 2s - loss: 0.0713 - 2s/epoch - 9ms/step
# Epoch 6/100
# 190/190 - 2s - loss: 0.0603 - 2s/epoch - 10ms/step
# Epoch 7/100
# 190/190 - 3s - loss: 0.0541 - 3s/epoch - 14ms/step
# Epoch 8/100
# 190/190 - 2s - loss: 0.0328 - 2s/epoch - 10ms/step
# Epoch 9/100
# 190/190 - 2s - loss: 0.0267 - 2s/epoch - 9ms/step
# Epoch 10/100
# 190/190 - 2s - loss: 0.0221 - 2s/epoch - 10ms/step
# Epoch 11/100
# 190/190 - 2s - loss: 0.0223 - 2s/epoch - 9ms/step
# Epoch 12/100
# 190/190 - 2s - loss: 0.0198 - 2s/epoch - 9ms/step
# Epoch 13/100
# 190/190 - 2s - loss: 0.0193 - 2s/epoch - 10ms/step
# Epoch 14/100
# 190/190 - 3s - loss: 0.0224 - 3s/epoch - 14ms/step
# Epoch 15/100
# 190/190 - 2s - loss: 0.0183 - 2s/epoch - 10ms/step
# Epoch 16/100
# 190/190 - 2s - loss: 0.0170 - 2s/epoch - 10ms/step
# Epoch 17/100
# 190/190 - 2s - loss: 0.0147 - 2s/epoch - 9ms/step
# Epoch 18/100
# 190/190 - 2s - loss: 0.0154 - 2s/epoch - 9ms/step
# Epoch 19/100
# 190/190 - 2s - loss: 0.0137 - 2s/epoch - 9ms/step
# Epoch 20/100
# 190/190 - 2s - loss: 0.0164 - 2s/epoch - 10ms/step
# Epoch 21/100
# 190/190 - 3s - loss: 0.0143 - 3s/epoch - 14ms/step
# Epoch 22/100
# 190/190 - 2s - loss: 0.0132 - 2s/epoch - 11ms/step
# Epoch 23/100
# 190/190 - 2s - loss: 0.0125 - 2s/epoch - 10ms/step
# Epoch 24/100
# 190/190 - 2s - loss: 0.0132 - 2s/epoch - 9ms/step
# Epoch 25/100
# 190/190 - 2s - loss: 0.0148 - 2s/epoch - 9ms/step
# Epoch 26/100
# 190/190 - 2s - loss: 0.0124 - 2s/epoch - 9ms/step
# Epoch 27/100
# 190/190 - 2s - loss: 0.0128 - 2s/epoch - 10ms/step
# Epoch 28/100
# 190/190 - 3s - loss: 0.0129 - 3s/epoch - 14ms/step
# Epoch 29/100
# 190/190 - 2s - loss: 0.0157 - 2s/epoch - 11ms/step
# Epoch 30/100
# 190/190 - 2s - loss: 0.0156 - 2s/epoch - 10ms/step
# Epoch 31/100
# 190/190 - 2s - loss: 0.0151 - 2s/epoch - 10ms/step
# Epoch 32/100
# 190/190 - 2s - loss: 0.0107 - 2s/epoch - 9ms/step
# Epoch 33/100
# 190/190 - 2s - loss: 0.0106 - 2s/epoch - 9ms/step
# Epoch 34/100
# 190/190 - 2s - loss: 0.0099 - 2s/epoch - 10ms/step
# Epoch 35/100
# 190/190 - 3s - loss: 0.0168 - 3s/epoch - 14ms/step
# Epoch 36/100
# 190/190 - 2s - loss: 0.0154 - 2s/epoch - 10ms/step
# Epoch 37/100
# 190/190 - 2s - loss: 0.0089 - 2s/epoch - 9ms/step
# Epoch 38/100
# 190/190 - 2s - loss: 0.0120 - 2s/epoch - 10ms/step
# Epoch 39/100
# 190/190 - 2s - loss: 0.0112 - 2s/epoch - 10ms/step
# Epoch 40/100
# 190/190 - 2s - loss: 0.0093 - 2s/epoch - 10ms/step
# Epoch 41/100
# 190/190 - 2s - loss: 0.0107 - 2s/epoch - 11ms/step
# Epoch 42/100
# 190/190 - 3s - loss: 0.0091 - 3s/epoch - 14ms/step
# Epoch 43/100
# 190/190 - 2s - loss: 0.0095 - 2s/epoch - 10ms/step
# Epoch 44/100
# 190/190 - 2s - loss: 0.0086 - 2s/epoch - 9ms/step
# Epoch 45/100
# 190/190 - 2s - loss: 0.0098 - 2s/epoch - 9ms/step
# Epoch 46/100
# 190/190 - 2s - loss: 0.0098 - 2s/epoch - 10ms/step
# Epoch 47/100
# 190/190 - 2s - loss: 0.0118 - 2s/epoch - 9ms/step
# Epoch 48/100
# 190/190 - 2s - loss: 0.0133 - 2s/epoch - 11ms/step
# Epoch 49/100
# 190/190 - 3s - loss: 0.0090 - 3s/epoch - 14ms/step
# Epoch 50/100
# 190/190 - 2s - loss: 0.0088 - 2s/epoch - 10ms/step
# Epoch 51/100
# 190/190 - 2s - loss: 0.0099 - 2s/epoch - 9ms/step
# Epoch 52/100
# 190/190 - 2s - loss: 0.0096 - 2s/epoch - 9ms/step
# Epoch 53/100
# 190/190 - 2s - loss: 0.0118 - 2s/epoch - 9ms/step
# Epoch 54/100
# 190/190 - 2s - loss: 0.0094 - 2s/epoch - 9ms/step
# Epoch 55/100
# 190/190 - 2s - loss: 0.0078 - 2s/epoch - 11ms/step
# Epoch 56/100
# 190/190 - 3s - loss: 0.0081 - 3s/epoch - 14ms/step
# Epoch 57/100
# 190/190 - 2s - loss: 0.0098 - 2s/epoch - 10ms/step
# Epoch 58/100
# 190/190 - 2s - loss: 0.0096 - 2s/epoch - 9ms/step
# Epoch 59/100
# 190/190 - 2s - loss: 0.0126 - 2s/epoch - 9ms/step
# Epoch 60/100
# 190/190 - 2s - loss: 0.0093 - 2s/epoch - 9ms/step
# Epoch 61/100
# 190/190 - 2s - loss: 0.0086 - 2s/epoch - 9ms/step
# Epoch 62/100
# 190/190 - 2s - loss: 0.0094 - 2s/epoch - 11ms/step
# Epoch 63/100
# 190/190 - 3s - loss: 0.0080 - 3s/epoch - 14ms/step
# Epoch 64/100
# 190/190 - 2s - loss: 0.0101 - 2s/epoch - 10ms/step
# Epoch 65/100
# 190/190 - 2s - loss: 0.0095 - 2s/epoch - 9ms/step
# Epoch 66/100
# 190/190 - 2s - loss: 0.0079 - 2s/epoch - 9ms/step
# Epoch 67/100
# 190/190 - 2s - loss: 0.0076 - 2s/epoch - 9ms/step
# Epoch 68/100
# 190/190 - 2s - loss: 0.0117 - 2s/epoch - 9ms/step
# Epoch 69/100
# 190/190 - 2s - loss: 0.0126 - 2s/epoch - 9ms/step
# Epoch 70/100
# 190/190 - 3s - loss: 0.0125 - 3s/epoch - 14ms/step
# Epoch 71/100
# 190/190 - 2s - loss: 0.0117 - 2s/epoch - 11ms/step
# Epoch 72/100
# 190/190 - 2s - loss: 0.0076 - 2s/epoch - 9ms/step
# Epoch 73/100
# 190/190 - 2s - loss: 0.0089 - 2s/epoch - 9ms/step
# Epoch 74/100
# 190/190 - 2s - loss: 0.0083 - 2s/epoch - 9ms/step
# Epoch 75/100
# 190/190 - 2s - loss: 0.0097 - 2s/epoch - 9ms/step
# Epoch 76/100
# 190/190 - 2s - loss: 0.0094 - 2s/epoch - 11ms/step
# Epoch 77/100
# 190/190 - 3s - loss: 0.0090 - 3s/epoch - 14ms/step
# Epoch 78/100
# 190/190 - 2s - loss: 0.0097 - 2s/epoch - 11ms/step
# Epoch 79/100
# 190/190 - 2s - loss: 0.0098 - 2s/epoch - 9ms/step
# Epoch 80/100
# 190/190 - 2s - loss: 0.0082 - 2s/epoch - 9ms/step
# Epoch 81/100
# 190/190 - 2s - loss: 0.0087 - 2s/epoch - 10ms/step
# Epoch 82/100
# 190/190 - 2s - loss: 0.0088 - 2s/epoch - 9ms/step
# Epoch 83/100
# 190/190 - 2s - loss: 0.0095 - 2s/epoch - 10ms/step
# Epoch 84/100
# 190/190 - 3s - loss: 0.0087 - 3s/epoch - 14ms/step
# Epoch 85/100
# 190/190 - 2s - loss: 0.0091 - 2s/epoch - 11ms/step
# Epoch 86/100
# 190/190 - 2s - loss: 0.0076 - 2s/epoch - 9ms/step
# Epoch 87/100
# 190/190 - 2s - loss: 0.0094 - 2s/epoch - 10ms/step
# Epoch 88/100
# 190/190 - 2s - loss: 0.0097 - 2s/epoch - 9ms/step
# Epoch 89/100
# 190/190 - 2s - loss: 0.0082 - 2s/epoch - 9ms/step
# Epoch 90/100
# 190/190 - 2s - loss: 0.0080 - 2s/epoch - 9ms/step
# Epoch 91/100
# 190/190 - 3s - loss: 0.0118 - 3s/epoch - 15ms/step
# Epoch 92/100
# 190/190 - 2s - loss: 0.0083 - 2s/epoch - 12ms/step
# Epoch 93/100
# 190/190 - 2s - loss: 0.0075 - 2s/epoch - 9ms/step
# Epoch 94/100
# 190/190 - 2s - loss: 0.0086 - 2s/epoch - 9ms/step
# Epoch 95/100
# 190/190 - 2s - loss: 0.0083 - 2s/epoch - 9ms/step
# Epoch 96/100
# 190/190 - 2s - loss: 0.0091 - 2s/epoch - 9ms/step
# Epoch 97/100
# 190/190 - 2s - loss: 0.0106 - 2s/epoch - 9ms/step
# Epoch 98/100
# 190/190 - 3s - loss: 0.0094 - 3s/epoch - 13ms/step
# Epoch 99/100
# 190/190 - 2s - loss: 0.0081 - 2s/epoch - 12ms/step
# Epoch 100/100
# 190/190 - 2s - loss: 0.0074 - 2s/epoch - 9ms/step
# 6/6 [==============================] - 1s 6ms/step
# Epoch 1/100
# 189/189 - 7s - loss: 0.1251 - 7s/epoch - 39ms/step
# Epoch 2/100
# 189/189 - 4s - loss: 0.0686 - 4s/epoch - 20ms/step
# Epoch 3/100
# 189/189 - 3s - loss: 0.0656 - 3s/epoch - 16ms/step
# Epoch 4/100
# 189/189 - 3s - loss: 0.0619 - 3s/epoch - 15ms/step
# Epoch 5/100
# 189/189 - 3s - loss: 0.0573 - 3s/epoch - 16ms/step
# Epoch 6/100
# 189/189 - 4s - loss: 0.0480 - 4s/epoch - 22ms/step
# Epoch 7/100
# 189/189 - 3s - loss: 0.0444 - 3s/epoch - 16ms/step
# Epoch 8/100
# 189/189 - 3s - loss: 0.0364 - 3s/epoch - 15ms/step
# Epoch 9/100
# 189/189 - 3s - loss: 0.0267 - 3s/epoch - 15ms/step
# Epoch 10/100
# 189/189 - 4s - loss: 0.0240 - 4s/epoch - 22ms/step
# Epoch 11/100
# 189/189 - 3s - loss: 0.0213 - 3s/epoch - 17ms/step
# Epoch 12/100
# 189/189 - 3s - loss: 0.0230 - 3s/epoch - 16ms/step
# Epoch 13/100
# 189/189 - 3s - loss: 0.0235 - 3s/epoch - 16ms/step
# Epoch 14/100
# 189/189 - 4s - loss: 0.0197 - 4s/epoch - 20ms/step
# Epoch 15/100
# 189/189 - 3s - loss: 0.0153 - 3s/epoch - 18ms/step
# Epoch 16/100
# 189/189 - 3s - loss: 0.0146 - 3s/epoch - 16ms/step
# Epoch 17/100
# 189/189 - 3s - loss: 0.0160 - 3s/epoch - 16ms/step
# Epoch 18/100
# 189/189 - 3s - loss: 0.0146 - 3s/epoch - 18ms/step
# Epoch 19/100
# 189/189 - 4s - loss: 0.0181 - 4s/epoch - 20ms/step
# Epoch 20/100
# 189/189 - 3s - loss: 0.0160 - 3s/epoch - 15ms/step
# Epoch 21/100
# 189/189 - 3s - loss: 0.0143 - 3s/epoch - 16ms/step
# Epoch 22/100
# 189/189 - 3s - loss: 0.0115 - 3s/epoch - 17ms/step
# Epoch 23/100
# 189/189 - 4s - loss: 0.0113 - 4s/epoch - 22ms/step
# Epoch 24/100
# 189/189 - 3s - loss: 0.0126 - 3s/epoch - 16ms/step
# Epoch 25/100
# 189/189 - 3s - loss: 0.0152 - 3s/epoch - 16ms/step
# Epoch 26/100
# 189/189 - 3s - loss: 0.0140 - 3s/epoch - 16ms/step
# Epoch 27/100
# 189/189 - 4s - loss: 0.0115 - 4s/epoch - 22ms/step
# Epoch 28/100
# 189/189 - 3s - loss: 0.0138 - 3s/epoch - 16ms/step
# Epoch 29/100
# 189/189 - 3s - loss: 0.0114 - 3s/epoch - 16ms/step
# Epoch 30/100
# 189/189 - 3s - loss: 0.0161 - 3s/epoch - 16ms/step
# Epoch 31/100
# 189/189 - 4s - loss: 0.0131 - 4s/epoch - 20ms/step
# Epoch 32/100
# 189/189 - 3s - loss: 0.0102 - 3s/epoch - 18ms/step
# Epoch 33/100
# 189/189 - 3s - loss: 0.0106 - 3s/epoch - 15ms/step
# Epoch 34/100
# 189/189 - 3s - loss: 0.0107 - 3s/epoch - 15ms/step
# Epoch 35/100
# 189/189 - 3s - loss: 0.0110 - 3s/epoch - 17ms/step
# Epoch 36/100
# 189/189 - 4s - loss: 0.0110 - 4s/epoch - 21ms/step
# Epoch 37/100
# 189/189 - 3s - loss: 0.0113 - 3s/epoch - 16ms/step
# Epoch 38/100
# 189/189 - 3s - loss: 0.0122 - 3s/epoch - 16ms/step
# Epoch 39/100
# 189/189 - 3s - loss: 0.0141 - 3s/epoch - 16ms/step
# Epoch 40/100
# 189/189 - 4s - loss: 0.0118 - 4s/epoch - 23ms/step
# Epoch 41/100
# 189/189 - 3s - loss: 0.0104 - 3s/epoch - 15ms/step
# Epoch 42/100
# 189/189 - 3s - loss: 0.0126 - 3s/epoch - 15ms/step
# Epoch 43/100
# 189/189 - 3s - loss: 0.0100 - 3s/epoch - 16ms/step
# Epoch 44/100
# 189/189 - 4s - loss: 0.0126 - 4s/epoch - 21ms/step
# Epoch 45/100
# 189/189 - 3s - loss: 0.0128 - 3s/epoch - 17ms/step
# Epoch 46/100
# 189/189 - 3s - loss: 0.0122 - 3s/epoch - 15ms/step
# Epoch 47/100
# 189/189 - 3s - loss: 0.0114 - 3s/epoch - 16ms/step
# Epoch 48/100
# 189/189 - 3s - loss: 0.0099 - 3s/epoch - 18ms/step
# Epoch 49/100
# 189/189 - 4s - loss: 0.0105 - 4s/epoch - 20ms/step
# Epoch 50/100
# 189/189 - 3s - loss: 0.0091 - 3s/epoch - 15ms/step
# Epoch 51/100
# 189/189 - 3s - loss: 0.0104 - 3s/epoch - 15ms/step
# Epoch 52/100
# 189/189 - 3s - loss: 0.0090 - 3s/epoch - 15ms/step
# Epoch 53/100
# 189/189 - 4s - loss: 0.0104 - 4s/epoch - 23ms/step
# Epoch 54/100
# 189/189 - 3s - loss: 0.0087 - 3s/epoch - 16ms/step
# Epoch 55/100
# 189/189 - 3s - loss: 0.0090 - 3s/epoch - 15ms/step
# Epoch 56/100
# 189/189 - 3s - loss: 0.0088 - 3s/epoch - 15ms/step
# Epoch 57/100
# 189/189 - 4s - loss: 0.0133 - 4s/epoch - 20ms/step
# Epoch 58/100
# 189/189 - 3s - loss: 0.0097 - 3s/epoch - 18ms/step
# Epoch 59/100
# 189/189 - 3s - loss: 0.0073 - 3s/epoch - 15ms/step
# Epoch 60/100
# 189/189 - 3s - loss: 0.0098 - 3s/epoch - 16ms/step
# Epoch 61/100
# 189/189 - 3s - loss: 0.0083 - 3s/epoch - 18ms/step
# Epoch 62/100
# 189/189 - 4s - loss: 0.0082 - 4s/epoch - 20ms/step
# Epoch 63/100
# 189/189 - 3s - loss: 0.0083 - 3s/epoch - 16ms/step
# Epoch 64/100
# 189/189 - 3s - loss: 0.0088 - 3s/epoch - 15ms/step
# Epoch 65/100
# 189/189 - 3s - loss: 0.0078 - 3s/epoch - 16ms/step
# Epoch 66/100
# 189/189 - 4s - loss: 0.0098 - 4s/epoch - 22ms/step
# Epoch 67/100
# 189/189 - 3s - loss: 0.0083 - 3s/epoch - 16ms/step
# Epoch 68/100
# 189/189 - 3s - loss: 0.0073 - 3s/epoch - 16ms/step
# Epoch 69/100
# 189/189 - 3s - loss: 0.0075 - 3s/epoch - 16ms/step
# Epoch 70/100
# 189/189 - 4s - loss: 0.0107 - 4s/epoch - 22ms/step
# Epoch 71/100
# 189/189 - 3s - loss: 0.0072 - 3s/epoch - 16ms/step
# Epoch 72/100
# 189/189 - 3s - loss: 0.0070 - 3s/epoch - 15ms/step
# Epoch 73/100
# 189/189 - 3s - loss: 0.0103 - 3s/epoch - 15ms/step
# Epoch 74/100
# 189/189 - 4s - loss: 0.0104 - 4s/epoch - 20ms/step
# Epoch 75/100
# 189/189 - 4s - loss: 0.0078 - 4s/epoch - 19ms/step
# Epoch 76/100
# 189/189 - 3s - loss: 0.0107 - 3s/epoch - 16ms/step
# Epoch 77/100
# 189/189 - 3s - loss: 0.0096 - 3s/epoch - 15ms/step
# Epoch 78/100
# 189/189 - 3s - loss: 0.0081 - 3s/epoch - 18ms/step
# Epoch 79/100
# 189/189 - 4s - loss: 0.0099 - 4s/epoch - 21ms/step
# Epoch 80/100
# 189/189 - 3s - loss: 0.0086 - 3s/epoch - 16ms/step
# Epoch 81/100
# 189/189 - 3s - loss: 0.0086 - 3s/epoch - 16ms/step
# Epoch 82/100
# 189/189 - 3s - loss: 0.0084 - 3s/epoch - 15ms/step
# Epoch 83/100
# 189/189 - 4s - loss: 0.0074 - 4s/epoch - 22ms/step
# Epoch 84/100
# 189/189 - 3s - loss: 0.0085 - 3s/epoch - 15ms/step
# Epoch 85/100
# 189/189 - 3s - loss: 0.0069 - 3s/epoch - 16ms/step
# Epoch 86/100
# 189/189 - 3s - loss: 0.0073 - 3s/epoch - 16ms/step
# Epoch 87/100
# 189/189 - 4s - loss: 0.0096 - 4s/epoch - 22ms/step
# Epoch 88/100
# 189/189 - 3s - loss: 0.0075 - 3s/epoch - 16ms/step
# Epoch 89/100
# 189/189 - 3s - loss: 0.0077 - 3s/epoch - 15ms/step
# Epoch 90/100
# 189/189 - 3s - loss: 0.0076 - 3s/epoch - 15ms/step
# Epoch 91/100
# 189/189 - 4s - loss: 0.0080 - 4s/epoch - 19ms/step
# Epoch 92/100
# 189/189 - 4s - loss: 0.0068 - 4s/epoch - 19ms/step
# Epoch 93/100
# 189/189 - 3s - loss: 0.0072 - 3s/epoch - 16ms/step
# Epoch 94/100
# 189/189 - 3s - loss: 0.0085 - 3s/epoch - 16ms/step
# Epoch 95/100
# 189/189 - 3s - loss: 0.0078 - 3s/epoch - 17ms/step
# Epoch 96/100
# 189/189 - 4s - loss: 0.0084 - 4s/epoch - 21ms/step
# Epoch 97/100
# 189/189 - 3s - loss: 0.0107 - 3s/epoch - 16ms/step
# Epoch 98/100
# 189/189 - 3s - loss: 0.0102 - 3s/epoch - 16ms/step
# Epoch 99/100
# 189/189 - 3s - loss: 0.0079 - 3s/epoch - 16ms/step
# Epoch 100/100
# 189/189 - 4s - loss: 0.0072 - 4s/epoch - 22ms/step
# 6/6 [==============================] - 1s 8ms/step

# %%
for result in results:
    print(f"n_steps: {result[0]}, RMSE: {result[1]}, MAPE: {result[2]}")
# Out:
# n_steps: 2, RMSE: 0.27584893292147966, MAPE: 0.17552305467797144
# n_steps: 6, RMSE: 0.3022574405111366, MAPE: 0.2420750652781241
# n_steps: 13, RMSE: 0.21736056448090305, MAPE: 0.17157607469199315
# n_steps: 20, RMSE: 0.11752436243073018, MAPE: 0.08611727508647642

# %%
plt.figure(figsize=(10, 5))
plt.plot([result[0] for result in results], [result[1] for result in results], marker='o', label='RMSE')
plt.plot([result[0] for result in results], [result[2] for result in results], marker='o', label='MAPE')
plt.xlabel('n_steps')
plt.ylabel('Error')
plt.title('Error vs. n_steps')
plt.legend()
plt.show()

# %% [markdown]
# The result shows that n_steps = n will reach the most accurate prediction, means that predicting the n+1th days is the best choice

# %% [markdown]
# #### 3.2.5 Cross Validation

# %%
# n_steps = 6
# X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

# %%
# tscv = TimeSeriesSplit(n_splits=5)
# rmse_scores = []
# mape_scores = []

# for train_index, test_index in tscv.split(X1):
#     X_train, X_test = X1[train_index], X1[test_index]
#     y_train, y_test = y1[train_index], y1[test_index]

#     # Define the model
#     model = Sequential()
#     model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
#     model.add(LSTM(50, activation='relu'))
#     model.add(Dense(1))
#     model.compile(loss='mean_squared_error', optimizer='adam')

#     # Train the model
#     model.fit(X_train, y_train, epochs=100, batch_size=4, verbose=0, shuffle=False)

#     # Predict
#     y_pred = model.predict(X_test)
#     y_pred = y_pred[:, 0]

#     # Calculate RMSE and MAPE
#     rmse = mean_squared_error(y_test, y_pred, squared=False)
#     mape = mean_absolute_percentage_error(y_test, y_pred)

#     rmse_scores.append(rmse)
#     mape_scores.append(mape)

# print(f"Average RMSE: {np.mean(rmse_scores)}, Average MAPE: {np.mean(mape_scores)}")

# %% [markdown]
# ###3.3 Run Saved Model

# %%
# Load the SavedModel
model = models.load_model('predict_bbri.h5')
sc = joblib.load('standard_scaler.pkl')

# %%
def prepare_input_data(ticker, end_date, n_steps):
    stock_data = yf.download(ticker, end=end_date)
    X_feat = stock_data[['Open', 'High', 'Low']]
    target_y = stock_data['Close']

    X_ft = sc.fit_transform(X_feat.values)
    stock_data_ft = pd.DataFrame(columns=X_feat.columns, data=X_ft, index=X_feat.index)
    stock_data_ft['Close'] = target_y.values

    input_data = stock_data_ft.values[-n_steps:, :-1]
    input_data = np.expand_dims(input_data, axis=0)

    return input_data, stock_data_ft.index[-1]

# %%
# Parameter prediksi
ticker = 'BBRI.JK'
end_date = '2024-05-15'
n_steps = 6

# Menyiapkan data input
input_data, last_date = prepare_input_data(ticker, end_date, n_steps)

# Melakukan prediksi
predicted_price_scaled = model.predict(input_data).flatten()[0]

# Mengembalikan hasil prediksi ke skala semula
predicted_price = sc.inverse_transform([[np.nan, predicted_price_scaled, np.nan]])[0][1]

# Menampilkan hasil prediksi
print(f"Harga saham {ticker} yang diprediksi untuk tanggal {end_date} adalah: {predicted_price:.2f}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 2s 2s/step
# Harga saham BBRI.JK yang diprediksi untuk tanggal 2024-05-15 adalah: 4860.46
